# %% [markdown]
# Read in all the packages

# %%
import os
import ee
import numpy as np
from geeml.extract import extractor
import pandas as pd
import random

# import geemap
# Authenticate GEE
# ee.Authenticate()
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json"

service_account = 'gee-serdp-upload@appspot.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json")
ee.Initialize(credentials)
# Initialize GEE with high-volume end-point
# ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')
ee.Initialize()

# %%
import geemap
from google.cloud import storage
from google.cloud import client

# %% [markdown]
# Read in assets

# %%
sent_2A = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") #sentinel 2
s2Clouds = ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY') #cloud masking for sentinel
lfdb = ee.FeatureCollection("users/spotter/fire_cnn/ann_w_id") #anna polygons 

#need to add ids to annas polygons
# Create a sequence of numbers from 1 to the number of features
# indexes = lfdb.aggregate_array('system:index')
# ids = list(range(1, indexes.size().getInfo() + 1))
# idByIndex = ee.Dictionary.fromLists(indexes, ids)

# # Map over the collection and set the 'ID' property
# lfdb = lfdb.map(lambda feature: feature.set('ID', idByIndex.get(feature.get('system:index'))))

# %% [markdown]
# Mask clouds Sentinel

# %%
#probability of clouds
MAX_CLOUD_PROBABILITY = 50

def sent_maskcloud(image):
    
    
    image = image.select(['B2', 'B3', 'B4', 'B8', 'B11', 'B12'], ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7'])# rename bands to match landsat
  
    image =  image.toShort()
    
    clouds = ee.Image(image.get('cloud_mask')).select('probability')
    
    isNotCloud = clouds.lt(MAX_CLOUD_PROBABILITY)
    
    image = image.updateMask(isNotCloud)

    #reproject 30m but remember b1, b2 and b3 are 10 and the rest are 20
    image1 = image.select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4'])
    image2 = image.select(['SR_B5', 'SR_B7'])

    
    image1 = image1.reproject(
    crs = image1.projection().crs(),
    scale = 30) #resample for landsat
    
    
    image2 = image2.reproject(
    crs = image2.projection().crs(),
    scale = 30) #resample for landsat
    
    image = image1.addBands(image2)
    
    return image 

#Join S2 SR with cloud probability dataset to add cloud mask.
s2SrWithCloudMask = ee.Join.saveFirst('cloud_mask').apply(
    
  primary=sent_2A,
  secondary=s2Clouds,
  condition=ee.Filter.equals(leftField='system:index', rightField='system:index'))

#apply cloud masking
sent_2A = ee.ImageCollection(s2SrWithCloudMask).map(sent_maskcloud)

# %% [markdown]
# Landsat Mask, snow and clouds

# %%
def mask(image):
    qa = image.select('QA_PIXEL')                                       
    mask = qa.bitwiseAnd(8).eq(0).And(qa.bitwiseAnd(10).eq(0)).And(qa.bitwiseAnd(32).eq(0))  
    return(image.updateMask(mask))

# %% [markdown]
# Correct the landsat scale factor and sentinel scale factor

# %%
def land_scale(image):

    return(image.multiply(0.0000275).add(-0.2))

def sent_scale(image):
    return(image.multiply(0.0001))

# %% [markdown]
# Coefficients from Logan Berner to apply correction factors

# %%
import pandas as pd
coeffs = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/raw_files/boreal_xcal_regression_coefficients.csv").fillna(0)

#l5
def landsat_correct(sat, bands):

    """argument 1 is which sattelite, LANDASAT_5 or LANDSAT_8
    argument 2 is bands of interest.  Bands must be in same order as EE,
    
    regression is of form,
    L7 = B0 + (B1 * L5/8) + (B2 * L^2) + (B3 * L^3)
    """

    #bands of interest in order of interest
    l5 = coeffs[(coeffs['satellite'] == sat) & (coeffs['band.or.si'] .isin (bands))] 

    #arrange the band or si column
    l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)
    l5=l5.sort_values('band.or.si')

    b0 = l5['B0'].values.tolist()
    b1 = l5['B1'].values.tolist()
    b2 = l5['B2'].values.tolist()
    b3 = l5['B3'].values.tolist()

    return (b0, b1, b2, b3)

#get the corrections, each output is a list at one of the four locations
l8_corr = landsat_correct(sat = 'LANDSAT_8', bands = ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])
l5_corr = landsat_correct(sat = 'LANDSAT_5', bands = ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])
# Out:
# /tmp/ipykernel_1036380/639313901.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)
# /tmp/ipykernel_1036380/639313901.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)

# %% [markdown]
# Authenticate my google bucket, not sure if this is needed anymore

# %%
os.environ["GCLOUD_PROJECT"] = "gee-serdp-upload"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json"
storage_client = storage.Client.from_service_account_json("/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json")

os.environ["GCLOUD_PROJECT"] = "gee-serdp-upload"
storage_client = storage.Client()
# bucket_name = 'smp-scratch/mtbs_1985'
bucket_name = 'smp-scratch'

bucket = storage_client.bucket(bucket_name)

# %% [markdown]
# There are going to be issues later with different band types, so cast them all to float

# %%
def to_float(image):

    b1 = image.select('SR_B1').cast({'SR_B1':'float'}) #0
    b2 = image.select('SR_B2').cast({'SR_B2':'float'}) #1
    b3 = image.select('SR_B3').cast({'SR_B3':'float'}) #2
    b4 = image.select('SR_B4').cast({'SR_B4':'float'}) #3
    b5 = image.select('SR_B5').cast({'SR_B5':'float'}) #4
    b6 = image.select('SR_B7').cast({'SR_B7':'float'}) #5

    image = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6)

    return image

# %%
def get_pre_post(pre_start, pre_end, post_start, post_end, geometry):

    """parameters are:
    pre_start: the start date for pre fire imagery
    pre_end: the end date for pre fire imagery
    post_start: the start date for post fire imagery
    post_end: the end date for post_fire imagery
    geometry: the geometry to filter by
    """

    #landsat 5
    lt5 = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2').filterDate(pre_start, post_end).filterBounds(geometry)
    #landsat 7
    le7 = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2').filterDate(pre_start, post_end).filterBounds(geometry)
    #landsat 8
    lc8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filterDate(pre_start, post_end).filterBounds(geometry)
    #sentinel 2
    sent = sent_2A.filterDate(pre_start, post_end).filterBounds(geometry)

    #select bands
    pre_lt5 = lt5.filterDate(pre_start, pre_end).map(mask).map(land_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

    #       #ensure we have imagery for the sensor
    if pre_lt5.size().getInfo() > 0 :


        #take the median
        pre_lt5 = pre_lt5.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        pre_lt5_nbr = pre_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        pre_lt5_ndvi = pre_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        pre_lt5_ndii = pre_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        pre_lt5 = pre_lt5.addBands(pre_lt5_nbr).addBands(pre_lt5_ndvi).addBands(pre_lt5_ndii)

        #apply the corrections

        l5_pre_corr = pre_lt5.multiply(l5_corr[1]).add(pre_lt5.pow(2).multiply(l5_corr[2])).add(pre_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])

    #-------now do post-fire
    #select bands
    post_lt5 = lt5.filterDate(post_start, post_end).map(mask).map(land_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

    #       #ensure we have imagery for the sensor
    if post_lt5.size().getInfo() > 0 :



        #take the median
        post_lt5 = post_lt5.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        post_lt5_nbr = post_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        post_lt5_ndvi = post_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        post_lt5_ndii = post_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        post_lt5 = post_lt5.addBands(post_lt5_nbr).addBands(post_lt5_ndvi).addBands(post_lt5_ndii)

        #apply the corrections

        l5_post_corr = post_lt5.multiply(l5_corr[1]).add(post_lt5.pow(2).multiply(l5_corr[2])).add(post_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])


      #         #------------------------------------------Landsat 7, no corrections but get things clipped and do pre fire/post_fire stuff


    #select bands
    pre_le7 = le7.filterDate(pre_start, pre_end).map(mask).map(land_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

    #       #ensure we have imagery for the sensor
    if pre_le7.size().getInfo() > 0 :



        #take the median
        pre_le7 = pre_le7.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        pre_le7_nbr = pre_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        pre_le7_ndvi = pre_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        pre_le7_ndii = pre_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        pre_le72 = pre_le7.addBands(pre_le7_nbr).addBands(pre_le7_ndvi).addBands(pre_le7_ndii)

    #-------now do post-fire
    #select bands
    post_le7 = le7.filterDate(post_start, post_end).map(mask).map(land_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)
    #       #ensure we have imagery for the sensor
    if post_le7.size().getInfo() > 0 :


        #take the median
        post_le7 = post_le7.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        post_le7_nbr = post_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        post_le7_ndvi = post_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        post_le7_ndii = post_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        post_le72 = post_le7.addBands(post_le7_nbr).addBands(post_le7_ndvi).addBands(post_le7_ndii)

    #------------------------------------------Landsat 8 corrections


    #-------first do pre-fire

    #select bands
    pre_lc8 = lc8.filterDate(pre_start, pre_end).map(mask).map(land_scale).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']) .map(to_float)

    #       #ensure we have imagery for the sensor
    if pre_lc8.size().getInfo() > 0 :



        #take the median
        pre_lc8 = pre_lc8.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        pre_lc8_nbr = pre_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        pre_lc8_ndvi = pre_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        pre_lc8_ndii = pre_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        pre_lc8 = pre_lc8.addBands(pre_lc8_nbr).addBands(pre_lc8_ndvi).addBands(pre_lc8_ndii)

        #apply the corrections

        l8_pre_corr = pre_lc8.multiply(l8_corr[1]).add(pre_lc8.pow(2).multiply(l8_corr[2])).add(pre_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

    #-------now do post-fire
    #select bands
    post_lc8 = lc8.filterDate(post_start, post_end).map(mask).map(land_scale).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']) .map(to_float)

    #       #ensure we have imagery for the sensor
    if post_lc8.size().getInfo() > 0 :



        #take the median
        post_lc8 = post_lc8.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        post_lc8_nbr = post_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        post_lc8_ndvi = post_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        post_lc8_ndii = post_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        post_lc8 = post_lc8.addBands(post_lc8_nbr).addBands(post_lc8_ndvi).addBands(post_lc8_ndii)

        #apply the corrections

        l8_post_corr = post_lc8.multiply(l8_corr[1]).add(post_lc8.pow(2).multiply(l8_corr[2])).add(post_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

        # #          #------------------------------------------Sentinel 2 corrections, use landsat 8 coefficients


    ##-------first do pre-fire

    #select bands
    pre_sent = sent_2A.filterDate(pre_start, pre_end).map(sent_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

    #       #ensure we have imagery for the sensor
    if pre_sent.size().getInfo() > 0 :



          #take the median
        pre_sent = pre_sent.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        pre_sent_nbr = pre_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        pre_sent_ndvi = pre_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        pre_sent_ndii = pre_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        pre_sent = pre_sent.addBands(pre_sent_nbr).addBands(pre_sent_ndvi).addBands(pre_sent_ndii)

        #apply the corrections

        sent_pre_corr = pre_sent.multiply(l8_corr[1]).add(pre_sent.pow(2).multiply(l8_corr[2])).add(pre_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

    #-------now do post-fire
    #select bands
    post_sent = sent_2A.filterDate(post_start, post_end).map(sent_scale).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

    #       #ensure we have imagery for the sensor
    if post_sent.size().getInfo() > 0 :



        #take the median
        post_sent = post_sent.median().clip(geometry)

        #calculate nbr, ndvi and ndii
        post_sent_nbr = post_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).cast({'NBR': 'float'})
        post_sent_ndvi = post_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).cast({'NDVI': 'float'})
        post_sent_ndii = post_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).cast({'NDII': 'float'})

        #add the bands back
        post_sent = post_sent.addBands(post_sent_nbr).addBands(post_sent_ndvi).addBands(post_sent_ndii)

        #apply the corrections

        sent_post_corr = post_sent.multiply(l8_corr[1]).add(post_sent.pow(2).multiply(l8_corr[2])).add(post_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])


    #try to see if image exists, if so append

    #----------------------all prefire

    #       #empty list for pre-fire, use this to combine if we have land 5, 7, 8 or sentinel
    pre_input = []

    try:
        l5_pre_corr.getInfo()
        pre_input.append(l5_pre_corr)

    except:
        pass

    try:
        pre_le72.getInfo()
        pre_input.append(pre_le72)

    except:
        pass

    try:
        l8_pre_corr.getInfo()
        pre_input.append(l8_pre_corr)

    except:
        pass

    try:
        sent_pre_corr.getInfo()
        pre_input.append(sent_pre_corr)

    except:
        pass


    #----------------------all postfire

    #         #       #empty list for post-fire, use this to combine if we have land 5, 7, 8 or sentinel
    post_input = []

    try:
        l5_post_corr.getInfo()
        post_input.append(l5_post_corr)

    except:
        pass

    try:
        post_le72.getInfo()
        post_input.append(post_le72)

    except:
        pass

    try:
        l8_post_corr.getInfo()
        post_input.append(l8_post_corr)

    except:
        pass

    try:
        sent_post_corr.getInfo()
        post_input.append(sent_post_corr)

    except:
        pass

    #return the two lists of pre input and post input
    return pre_input, post_input

# %%
#get all the ids within the lfdb shapefile
all_ids = ee.List(lfdb.distinct(["ID"]).aggregate_array("ID"))
all_ids = all_ids.getInfo()

# all_ids = all_ids[0:2]

pre_months = ['-04-01', '-05-01', '-06-01', '-07-01', '-08-01', '-09-01', '-06-01']
end_months = ['-05-01', '-06-01', '-07-01', '-08-01', '-09-01', '-10-01', '-08-31']

all_months = dict(zip(pre_months, end_months))

# all_ids = [1]
#loop through each fire polygon
for i in all_ids:

    #name of output file
    fname = f"median_{i}.tif"

    #check if file exists on my bucket, if it does skip
    stats = storage.Blob(bucket=bucket, name=fname).exists(storage_client)
    if stats == False:
        
        #get the fire polygon of interest
        sub_shape = lfdb.filter(ee.Filter.eq("ID", i))

        #get all other fire ids that are not this one
        not_fires = lfdb.filter(ee.Filter.neq("ID", i))

      
        #first get the bounding box of the fire
        bbox = sub_shape.geometry().bounds()


        #offset the bounding box by a random number
        # all_rands = [0.00, 0.02, -0.02]
        all_rands = [0.00]


        rand1 = random.sample(all_rands, 1)[0]
        rand2 = random.sample(all_rands, 1)[0]

        #offset applied
        proj = ee.Projection("EPSG:4326").translate(rand1, rand2)
        
        #for the bounding box apply the randomly selected offset
        final_buffer = ee.Geometry.Polygon(bbox.coordinates(), proj).transform(proj)
        
        #this is a bit of a hack but we have two different bounding box sizes because when we export we need to use some additonal area to avoid cuttoffs
        final_buffer2 = final_buffer.buffer(distance= 5000).bounds()

        final_buffer = final_buffer.buffer(distance= 40000)#.bounds().transform(proj='EPSG:3413', maxError=1)
    
        #get the year of this fire
        this_year = ee.Number(sub_shape.aggregate_array('Year').get(0))
        
        year = this_year.getInfo() 
        
        pre_start = ee.Date.fromYMD(this_year.subtract(1), 6, 1)
        pre_end = ee.Date.fromYMD(this_year.subtract(1), 8, 31)
        post_start = pre_start.advance(2, 'year')
        post_end = pre_end.advance(2, 'year')
     
        #just getting some date info here to ensure pre fire is one  year before and post fire is one year after the fire year of interest
        startYear = pre_start.get('year')

        #convert to client side
        startYear = startYear.getInfo()  # local string
        endYear = str(int(startYear) + 2)
        startYear = str(startYear)

        
        #loop through all the months and use 85th percentile to download all data
        all_months_images = []

         #loop through all months 
        for m1, m2 in all_months.items():

            if m1 == '-06-01' and m2 == '-08-31':

                start_year = year - 1
                end_year = year + 1

            else:

                start_year = year - 1
                end_year = year



            #get pre dates
            pre_start = str(start_year) + m1
            pre_end = str(start_year) + m2

            #get post dates


            post_start = str(end_year) + m1
            post_end = str(end_year) + m2



            #apply the function to get the pre_fire image and post_fire image
            all_imagery = get_pre_post(pre_start, pre_end, post_start, post_end, final_buffer)

            #return the pre and post fire input imagery lists
            pre_input = all_imagery[0]
            post_input = all_imagery[1]

            #if the lists each are larger than 1 we have imagery
            if (len(pre_input) >0) and (len(post_input) > 0):

                #take the median of the image collections
                pre_input = ee.ImageCollection(pre_input)
                post_input = ee.ImageCollection(post_input)

                #get median of images
                pre_input = pre_input.median()
                post_input= post_input.median()

                #difference the bands
                raw_bands = pre_input.subtract(post_input).multiply(1000)

                b1 = raw_bands.select('SR_B1').cast({'SR_B1':'short'})
                b2 = raw_bands.select('SR_B2').cast({'SR_B2':'short'})
                b3 = raw_bands.select('SR_B3').cast({'SR_B3':'short'})
                b4 = raw_bands.select('SR_B4').cast({'SR_B4':'short'})
                b5 = raw_bands.select('SR_B5').cast({'SR_B5':'short'})
                b6 = raw_bands.select('SR_B7').cast({'SR_B7':'short'})
                b7 = raw_bands.select('NBR').cast({'NBR':'short'})
                b8 = raw_bands.select('NDVI').cast({'NDVI':'short'})
                b9 = raw_bands.select('NDII').cast({'NDII':'short'})

                #combine all the bands
                # raw_bands = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6).addBands(b7).addBands(b8).addBands(b9)
                raw_bands = b7.addBands(b8).addBands(b9)

                all_months_images.append(raw_bands)


        #append to all_days vi
        raw_bands = ee.ImageCollection(all_months_images).reduce(ee.Reducer.percentile([85]))
        
        b1 = raw_bands.select('SR_B1_p85').cast({'SR_B1_p85':'short'}) #0
        b2 = raw_bands.select('SR_B2_p85').cast({'SR_B2_p85':'short'}) #1
        b3 = raw_bands.select('SR_B3_p85').cast({'SR_B3_p85':'short'}) #2
        b4 = raw_bands.select('SR_B4_p85').cast({'SR_B4_p85':'short'}) #3
        b5 = raw_bands.select('SR_B5_p85').cast({'SR_B5_p85':'short'}) #4
        b6 = raw_bands.select('SR_B7_p85').cast({'SR_B7_p85':'short'}) #5
        b7 = raw_bands.select('NBR_p85').cast({'NBR_p85':'short'}) #band 6 is dnbr is numpy
        b8 = raw_bands.select('NDVI_p85').cast({'NDVI_p85':'short'}) #7
        b9 = raw_bands.select('NDII_p85').cast({'NDII_p85':'short'}) #8


        #if using all bands
        raw_bands = b7.addBands(b8).addBands(b9)


        raw_bands = raw_bands.clip(final_buffer)
        
        #we need to see which image ids from the entire lfdb are already included in the buffer
        lfdb_filtered_orig = lfdb.filterBounds(final_buffer)

        #ensure all fires are within the actual year of interest (this_year) and two years prior, otherwise ignore, this is to ensure we don't have nearby fires from previous years
        first_year =  int(startYear) + 1
        second_year =  int(startYear)
        third_year =  int(startYear) - 1
        fourth_year = int(startYear) + 2

        lfdb_filtered = lfdb_filtered_orig.filter(ee.Filter.eq("Year", year))

        bad_filtered = lfdb_filtered_orig.filter(ee.Filter.Or(ee.Filter.eq("Year", second_year), ee.Filter.eq("Year", third_year), ee.Filter.eq("Year", fourth_year)))


        #get ids which are in image
        all_ids_new = ee.List(lfdb_filtered.distinct(["ID"]).aggregate_array("ID")).getInfo()


        #remove ids from all dates which we do not need anymore
        all_ids2 = [i for i in all_ids if i not in all_ids_new]

        #area we have good fires
        fire_rast = lfdb_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

        #areas we have fires from other years or nearby we don't want to use
        bad_fire_rast = bad_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

        #change values to 1 for fire of interest
        fire_rast = fire_rast.where(fire_rast.gt(0), 1)

        #change values for bad fire raster to 1 as well
        bad_fire_rast = bad_fire_rast.where(bad_fire_rast.gt(0), 1)

        #if the fires overlap we want to keep those locations
        bad_fire_rast = bad_fire_rast.where(bad_fire_rast.eq(1).And(fire_rast.eq(1)), 2).unmask(-999)

        #rename to y for the fire raster
        fire_rast = fire_rast.rename(['y'])

        #copy the first values of raw_bands
        y = raw_bands.select(['NBR_p85'], ['y'])

        #turn all values of y to 0
        y  = y.where(y.gt(-10000), 0)

        #turn values to 1 where fire_rast is 1
        y  = y.where(fire_rast.eq(1), 1)

        # #we need to ensure all bands are shorts 
        # b1 = raw_bands.select('SR_B1').cast({'SR_B1':'short'}) 
        # b2 = raw_bands.select('SR_B2').cast({'SR_B2':'short'}) 
        # b3 = raw_bands.select('SR_B3').cast({'SR_B3':'short'}) 
        # b4 = raw_bands.select('SR_B4').cast({'SR_B4':'short'}) 
        # b5 = raw_bands.select('SR_B5').cast({'SR_B5':'short'}) 
        # b6 = raw_bands.select('SR_B7').cast({'SR_B7':'short'}) 
        # b7 = raw_bands.select('NBR').cast({'NBR':'short'}) 
        # b8 = raw_bands.select('NDVI').cast({'NDVI':'short'}) 
        # b9 = raw_bands.select('NDII').cast({'NDII':'short'}) 
        b10 = y.select('y').cast({'y':'short'})

        #combine all the bands for predictors
        # raw_bands = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6).addBands(b7).addBands(b8).addBands(b9)
        # raw_bands = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6).addBands(b7).addBands(b8).addBands(b9)

        #for areas where there are nearby fires or fires in previous years we set those to 0
        raw_bands = raw_bands.updateMask(bad_fire_rast.neq(1))

        #add in the target variable
        raw_bands = raw_bands.addBands(b10)

        #start download
        print(f"Downloading {fname}")


        #export image to my cloud storage
        task = ee.batch.Export.image.toCloudStorage(
                                image = raw_bands.toShort(),
                                region=final_buffer2, 
                                description='median_' + str(i),
                                scale=30,
                                crs='EPSG:3413',
                                maxPixels=1e13,
                                bucket = 'smp-scratch')

        task.start()
        
        
        
        
        
        

#---------original   
        
#         #date ranges for pre and post fire
#         pre_start = ee.Date.fromYMD(this_year.subtract(1), 6, 1)
#         pre_end = ee.Date.fromYMD(this_year.subtract(1), 8, 31)
#         post_start = pre_start.advance(2, 'year')
#         post_end = pre_end.advance(2, 'year')
     
#         #just getting some date info here to ensure pre fire is one  year before and post fire is one year after the fire year of interest
#         startYear = pre_start.get('year')

#         #convert to client side
#         startYear = startYear.getInfo()  # local string
#         endYear = str(int(startYear) + 2)
#         startYear = str(startYear)

#         #------------------------------------------------harmonize landsat
#         startDay  = '01-01' # what is the beginning of date filter | month-day
#         endDay     = '12-30' # what is the end of date filter | month-day



#         #------ RETRIEVE A SENSOR SR COLLECTION FUNCTION -----
#         def getSRcollection(start_date, end_date, sensor):
#             # get a landsat collection for given year, day range, and sensor
#             srCollection = ee.ImageCollection('LANDSAT/'+ sensor + '/C02/T1_L2').filterDate(start_date, end_date)

#             return srCollection

#         #get the image collections only in the dates of interest and filter by the final buffer aoi
#         lt5 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LT05').filterBounds(final_buffer)    
#         le7 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LE07').filterBounds(final_buffer)     
#         lc8 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LC08').filterBounds(final_buffer)        
#         sent= sent_2A.filterBounds(final_buffer)

#         #------------------------------------------Landsat 5 corrections

#         #pre fire apply landsat mask, scale factor etc.
#         pre_lt5 = lt5.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #ensure we have imagery for the sensor
#         if pre_lt5.size().getInfo() > 0 :


#             #take the median pf the collection
#             pre_lt5 = pre_lt5.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             pre_lt5_nbr = pre_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             pre_lt5_ndvi = pre_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             pre_lt5_ndii = pre_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             pre_lt5 = pre_lt5.addBands(pre_lt5_nbr).addBands(pre_lt5_ndvi).addBands(pre_lt5_ndii)

#             #apply the corrections from Logan
#             l5_pre_corr = pre_lt5.multiply(l5_corr[1]).add(pre_lt5.pow(2).multiply(l5_corr[2])).add(pre_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])

#         #-------now do post-fire
#         #select bands
#         post_lt5 = lt5.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if post_lt5.size().getInfo() > 0 :

#             #take the median
#             post_lt5 = post_lt5.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             post_lt5_nbr = post_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             post_lt5_ndvi = post_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             post_lt5_ndii = post_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             post_lt5 = post_lt5.addBands(post_lt5_nbr).addBands(post_lt5_ndvi).addBands(post_lt5_ndii)

#             #apply the corrections

#             l5_post_corr = post_lt5.multiply(l5_corr[1]).add(post_lt5.pow(2).multiply(l5_corr[2])).add(post_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])


#         #------------------------------------------Landsat 7, no corrections but get things clipped and do pre fire/post_fire stuff


#         #select bands
#         pre_le7 = le7.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#               #ensure we have imagery for the sensor
#         if pre_le7.size().getInfo() > 0 :

#             #take the median
#             pre_le7 = pre_le7.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             pre_le7_nbr = pre_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             pre_le7_ndvi = pre_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             pre_le7_ndii = pre_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             pre_le72 = pre_le7.addBands(pre_le7_nbr).addBands(pre_le7_ndvi).addBands(pre_le7_ndii)

# #         #-------now do post-fire
# #         #select bands
#         post_le7 = le7.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if post_le7.size().getInfo() > 0 :


#             #take the median
#             post_le7 = post_le7.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             post_le7_nbr = post_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             post_le7_ndvi = post_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             post_le7_ndii = post_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             post_le72 = post_le7.addBands(post_le7_nbr).addBands(post_le7_ndvi).addBands(post_le7_ndii)

#         #------------------------------------------Landsat 8 corrections


#         #-------first do pre-fire

#         #select bands, note here we rename to match landsat 5 and 7
#         pre_lc8 = lc8.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if pre_lc8.size().getInfo() > 0 :

#             #take the median
#             pre_lc8 = pre_lc8.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             pre_lc8_nbr = pre_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             pre_lc8_ndvi = pre_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             pre_lc8_ndii = pre_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             pre_lc8 = pre_lc8.addBands(pre_lc8_nbr).addBands(pre_lc8_ndvi).addBands(pre_lc8_ndii)

#             #apply the corrections
#             l8_pre_corr = pre_lc8.multiply(l8_corr[1]).add(pre_lc8.pow(2).multiply(l8_corr[2])).add(pre_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

#         #-------now do post-fire
#           #select bands
#         post_lc8 = lc8.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if post_lc8.size().getInfo() > 0 :

#         #take the median
#             post_lc8 = post_lc8.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             post_lc8_nbr = post_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             post_lc8_ndvi = post_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             post_lc8_ndii = post_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             post_lc8 = post_lc8.addBands(post_lc8_nbr).addBands(post_lc8_ndvi).addBands(post_lc8_ndii)

#             #apply the corrections

#             l8_post_corr = post_lc8.multiply(l8_corr[1]).add(post_lc8.pow(2).multiply(l8_corr[2])).add(post_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])
#         #------------------------------------------Sentinel 2 corrections, use landsat 8 coefficients


#         #-------first do pre-fire

#         # select bands
#         pre_sent = sent_2A.filterDate(pre_start, pre_end).map(sent_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if pre_sent.size().getInfo() > 0 :

#             #take the median
#             pre_sent = pre_sent.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             pre_sent_nbr = pre_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             pre_sent_ndvi = pre_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             pre_sent_ndii = pre_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             pre_sent = pre_sent.addBands(pre_sent_nbr).addBands(pre_sent_ndvi).addBands(pre_sent_ndii)

#             #apply the corrections

#             sent_pre_corr = pre_sent.multiply(l8_corr[1]).add(pre_sent.pow(2).multiply(l8_corr[2])).add(pre_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

#         #-------now do post-fire
#         #select bands
#         post_sent = sent_2A.filterDate(post_start, post_end).map(sent_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

#         #       #ensure we have imagery for the sensor
#         if post_sent.size().getInfo() > 0 :

#             #take the median
#             post_sent = post_sent.median().clip(final_buffer)

#             #calculate nbr, ndvi and ndii
#             post_sent_nbr = post_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
#             post_sent_ndvi = post_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
#             post_sent_ndii = post_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

#             #add the bands back
#             post_sent = post_sent.addBands(post_sent_nbr).addBands(post_sent_ndvi).addBands(post_sent_ndii)

#             #apply the corrections

#             sent_post_corr = post_sent.multiply(l8_corr[1]).add(post_sent.pow(2).multiply(l8_corr[2])).add(post_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])


#         #try to see if image exists, if so append

#         #----------------------all prefire

#         #empty list for pre-fire, use this to combine if we have land 5, 7, 8 or sentinel 
#         pre_input = []

#         try:
#             l5_pre_corr.getInfo()
#             pre_input.append(l5_pre_corr)

#         except:
#             pass

#         try:
#             pre_le72.getInfo()
#             pre_input.append(pre_le72)

#         except:
#             pass

#         try:
#             l8_pre_corr.getInfo()
#             pre_input.append(l8_pre_corr)

#         except:
#             pass

#         try:
#             sent_pre_corr.getInfo()
#             pre_input.append(sent_pre_corr)

#         except:
#             pass


#         #----------------------all postfire

#         #empty list for post-fire, use this to combine if we have land 5, 7, 8 or sentinel 
#         post_input = []

#         try:
#             l5_post_corr.getInfo()
#             post_input.append(l5_post_corr)

#         except:
#             pass

#         try:
#             post_le72.getInfo()
#             post_input.append(post_le72)

#         except:
#             pass

#         try:
#             l8_post_corr.getInfo()
#             post_input.append(l8_post_corr)

#         except:
#             pass

#         try:
#             sent_post_corr.getInfo()
#             post_input.append(sent_post_corr)

#         except:
#             pass
    
        
#         #ensure we have both pre fire and post fire imagery, otherwise can't get training data
#         if (len(pre_input) >0) and (len(post_input) > 0):

#             #take the median of the image collections
#             pre_input = ee.ImageCollection(pre_input)
#             post_input = ee.ImageCollection(post_input)

#             pre_input = pre_input.median()
#             post_input= post_input.median()

#             #difference the bands fore pre and post fire
#             raw_bands = pre_input.subtract(post_input).multiply(1000)

#             #we need to see which image ids from the entire lfdb are already included in the buffer
#             lfdb_filtered_orig = lfdb.filterBounds(final_buffer)

#             #ensure all fires are within the actual year of interest (this_year) and two years prior, otherwise ignore, this is to ensure we don't have nearby fires from previous years
#             first_year =  int(startYear) + 1
#             second_year =  int(startYear)
#             third_year =  int(startYear) - 1
#             fourth_year = int(startYear) + 2

#             lfdb_filtered = lfdb_filtered_orig.filter(ee.Filter.eq("Year", first_year))

#             bad_filtered = lfdb_filtered_orig.filter(ee.Filter.Or(ee.Filter.eq("Year", second_year), ee.Filter.eq("Year", third_year), ee.Filter.eq("Year", fourth_year)))


#             #get ids which are in image
#             all_ids_new = ee.List(lfdb_filtered.distinct(["ID"]).aggregate_array("ID")).getInfo()


#             #remove ids from all dates which we do not need anymore
#             all_ids2 = [i for i in all_ids if i not in all_ids_new]

#             #area we have good fires
#             fire_rast = lfdb_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

#             #areas we have fires from other years or nearby we don't want to use
#             bad_fire_rast = bad_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

#             #change values to 1 for fire of interest
#             fire_rast = fire_rast.where(fire_rast.gt(0), 1)

#             #change values for bad fire raster to 1 as well
#             bad_fire_rast = bad_fire_rast.where(bad_fire_rast.gt(0), 1)

#             #if the fires overlap we want to keep those locations
#             bad_fire_rast = bad_fire_rast.where(bad_fire_rast.eq(1).And(fire_rast.eq(1)), 2).unmask(-999)

#             #rename to y for the fire raster
#             fire_rast = fire_rast.rename(['y'])

#             #copy the first values of raw_bands
#             y = post_input.select(['SR_B2'], ['y'])

#             #turn all values of y to 0
#             y  = y.where(y.gt(0), 0)

#             #turn values to 1 where fire_rast is 1
#             y  = y.where(fire_rast.eq(1), 1)
            
#             #we need to ensure all bands are shorts 
#             b1 = raw_bands.select('SR_B1').cast({'SR_B1':'short'}) 
#             b2 = raw_bands.select('SR_B2').cast({'SR_B2':'short'}) 
#             b3 = raw_bands.select('SR_B3').cast({'SR_B3':'short'}) 
#             b4 = raw_bands.select('SR_B4').cast({'SR_B4':'short'}) 
#             b5 = raw_bands.select('SR_B5').cast({'SR_B5':'short'}) 
#             b6 = raw_bands.select('SR_B7').cast({'SR_B7':'short'}) 
#             b7 = raw_bands.select('NBR').cast({'NBR':'short'}) 
#             b8 = raw_bands.select('NDVI').cast({'NDVI':'short'}) 
#             b9 = raw_bands.select('NDII').cast({'NDII':'short'}) 
#             b10 = y.select('y').cast({'y':'short'})
            
#             #combine all the bands for predictors
#             raw_bands = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6).addBands(b7).addBands(b8).addBands(b9)
            
#             #for areas where there are nearby fires or fires in previous years we set those to 0
#             raw_bands = raw_bands.updateMask(bad_fire_rast.neq(1))
            
#             #add in the target variable
#             raw_bands = raw_bands.addBands(b10)

#             #start download
#             print(f"Downloading {fname}")
            

#             #export image to my cloud storage
#             task = ee.batch.Export.image.toCloudStorage(
#                                     image = raw_bands.toShort(),
#                                     region=final_buffer2, 
#                                     description='median_' + str(i),
#                                     scale=30,
#                                     crs='EPSG:3413',
#                                     maxPixels=1e13,
#                                     bucket = 'smp-scratch')

#             task.start()
# Out:
# Downloading median_1195.tif
# Downloading median_1196.tif
# Downloading median_1197.tif
# Downloading median_1198.tif
# Downloading median_1199.tif
# Downloading median_1200.tif
# Downloading median_1201.tif
# Downloading median_1202.tif
# Downloading median_1203.tif
# Downloading median_1204.tif
# Downloading median_1205.tif
# Downloading median_1206.tif
# Downloading median_1207.tif
# Downloading median_1208.tif
# Downloading median_1209.tif
# Downloading median_1210.tif
# Downloading median_1211.tif
# Downloading median_1212.tif
# Downloading median_1213.tif
# Downloading median_1214.tif
# Downloading median_1215.tif
# Downloading median_1216.tif
# Downloading median_1217.tif
# Downloading median_1218.tif
# Downloading median_1219.tif
# Downloading median_1220.tif
# Downloading median_1221.tif
# Downloading median_1222.tif
# Downloading median_1223.tif
# Downloading median_1224.tif
# Downloading median_1225.tif
# Downloading median_1226.tif
# Downloading median_1227.tif
# Downloading median_1228.tif
# Downloading median_1229.tif
# Downloading median_1230.tif
# Downloading median_1231.tif
# Downloading median_1232.tif
# Downloading median_1233.tif
# Downloading median_1234.tif
# Downloading median_1235.tif
# Downloading median_1236.tif
# Downloading median_1237.tif
# Downloading median_1238.tif
# Downloading median_1239.tif
# Downloading median_1240.tif
# Downloading median_1241.tif
# Downloading median_1242.tif
# Downloading median_1243.tif
# Downloading median_1244.tif
# Downloading median_1245.tif
# Downloading median_1246.tif
# Downloading median_1247.tif
# Downloading median_1248.tif
# Downloading median_1249.tif
# Downloading median_1250.tif
# Downloading median_1251.tif
# Downloading median_1252.tif
# Downloading median_1253.tif
# Downloading median_1254.tif
# Downloading median_1255.tif
# Downloading median_1256.tif
# Downloading median_1257.tif
# Downloading median_1258.tif
# Downloading median_1259.tif
# Downloading median_1260.tif
# Downloading median_1261.tif
# Downloading median_1262.tif
# Downloading median_1263.tif
# Downloading median_1264.tif
# Downloading median_1265.tif
# Downloading median_1266.tif
# Downloading median_1267.tif
# Downloading median_1268.tif
# Downloading median_1269.tif
# Downloading median_1270.tif
# Downloading median_1271.tif
# Downloading median_1272.tif
# Downloading median_1273.tif
# Downloading median_1274.tif
# Downloading median_1275.tif
# Downloading median_1276.tif
# Downloading median_1277.tif
# Downloading median_1278.tif
# Downloading median_1279.tif
# Downloading median_1280.tif
# Downloading median_1281.tif
# Downloading median_1282.tif
# Downloading median_1283.tif
# Downloading median_1284.tif
# Downloading median_1285.tif
# Downloading median_1286.tif
# Downloading median_1287.tif
# Downloading median_1288.tif
# Downloading median_1289.tif
# Downloading median_1290.tif
# Downloading median_1291.tif
# Downloading median_1292.tif
# Downloading median_1293.tif
# Downloading median_1294.tif
# Downloading median_1295.tif
# Downloading median_1296.tif
# Downloading median_1297.tif
# Downloading median_1298.tif
# Downloading median_1299.tif
# Downloading median_1300.tif
# Downloading median_1301.tif
# Downloading median_1302.tif
# Downloading median_1303.tif
# Downloading median_1304.tif
# Downloading median_1305.tif
# Downloading median_1306.tif
# Downloading median_1307.tif
# Downloading median_1308.tif
# Downloading median_1309.tif
# Downloading median_1310.tif
# Downloading median_1311.tif
# Downloading median_1312.tif
# Downloading median_1313.tif
# Downloading median_1314.tif
# Downloading median_1315.tif
# Downloading median_1316.tif
# Downloading median_1317.tif
# Downloading median_1318.tif
# Downloading median_1319.tif
# Downloading median_1320.tif
# Downloading median_1321.tif
# Downloading median_1322.tif
# Downloading median_1323.tif
# Downloading median_1324.tif
# Downloading median_1325.tif
# Downloading median_1326.tif
# Downloading median_1327.tif
# Downloading median_1328.tif
# Downloading median_1329.tif
# Downloading median_1330.tif
# Downloading median_1331.tif
# Downloading median_1332.tif
# Downloading median_1333.tif
# Downloading median_1334.tif
# Downloading median_1335.tif
# Downloading median_1336.tif
# Downloading median_1337.tif
# Downloading median_1338.tif
# Downloading median_1339.tif
# Downloading median_1340.tif
# Downloading median_1341.tif
# Downloading median_1342.tif
# Downloading median_1343.tif
# Downloading median_1344.tif
# Downloading median_1345.tif
# Downloading median_1346.tif
# Downloading median_1347.tif
# Downloading median_1348.tif
# Downloading median_1349.tif
# Downloading median_1350.tif
# Downloading median_1351.tif
# Downloading median_1352.tif
# Downloading median_1353.tif
# Downloading median_1354.tif
# Downloading median_1355.tif
# Downloading median_1356.tif
# Downloading median_1357.tif
# Downloading median_1358.tif
# Downloading median_1359.tif
# Downloading median_1360.tif
# Downloading median_1361.tif
# Downloading median_1362.tif
# Downloading median_1363.tif
# Downloading median_1364.tif
# Downloading median_1365.tif
# Downloading median_1366.tif
# Downloading median_1367.tif
# Downloading median_1368.tif
# Downloading median_1369.tif
# Downloading median_1370.tif
# Downloading median_1371.tif
# Downloading median_1372.tif
# Downloading median_1373.tif
# Downloading median_1374.tif
# Downloading median_1375.tif
# Downloading median_1376.tif
# Downloading median_1377.tif
# Downloading median_1378.tif
# Downloading median_1379.tif
# Downloading median_1380.tif
# Downloading median_1381.tif
# Downloading median_1382.tif
# Downloading median_1383.tif
# Downloading median_1384.tif
# Downloading median_1385.tif
# Downloading median_1386.tif
# Downloading median_1387.tif
# Downloading median_1388.tif
# Downloading median_1389.tif
# Downloading median_1390.tif
# Downloading median_1391.tif
# Downloading median_1392.tif
# Downloading median_1393.tif
# Downloading median_1394.tif
# Downloading median_1395.tif
# Downloading median_1396.tif
# Downloading median_1397.tif
# Downloading median_1398.tif
# Downloading median_1399.tif
# Downloading median_1400.tif
# Downloading median_1401.tif
# Downloading median_1402.tif
# Downloading median_1403.tif
# Downloading median_1404.tif
# Downloading median_1405.tif
# Downloading median_1406.tif
# Downloading median_1407.tif
# Downloading median_1408.tif
# Downloading median_1409.tif
# Downloading median_1410.tif
# Downloading median_1411.tif
# Downloading median_1412.tif
# Downloading median_1413.tif
# Downloading median_1414.tif
# Downloading median_1415.tif
# Downloading median_1416.tif
# Downloading median_1417.tif
# Downloading median_1418.tif
# Downloading median_1419.tif
# Downloading median_1420.tif
# Downloading median_1421.tif
# Downloading median_1422.tif
# Downloading median_1423.tif
# Downloading median_1424.tif
# Downloading median_1425.tif
# Downloading median_1426.tif
# Downloading median_1427.tif
# Downloading median_1428.tif
# Downloading median_1429.tif
# Downloading median_1430.tif
# Downloading median_1431.tif
# Downloading median_1432.tif
# Downloading median_1433.tif
# Downloading median_1434.tif
# Downloading median_1435.tif
# Downloading median_1436.tif
# Downloading median_1437.tif
# Downloading median_1438.tif
# Downloading median_1439.tif
# Downloading median_1440.tif
# Downloading median_1441.tif
# Downloading median_1442.tif
# Downloading median_1443.tif
# Downloading median_1444.tif
# Downloading median_1445.tif
# Downloading median_1446.tif
# Downloading median_1447.tif
# Downloading median_1448.tif
# Downloading median_1449.tif
# Downloading median_1450.tif
# Downloading median_1451.tif
# Downloading median_1452.tif
# Downloading median_1453.tif
# Downloading median_1454.tif
# Downloading median_1455.tif
# Downloading median_1456.tif
# Downloading median_1457.tif
# Downloading median_1458.tif
# Downloading median_1459.tif
# Downloading median_1460.tif
# Downloading median_1461.tif
# Downloading median_1462.tif
# Downloading median_1463.tif
# Downloading median_1464.tif
# Downloading median_1465.tif
# Downloading median_1466.tif
# Downloading median_1467.tif
# Downloading median_1468.tif
# Downloading median_1469.tif
# Downloading median_1470.tif
# Downloading median_1471.tif
# Downloading median_1472.tif
# Downloading median_1473.tif
# Downloading median_1474.tif
# Downloading median_1475.tif
# Downloading median_1476.tif
# Downloading median_1477.tif
# Downloading median_1478.tif
# Downloading median_1479.tif
# Downloading median_1480.tif
# Downloading median_1481.tif
# Downloading median_1482.tif
# Downloading median_1483.tif
# Downloading median_1484.tif
# Downloading median_1485.tif
# Downloading median_1486.tif
# Downloading median_1487.tif
# Downloading median_1488.tif
# Downloading median_1489.tif
# Downloading median_1490.tif
# Downloading median_1491.tif
# Downloading median_1492.tif
# Downloading median_1493.tif
# Downloading median_1494.tif
# Downloading median_1495.tif
# Downloading median_1496.tif
# Downloading median_1497.tif
# Downloading median_1498.tif
# Downloading median_1499.tif
# Downloading median_1500.tif
# Downloading median_1501.tif
# Downloading median_1502.tif
# Downloading median_1503.tif
# Downloading median_1504.tif
# Downloading median_1505.tif
# Downloading median_1506.tif
# Downloading median_1507.tif
# Downloading median_1508.tif
# Downloading median_1509.tif
# Downloading median_1510.tif
# Downloading median_1511.tif
# Downloading median_1512.tif
# Downloading median_1513.tif
# Downloading median_1514.tif
# Downloading median_1515.tif
# Downloading median_1516.tif
# Downloading median_1517.tif
# Downloading median_1518.tif
# Downloading median_1519.tif
# Downloading median_1520.tif
# Downloading median_1521.tif
# Downloading median_1522.tif
# Downloading median_1523.tif
# Downloading median_1524.tif
# Downloading median_1525.tif
# Downloading median_1526.tif
# Downloading median_1527.tif
# Downloading median_1528.tif
# Downloading median_1529.tif
# Downloading median_1530.tif
# Downloading median_1531.tif
# Downloading median_1532.tif
# Downloading median_1533.tif
# Downloading median_1534.tif
# Downloading median_1535.tif
# Downloading median_1536.tif
# Downloading median_1537.tif
# Downloading median_1538.tif
# Downloading median_1539.tif
# Downloading median_1540.tif
# Downloading median_1541.tif
# Downloading median_1542.tif
# Downloading median_1543.tif
# Downloading median_1544.tif
# Downloading median_1545.tif
# Downloading median_1546.tif
# Downloading median_1547.tif
# Downloading median_1548.tif
# Downloading median_1549.tif
# Downloading median_1550.tif
# Downloading median_1551.tif
# Downloading median_1552.tif
# Downloading median_1553.tif
# Downloading median_1554.tif
# Downloading median_1555.tif
# Downloading median_1556.tif
# Downloading median_1557.tif
# Downloading median_1558.tif
# Downloading median_1559.tif
# Downloading median_1560.tif
# Downloading median_1561.tif
# Downloading median_1562.tif
# Downloading median_1563.tif
# Downloading median_1564.tif
# Downloading median_1565.tif
# Downloading median_1566.tif
# Downloading median_1567.tif
# Downloading median_1568.tif
# Downloading median_1569.tif
# Downloading median_1570.tif
# Downloading median_1571.tif
# Downloading median_1572.tif
# Downloading median_1573.tif
# Downloading median_1574.tif
# Downloading median_1575.tif
# Downloading median_1576.tif
# Downloading median_1577.tif
# Downloading median_1578.tif
# Downloading median_1579.tif
# Downloading median_1580.tif
# Downloading median_1581.tif
# Downloading median_1582.tif
# Downloading median_1583.tif
# Downloading median_1584.tif
# Downloading median_1585.tif
# Downloading median_1586.tif
# Downloading median_1587.tif
# Downloading median_1588.tif
# Downloading median_1589.tif
# Downloading median_1590.tif
# Downloading median_1591.tif
# Downloading median_1592.tif
# Downloading median_1593.tif
# Downloading median_1594.tif
# Downloading median_1595.tif
# Downloading median_1596.tif
# Downloading median_1597.tif
# Downloading median_1598.tif
# Downloading median_1599.tif
# Downloading median_1600.tif
# Downloading median_1601.tif
# Downloading median_1602.tif
# Downloading median_1603.tif
# Downloading median_1604.tif
# Downloading median_1605.tif
# Downloading median_1606.tif
# Downloading median_1607.tif
# Downloading median_1608.tif
# Downloading median_1609.tif
# Downloading median_1610.tif
# Downloading median_1611.tif
# Downloading median_1612.tif
# Downloading median_1613.tif
# Downloading median_1614.tif
# Downloading median_1615.tif
# Downloading median_1616.tif
# Downloading median_1617.tif
# Downloading median_1618.tif
# Downloading median_1619.tif
# Downloading median_1620.tif
# Downloading median_1621.tif
# Downloading median_1622.tif
# Downloading median_1623.tif
# Downloading median_1624.tif
# Downloading median_1625.tif
# Downloading median_1626.tif
# Downloading median_1627.tif
# Downloading median_1628.tif
# Downloading median_1629.tif
# Downloading median_1630.tif
# Downloading median_1631.tif
# Downloading median_1632.tif
# Downloading median_1633.tif
# Downloading median_1634.tif
# Downloading median_1635.tif
# Downloading median_1636.tif
# Downloading median_1637.tif
# Downloading median_1638.tif
# Downloading median_1639.tif
# Downloading median_1640.tif
# Downloading median_1641.tif
# Downloading median_1642.tif
# Downloading median_1643.tif
# Downloading median_1644.tif
# Downloading median_1645.tif
# Downloading median_1646.tif
# Downloading median_1647.tif
# Downloading median_1648.tif
# Downloading median_1649.tif
# Downloading median_1650.tif
# Downloading median_1651.tif
# Downloading median_1652.tif
# Downloading median_1653.tif
# Downloading median_1654.tif
# Downloading median_1655.tif
# Downloading median_1656.tif
# Downloading median_1657.tif
# Downloading median_1658.tif
# Downloading median_1659.tif
# Downloading median_1660.tif
# Downloading median_1661.tif
# Downloading median_1662.tif
# Downloading median_1663.tif
# Downloading median_1664.tif
# Downloading median_1665.tif
# Downloading median_1666.tif
# Downloading median_1667.tif
# Downloading median_1668.tif
# Downloading median_1669.tif
# Downloading median_1670.tif
# Downloading median_1671.tif
# Downloading median_1672.tif
# Downloading median_1673.tif
# Downloading median_1674.tif
# Downloading median_1675.tif
# Downloading median_1676.tif
# Downloading median_1677.tif
# Downloading median_1678.tif
# Downloading median_1679.tif
# Downloading median_1680.tif
# Downloading median_1681.tif
# Downloading median_1682.tif
# Downloading median_1683.tif
# Downloading median_1684.tif
# Downloading median_1685.tif
# Downloading median_1686.tif
# Downloading median_1687.tif
# Downloading median_1688.tif
# Downloading median_1689.tif
# Downloading median_1690.tif
# Downloading median_1691.tif
# Downloading median_1692.tif
# Downloading median_1693.tif
# Downloading median_1694.tif
# Downloading median_1695.tif
# Downloading median_1696.tif
# Downloading median_1697.tif
# Downloading median_1698.tif
# Downloading median_1699.tif
# Downloading median_1700.tif
# Downloading median_1701.tif
# Downloading median_1702.tif
# Downloading median_1703.tif
# Downloading median_1704.tif
# Downloading median_1705.tif
# Downloading median_1706.tif
# Downloading median_1707.tif
# Downloading median_1708.tif
# Downloading median_1709.tif
# Downloading median_1710.tif
# Downloading median_1711.tif
# Downloading median_1712.tif
# Downloading median_1713.tif
# Downloading median_1714.tif
# Downloading median_1715.tif
# Downloading median_1716.tif
# Downloading median_1717.tif
# Downloading median_1718.tif
# Downloading median_1719.tif
# Downloading median_1720.tif
# Downloading median_1721.tif
# Downloading median_1722.tif
# Downloading median_1723.tif
# Downloading median_1724.tif
# Downloading median_1725.tif
# Downloading median_1726.tif
# Downloading median_1727.tif
# Downloading median_1728.tif
# Downloading median_1729.tif
# Downloading median_1730.tif
# Downloading median_1731.tif
# Downloading median_1732.tif
# Downloading median_1733.tif
# Downloading median_1734.tif
# Downloading median_1735.tif
# Downloading median_1736.tif
# Downloading median_1737.tif
# Downloading median_1738.tif
# Downloading median_1739.tif
# Downloading median_1740.tif
# Downloading median_1741.tif
# Downloading median_1742.tif
# Downloading median_1743.tif
# Downloading median_1744.tif
# Downloading median_1745.tif
# Downloading median_1746.tif
# Downloading median_1747.tif
# Downloading median_1748.tif
# Downloading median_1749.tif
# Downloading median_1750.tif
# Downloading median_1751.tif
# Downloading median_1752.tif
# Downloading median_1753.tif
# Downloading median_1754.tif
# Downloading median_1755.tif
# Downloading median_1756.tif
# Downloading median_1757.tif
# Downloading median_1758.tif
# Downloading median_1759.tif
# Downloading median_1760.tif
# Downloading median_1761.tif
# Downloading median_1762.tif
# Downloading median_1763.tif
# Downloading median_1764.tif
# Downloading median_1765.tif
# Downloading median_1766.tif
# Downloading median_1767.tif
# Downloading median_1768.tif
# Downloading median_1769.tif
# Downloading median_1770.tif
# Downloading median_1771.tif
# Downloading median_1772.tif
# Downloading median_1773.tif
# Downloading median_1774.tif
# Downloading median_1775.tif
# Downloading median_1776.tif
# Downloading median_1777.tif
# Downloading median_1778.tif
# Downloading median_1779.tif
# Downloading median_1780.tif
# Downloading median_1781.tif
# Downloading median_1782.tif
# Downloading median_1783.tif
# Downloading median_1784.tif
# Downloading median_1785.tif
# Downloading median_1786.tif
# Downloading median_1787.tif
# Downloading median_1788.tif
# Downloading median_1789.tif
# Downloading median_1790.tif
# Downloading median_1791.tif
# Downloading median_1792.tif
# Downloading median_1793.tif
# Downloading median_1794.tif
# Downloading median_1795.tif
# Downloading median_1796.tif
# Downloading median_1797.tif
# Downloading median_1798.tif
# Downloading median_1799.tif
# Downloading median_1800.tif
# Downloading median_1801.tif
# Downloading median_1802.tif
# Downloading median_1803.tif
# Downloading median_1804.tif
# Downloading median_1805.tif
# Downloading median_1806.tif
# Downloading median_1807.tif
# Downloading median_1808.tif
# Downloading median_1809.tif
# Downloading median_1810.tif
# Downloading median_1811.tif
# Downloading median_1812.tif
# Downloading median_1813.tif
# Downloading median_1814.tif
# Downloading median_1815.tif
# Downloading median_1816.tif
# Downloading median_1817.tif
# Downloading median_1818.tif
# Downloading median_1819.tif
# Downloading median_1820.tif
# Downloading median_1821.tif
# Downloading median_1822.tif
# Downloading median_1823.tif
# Downloading median_1824.tif
# Downloading median_1825.tif
# Downloading median_1826.tif
# Downloading median_1827.tif
# Downloading median_1828.tif
# Downloading median_1829.tif
# Downloading median_1830.tif
# Downloading median_1831.tif
# Downloading median_1832.tif
# Downloading median_1833.tif
# Downloading median_1834.tif
# Downloading median_1835.tif
# Downloading median_1836.tif
# Downloading median_1837.tif
# Downloading median_1838.tif
# Downloading median_1839.tif
# Downloading median_1840.tif
# Downloading median_1841.tif
# Downloading median_1842.tif
# Downloading median_1843.tif
# Downloading median_1844.tif
# Downloading median_1845.tif
# Downloading median_1846.tif
# Downloading median_1847.tif
# Downloading median_1848.tif
# Downloading median_1849.tif
# Downloading median_1850.tif
# Downloading median_1851.tif
# Downloading median_1852.tif
# Downloading median_1853.tif
# Downloading median_1854.tif
# Downloading median_1855.tif
# Downloading median_1856.tif
# Downloading median_1857.tif
# Downloading median_1858.tif
# Downloading median_1859.tif
# Downloading median_1860.tif
# Downloading median_1861.tif
# Downloading median_1862.tif
# Downloading median_1863.tif
# Downloading median_1864.tif
# Downloading median_1865.tif
# Downloading median_1866.tif
# Downloading median_1867.tif
# Downloading median_1868.tif
# Downloading median_1869.tif
# Downloading median_1870.tif
# Downloading median_1871.tif
# Downloading median_1872.tif
# Downloading median_1873.tif
# Downloading median_1874.tif
# Downloading median_1875.tif
# Downloading median_1876.tif
# Downloading median_1877.tif
# Downloading median_1878.tif
# Downloading median_1879.tif
# Downloading median_1880.tif
# Downloading median_1881.tif
# Downloading median_1882.tif
# Downloading median_1883.tif
# Downloading median_1884.tif
# Downloading median_1885.tif
# Downloading median_1886.tif
# Downloading median_1887.tif
# Downloading median_1888.tif
# Downloading median_1889.tif
# Downloading median_1890.tif
# Downloading median_1891.tif
# Downloading median_1892.tif
# Downloading median_1893.tif
# Downloading median_1894.tif
# Downloading median_1895.tif
# Downloading median_1896.tif
# Downloading median_1897.tif
# Downloading median_1898.tif
# Downloading median_1899.tif
# Downloading median_1900.tif
# Downloading median_1901.tif
# Downloading median_1902.tif
# Downloading median_1903.tif
# Downloading median_1904.tif
# Downloading median_1905.tif
# Downloading median_1906.tif
# Downloading median_1907.tif
# Downloading median_1908.tif
# Downloading median_1909.tif
# Downloading median_1910.tif
# Downloading median_1911.tif
# Downloading median_1912.tif
# Downloading median_1913.tif
# Downloading median_1914.tif
# Downloading median_1915.tif
# Downloading median_1916.tif
# Downloading median_1917.tif
# Downloading median_1918.tif
# Downloading median_1919.tif
# Downloading median_1920.tif
# Downloading median_1921.tif
# Downloading median_1922.tif
# Downloading median_1923.tif
# Downloading median_1924.tif
# Downloading median_1925.tif
# Downloading median_1926.tif
# Downloading median_1927.tif
# Downloading median_1928.tif
# Downloading median_1929.tif
# Downloading median_1930.tif
# Downloading median_1931.tif
# Downloading median_1932.tif
# Downloading median_1933.tif
# Downloading median_1934.tif
# Downloading median_1935.tif
# Downloading median_1936.tif
# Downloading median_1937.tif
# Downloading median_1938.tif
# Downloading median_1939.tif
# Downloading median_1940.tif
# Downloading median_1941.tif
# Downloading median_1942.tif
# Downloading median_1943.tif
# Downloading median_1944.tif
# Downloading median_1945.tif
# Downloading median_1946.tif
# Downloading median_1947.tif
# Downloading median_1948.tif
# Downloading median_1949.tif
# Downloading median_1950.tif
# Downloading median_1951.tif
# Downloading median_1952.tif
# Downloading median_1953.tif
# Downloading median_1954.tif
# Downloading median_1955.tif
# Downloading median_1956.tif
# Downloading median_1957.tif
# Downloading median_1958.tif
# Downloading median_1959.tif
# Downloading median_1960.tif
# Downloading median_1961.tif
# Downloading median_1962.tif
# Downloading median_1963.tif
# Downloading median_1964.tif
# Downloading median_1965.tif
# Downloading median_1966.tif
# Downloading median_1967.tif
# Downloading median_1968.tif
# Downloading median_1969.tif
# Downloading median_1970.tif
# Downloading median_1971.tif
# Downloading median_1972.tif
# Downloading median_1973.tif
# Downloading median_1974.tif
# Downloading median_1975.tif
# Downloading median_1976.tif
# Downloading median_1977.tif
# Downloading median_1978.tif
# Downloading median_1979.tif
# Downloading median_1980.tif
# Downloading median_1981.tif
# Downloading median_1982.tif
# Downloading median_1983.tif
# Downloading median_1984.tif
# Downloading median_1985.tif
# Downloading median_1986.tif
# Downloading median_1987.tif
# Downloading median_1988.tif
# Downloading median_1989.tif
# Downloading median_1990.tif
# Downloading median_1991.tif
# Downloading median_1992.tif
# Downloading median_1993.tif
# Downloading median_1994.tif
# Downloading median_1995.tif
# Downloading median_1996.tif
# Downloading median_1997.tif
# Downloading median_1998.tif
# Downloading median_1999.tif
# Downloading median_2000.tif
# Downloading median_2001.tif
# Downloading median_2002.tif
# Downloading median_2003.tif
# Downloading median_2004.tif
# Downloading median_2005.tif
# Downloading median_2006.tif
# Downloading median_2007.tif
# Downloading median_2008.tif
# Downloading median_2009.tif
# Downloading median_2010.tif
# Downloading median_2011.tif
# Downloading median_2012.tif
# Downloading median_2013.tif
# Downloading median_2014.tif
# Downloading median_2015.tif
# Downloading median_2016.tif
# Downloading median_2017.tif
# Downloading median_2018.tif
# Downloading median_2019.tif
# Downloading median_2020.tif
# Downloading median_2021.tif
# Downloading median_2022.tif
# Downloading median_2023.tif
# Downloading median_2024.tif
# Downloading median_2025.tif
# Downloading median_2026.tif
# Downloading median_2027.tif
# Downloading median_2028.tif
# Downloading median_2029.tif
# Downloading median_2030.tif
# Downloading median_2031.tif
# Downloading median_2032.tif
# Downloading median_2033.tif
# Downloading median_2034.tif
# Downloading median_2035.tif
# Downloading median_2036.tif
# Downloading median_2037.tif
# Downloading median_2038.tif
# Downloading median_2039.tif
# Downloading median_2040.tif
# Downloading median_2041.tif
# Downloading median_2042.tif
# Downloading median_2043.tif
# Downloading median_2044.tif
# Downloading median_2045.tif
# Downloading median_2046.tif
# Downloading median_2047.tif
# Downloading median_2048.tif
# Downloading median_2049.tif
# Downloading median_2050.tif
# Downloading median_2051.tif
# Downloading median_2052.tif
# Downloading median_2053.tif
# Downloading median_2054.tif
# Downloading median_2055.tif
# Downloading median_2056.tif
# Downloading median_2057.tif
# Downloading median_2058.tif
# Downloading median_2059.tif
# Downloading median_2060.tif
# Downloading median_2061.tif
# Downloading median_2062.tif
# Downloading median_2063.tif
# Downloading median_2064.tif
# Downloading median_2065.tif
# Downloading median_2066.tif
# Downloading median_2067.tif
# Downloading median_2068.tif
# Downloading median_2069.tif
# Downloading median_2070.tif
# Downloading median_2071.tif
# Downloading median_2072.tif
# Downloading median_2073.tif
# Downloading median_2074.tif
# Downloading median_2075.tif
# Downloading median_2076.tif
# Downloading median_2077.tif
# Downloading median_2078.tif
# Downloading median_2079.tif
# Downloading median_2080.tif
# Downloading median_2081.tif
# Downloading median_2082.tif
# Downloading median_2083.tif
# Downloading median_2084.tif
# Downloading median_2085.tif
# Downloading median_2086.tif
# Downloading median_2087.tif
# Downloading median_2088.tif
# Downloading median_2089.tif
# Downloading median_2090.tif
# Downloading median_2091.tif
# Downloading median_2092.tif
# Downloading median_2093.tif
# Downloading median_2094.tif
# Downloading median_2095.tif
# Downloading median_2096.tif
# Downloading median_2097.tif
# Downloading median_2098.tif
# Downloading median_2099.tif
# Downloading median_2100.tif
# Downloading median_2101.tif
# Downloading median_2102.tif
# Downloading median_2103.tif
# Downloading median_2104.tif
# Downloading median_2105.tif
# Downloading median_2106.tif
# Downloading median_2107.tif
# Downloading median_2108.tif
# Downloading median_2109.tif
# Downloading median_2110.tif
# Downloading median_2111.tif
# Downloading median_2112.tif
# Downloading median_2113.tif
# Downloading median_2114.tif
# Downloading median_2115.tif
# Downloading median_2116.tif
# Downloading median_2117.tif
# Downloading median_2118.tif
# Downloading median_2119.tif
# Downloading median_2120.tif
# Downloading median_2121.tif
# Downloading median_2122.tif
# Downloading median_2123.tif
# Downloading median_2124.tif
# Downloading median_2125.tif
# Downloading median_2126.tif
# Downloading median_2127.tif
# Downloading median_2128.tif
# Downloading median_2129.tif
# Downloading median_2130.tif
# Downloading median_2131.tif
# Downloading median_2132.tif
# Downloading median_2133.tif
# Downloading median_2134.tif
# Downloading median_2135.tif
# Downloading median_2136.tif
# Downloading median_2137.tif
# Downloading median_2138.tif
# Downloading median_2139.tif
# Downloading median_2140.tif
# Downloading median_2141.tif
# Downloading median_2142.tif
# Downloading median_2143.tif
# Downloading median_2144.tif
# Downloading median_2145.tif
# Downloading median_2146.tif
# Downloading median_2147.tif
# Downloading median_2148.tif
# Downloading median_2149.tif
# Downloading median_2150.tif
# Downloading median_2151.tif
# Downloading median_2152.tif
# Downloading median_2153.tif
# Downloading median_2154.tif
# Downloading median_2155.tif
# Downloading median_2156.tif
# Downloading median_2157.tif
# Downloading median_2158.tif
# Downloading median_2159.tif
# Downloading median_2160.tif
# Downloading median_2161.tif
# Downloading median_2162.tif
# Downloading median_2163.tif
# Downloading median_2164.tif
# Downloading median_2165.tif
# Downloading median_2166.tif
# Downloading median_2167.tif
# Downloading median_2168.tif
# Downloading median_2169.tif
# Downloading median_2170.tif
# Downloading median_2171.tif
# Downloading median_2172.tif
# Downloading median_2173.tif
# Downloading median_2174.tif
# Downloading median_2175.tif
# Downloading median_2176.tif
# Downloading median_2177.tif
# Downloading median_2178.tif
# Downloading median_2179.tif
# Downloading median_2180.tif
# Downloading median_2181.tif
# Downloading median_2182.tif
# Downloading median_2183.tif
# Downloading median_2184.tif
# Downloading median_2185.tif
# Downloading median_2186.tif
# Downloading median_2187.tif
# Downloading median_2188.tif
# Downloading median_2189.tif
# Downloading median_2190.tif
# Downloading median_2191.tif
# Downloading median_2192.tif
# Downloading median_2193.tif
# Downloading median_2194.tif
# Downloading median_2195.tif
# Downloading median_2196.tif
# Downloading median_2197.tif
# Downloading median_2198.tif
# Downloading median_2199.tif
# Downloading median_2200.tif
# Downloading median_2201.tif
# Downloading median_2202.tif
# Downloading median_2203.tif
# Downloading median_2204.tif
# Downloading median_2205.tif
# Downloading median_2206.tif
# Downloading median_2207.tif
# Downloading median_2208.tif
# Downloading median_2209.tif
# Downloading median_2210.tif
# Downloading median_2211.tif
# Downloading median_2212.tif
# Downloading median_2213.tif
# Downloading median_2214.tif
# Downloading median_2215.tif
# Downloading median_2216.tif
# Downloading median_2217.tif
# Downloading median_2218.tif
# Downloading median_2219.tif
# Downloading median_2220.tif
# Downloading median_2221.tif
# Downloading median_2222.tif
# Downloading median_2223.tif
# Downloading median_2224.tif
# Downloading median_2225.tif
# Downloading median_2226.tif
# Downloading median_2227.tif
# Downloading median_2228.tif
# Downloading median_2229.tif
# Downloading median_2230.tif
# Downloading median_2231.tif
# Downloading median_2232.tif
# Downloading median_2233.tif
# Downloading median_2234.tif
# Downloading median_2235.tif
# Downloading median_2236.tif
# Downloading median_2237.tif
# Downloading median_2238.tif
# Downloading median_2239.tif
# Downloading median_2240.tif
# Downloading median_2241.tif
# Downloading median_2242.tif
# Downloading median_2243.tif
# Downloading median_2244.tif
# Downloading median_2245.tif
# Downloading median_2246.tif
# Downloading median_2247.tif
# Downloading median_2248.tif
# Downloading median_2249.tif
# Downloading median_2250.tif
# Downloading median_2251.tif
# Downloading median_2252.tif
# Downloading median_2253.tif
# Downloading median_2254.tif
# Downloading median_2255.tif
# Downloading median_2256.tif
# Downloading median_2257.tif
# Downloading median_2258.tif
# Downloading median_2259.tif
# Downloading median_2260.tif
# Downloading median_2261.tif
# Downloading median_2262.tif
# Downloading median_2263.tif
# Downloading median_2264.tif
# Downloading median_2265.tif
# Downloading median_2266.tif
# Downloading median_2267.tif
# Downloading median_2268.tif
# Downloading median_2269.tif
# Downloading median_2270.tif
# Downloading median_2271.tif
# Downloading median_2272.tif
# Downloading median_2273.tif
# Downloading median_2274.tif
# Downloading median_2275.tif
# Downloading median_2276.tif
# Downloading median_2277.tif
# Downloading median_2278.tif
# Downloading median_2279.tif
# Downloading median_2280.tif
# Downloading median_2281.tif
# Downloading median_2282.tif
# Downloading median_2283.tif
# Downloading median_2284.tif
# Downloading median_2285.tif
# Downloading median_2286.tif
# Downloading median_2287.tif
# Downloading median_2288.tif
# Downloading median_2289.tif
# Downloading median_2290.tif
# Downloading median_2291.tif
# Downloading median_2292.tif
# Downloading median_2293.tif
# Downloading median_2294.tif
# Downloading median_2295.tif
# Downloading median_2296.tif
# Downloading median_2297.tif
# Downloading median_2298.tif
# Downloading median_2299.tif
# Downloading median_2300.tif
# Downloading median_2301.tif
# Downloading median_2302.tif
# Downloading median_2303.tif
# Downloading median_2304.tif
# Downloading median_2305.tif
# Downloading median_2306.tif
# Downloading median_2307.tif
# Downloading median_2308.tif
# Downloading median_2309.tif
# Downloading median_2310.tif
# Downloading median_2311.tif
# Downloading median_2312.tif
# Downloading median_2313.tif
# Downloading median_2314.tif
# Downloading median_2315.tif
# Downloading median_2316.tif
# Downloading median_2317.tif
# Downloading median_2318.tif
# Downloading median_2319.tif
# Downloading median_2320.tif
# Downloading median_2321.tif
# Downloading median_2322.tif
# Downloading median_2323.tif
# Downloading median_2324.tif
# Downloading median_2325.tif
# Downloading median_2326.tif
# Downloading median_2327.tif
# Downloading median_2328.tif
# Downloading median_2329.tif
# Downloading median_2330.tif
# Downloading median_2331.tif
# Downloading median_2332.tif
# Downloading median_2333.tif
# Downloading median_2334.tif
# Downloading median_2335.tif
# Downloading median_2336.tif
# Downloading median_2337.tif
# Downloading median_2338.tif
# Downloading median_2339.tif
# Downloading median_2340.tif
# Downloading median_2341.tif
# Downloading median_2342.tif
# Downloading median_2343.tif
# Downloading median_2344.tif
# Downloading median_2345.tif
# Downloading median_2346.tif
# Downloading median_2347.tif
# Downloading median_2348.tif
# Downloading median_2349.tif
# Downloading median_2350.tif
# Downloading median_2351.tif
# Downloading median_2352.tif
# Downloading median_2353.tif
# Downloading median_2354.tif
# Downloading median_2355.tif
# Downloading median_2356.tif
# Downloading median_2357.tif
# Downloading median_2358.tif
# Downloading median_2359.tif
# Downloading median_2360.tif
# Downloading median_2361.tif
# Downloading median_2362.tif
# Downloading median_2363.tif
# Downloading median_2364.tif
# Downloading median_2365.tif
# Downloading median_2366.tif
# Downloading median_2367.tif
# Downloading median_2368.tif
# Downloading median_2369.tif
# Downloading median_2370.tif
# Downloading median_2371.tif
# Downloading median_2372.tif
# Downloading median_2373.tif
# Downloading median_2374.tif
# Downloading median_2375.tif
# Downloading median_2376.tif
# Downloading median_2377.tif
# Downloading median_2378.tif
# Downloading median_2379.tif
# Downloading median_2380.tif
# Downloading median_2381.tif
# Downloading median_2382.tif
# Downloading median_2383.tif
# Downloading median_2384.tif
# Downloading median_2385.tif
# Downloading median_2386.tif
# Downloading median_2387.tif
# Downloading median_2388.tif
# Downloading median_2389.tif
# Downloading median_2390.tif
# Downloading median_2391.tif
# Downloading median_2392.tif
# Downloading median_2393.tif
# Downloading median_2394.tif
# Downloading median_2395.tif
# Downloading median_2396.tif
# Downloading median_2397.tif
# Downloading median_2398.tif
# Downloading median_2399.tif
# Downloading median_2400.tif
# Downloading median_2401.tif
# Downloading median_2402.tif
# Downloading median_2403.tif
# Downloading median_2404.tif
# Downloading median_2405.tif
# Downloading median_2406.tif
# Downloading median_2407.tif
# Downloading median_2408.tif
# Downloading median_2409.tif
# Downloading median_2410.tif
# Downloading median_2411.tif
# Downloading median_2412.tif
# Downloading median_2413.tif
# Downloading median_2414.tif
# Downloading median_2415.tif
# Downloading median_2416.tif
# Downloading median_2417.tif
# Downloading median_2418.tif
# Downloading median_2419.tif
# Downloading median_2420.tif
# Downloading median_2421.tif
# Downloading median_2422.tif
# Downloading median_2423.tif
# Downloading median_2424.tif
# Downloading median_2425.tif
# Downloading median_2426.tif
# Downloading median_2427.tif
# Downloading median_2428.tif
# Downloading median_2429.tif
# Downloading median_2430.tif
# Downloading median_2431.tif
# Downloading median_2432.tif
# Downloading median_2433.tif
# Downloading median_2434.tif
# Downloading median_2435.tif
# Downloading median_2436.tif
# Downloading median_2437.tif
# Downloading median_2438.tif
# Downloading median_2439.tif
# Downloading median_2440.tif
# Downloading median_2441.tif
# Downloading median_2442.tif
# Downloading median_2443.tif
# Downloading median_2444.tif
# Downloading median_2445.tif
# Downloading median_2446.tif
# Downloading median_2447.tif
# Downloading median_2448.tif
# Downloading median_2449.tif
# Downloading median_2450.tif
# Downloading median_2451.tif
# Downloading median_2452.tif
# Downloading median_2453.tif
# Downloading median_2454.tif
# Downloading median_2455.tif
# Downloading median_2456.tif
# Downloading median_2457.tif
# Downloading median_2458.tif
# Downloading median_2459.tif
# Downloading median_2460.tif
# Downloading median_2461.tif
# Downloading median_2462.tif
# Downloading median_2463.tif
# Downloading median_2464.tif
# Downloading median_2465.tif
# Downloading median_2466.tif
# Downloading median_2467.tif
# Downloading median_2468.tif
# Downloading median_2469.tif
# Downloading median_2470.tif
# Downloading median_2471.tif
# Downloading median_2472.tif
# Downloading median_2473.tif
# Downloading median_2474.tif
# Downloading median_2475.tif
# Downloading median_2476.tif
# Downloading median_2477.tif
# Downloading median_2478.tif
# Downloading median_2479.tif
# Downloading median_2480.tif
# Downloading median_2481.tif
# Downloading median_2482.tif
# Downloading median_2483.tif
# Downloading median_2484.tif
# Downloading median_2485.tif
# Downloading median_2486.tif
# Downloading median_2487.tif
# Downloading median_2488.tif
# Downloading median_2489.tif
# Downloading median_2490.tif
# Downloading median_2491.tif
# Downloading median_2492.tif
# Downloading median_2493.tif
# Downloading median_2494.tif
# Downloading median_2495.tif
# Downloading median_2496.tif
# Downloading median_2497.tif
# Downloading median_2498.tif
# Downloading median_2499.tif
# Downloading median_2500.tif
# Downloading median_2501.tif
# Downloading median_2502.tif
# Downloading median_2503.tif
# Downloading median_2504.tif
# Downloading median_2505.tif
# Downloading median_2506.tif
# Downloading median_2507.tif
# Downloading median_2508.tif
# Downloading median_2509.tif
# Downloading median_2510.tif
# Downloading median_2511.tif
# Downloading median_2512.tif
# Downloading median_2513.tif
# Downloading median_2514.tif
# Downloading median_2515.tif
# Downloading median_2516.tif
# Downloading median_2517.tif
# Downloading median_2518.tif
# Downloading median_2519.tif
# Downloading median_2520.tif
# Downloading median_2521.tif
# Downloading median_2522.tif
# Downloading median_2523.tif
# Downloading median_2524.tif
# Downloading median_2525.tif
# Downloading median_2526.tif
# Downloading median_2527.tif
# Downloading median_2528.tif
# Downloading median_2529.tif
# Downloading median_2530.tif
# Downloading median_2531.tif
# Downloading median_2532.tif
# Downloading median_2533.tif
# Downloading median_2534.tif
# Downloading median_2535.tif
# Downloading median_2536.tif
# Downloading median_2537.tif
# Downloading median_2538.tif
# Downloading median_2539.tif
# Downloading median_2540.tif
# Downloading median_2541.tif
# Downloading median_2542.tif
# Downloading median_2543.tif
# Downloading median_2544.tif
# Downloading median_2545.tif
# Downloading median_2546.tif
# Downloading median_2547.tif
# Downloading median_2548.tif
# Downloading median_2549.tif
# Downloading median_2550.tif
# Downloading median_2551.tif
# Downloading median_2552.tif
# Downloading median_2553.tif
# Downloading median_2554.tif
# Downloading median_2555.tif
# Downloading median_2556.tif
# Downloading median_2557.tif
# Downloading median_2558.tif
# Downloading median_2559.tif
# Downloading median_2560.tif
# Downloading median_2561.tif
# Downloading median_2562.tif
# Downloading median_2563.tif
# Downloading median_2564.tif
# Downloading median_2565.tif
# Downloading median_2566.tif
# Downloading median_2567.tif
# Downloading median_2568.tif
# Downloading median_2569.tif
# Downloading median_2570.tif
# Downloading median_2571.tif
# Downloading median_2572.tif
# Downloading median_2573.tif
# Downloading median_2574.tif
# Downloading median_2575.tif
# Downloading median_2576.tif
# Downloading median_2577.tif
# Downloading median_2578.tif
# Downloading median_2579.tif
# Downloading median_2580.tif
# Downloading median_2581.tif
# Downloading median_2582.tif
# Downloading median_2583.tif
# Downloading median_2584.tif
# Downloading median_2585.tif
# Downloading median_2586.tif
# Downloading median_2587.tif
# Downloading median_2588.tif
# Downloading median_2589.tif
# Downloading median_2590.tif
# Downloading median_2591.tif
# Downloading median_2592.tif
# Downloading median_2593.tif
# Downloading median_2594.tif
# Downloading median_2595.tif
# Downloading median_2596.tif
# Downloading median_2597.tif
# Downloading median_2598.tif
# Downloading median_2599.tif
# Downloading median_2600.tif
# Downloading median_2601.tif
# Downloading median_2602.tif
# Downloading median_2603.tif
# Downloading median_2604.tif
# Downloading median_2605.tif
# Downloading median_2606.tif
# Downloading median_2607.tif
# Downloading median_2608.tif
# Downloading median_2609.tif
# Downloading median_2610.tif
# Downloading median_2611.tif
# Downloading median_2612.tif
# Downloading median_2613.tif
# Downloading median_2614.tif
# Downloading median_2615.tif
# Downloading median_2616.tif
# Downloading median_2617.tif
# Downloading median_2618.tif
# Downloading median_2619.tif
# Downloading median_2620.tif
# Downloading median_2621.tif
# Downloading median_2622.tif
# Downloading median_2623.tif
# Downloading median_2624.tif
# Downloading median_2625.tif
# Downloading median_2626.tif
# Downloading median_2627.tif
# Downloading median_2628.tif
# Downloading median_2629.tif
# Downloading median_2630.tif
# Downloading median_2631.tif
# Downloading median_2632.tif
# Downloading median_2633.tif
# Downloading median_2634.tif
# Downloading median_2635.tif
# Downloading median_2636.tif
# Downloading median_2637.tif
# Downloading median_2638.tif
# Downloading median_2639.tif
# Downloading median_2640.tif
# Downloading median_2641.tif
# Downloading median_2642.tif
# Downloading median_2643.tif
# Downloading median_2644.tif
# Downloading median_2645.tif
# Downloading median_2646.tif
# Downloading median_2647.tif
# Downloading median_2648.tif
# Downloading median_2649.tif
# Downloading median_2650.tif
# Downloading median_2651.tif
# Downloading median_2652.tif
# Downloading median_2653.tif
# Downloading median_2654.tif
# Downloading median_2655.tif
# Downloading median_2656.tif
# Downloading median_2657.tif
# Downloading median_2658.tif
# Downloading median_2659.tif
# Downloading median_2660.tif
# Downloading median_2661.tif
# Downloading median_2662.tif
# Downloading median_2663.tif
# Downloading median_2664.tif
# Downloading median_2665.tif
# Downloading median_2666.tif
# Downloading median_2667.tif
# Downloading median_2668.tif
# Downloading median_2669.tif
# Downloading median_2670.tif
# Downloading median_2671.tif
# Downloading median_2672.tif
# Downloading median_2673.tif
# Downloading median_2674.tif
# Downloading median_2675.tif
# Downloading median_2676.tif
# Downloading median_2677.tif
# Downloading median_2678.tif
# Downloading median_2679.tif
# Downloading median_2680.tif
# Downloading median_2681.tif
# Downloading median_2682.tif
# Downloading median_2683.tif
# Downloading median_2684.tif
# Downloading median_2685.tif
# Downloading median_2686.tif
# Downloading median_2687.tif
# Downloading median_2688.tif
# Downloading median_2689.tif
# Downloading median_2690.tif
# Downloading median_2691.tif
# Downloading median_2692.tif
# Downloading median_2693.tif
# Downloading median_2694.tif
# Downloading median_2695.tif
# Downloading median_2696.tif
# Downloading median_2697.tif
# Downloading median_2698.tif
# Downloading median_2699.tif
# Downloading median_2700.tif
# Downloading median_2701.tif
# Downloading median_2702.tif
# Downloading median_2703.tif
# Downloading median_2704.tif
# Downloading median_2705.tif
# Downloading median_2706.tif
# Downloading median_2707.tif
# Downloading median_2708.tif
# Downloading median_2709.tif
# Downloading median_2710.tif
# Downloading median_2711.tif
# Downloading median_2712.tif
# Downloading median_2713.tif
# Downloading median_2714.tif
# Downloading median_2715.tif
# Downloading median_2716.tif
# Downloading median_2717.tif
# Downloading median_2718.tif
# Downloading median_2719.tif
# Downloading median_2720.tif
# Downloading median_2721.tif
# Downloading median_2722.tif
# Downloading median_2723.tif
# Downloading median_2724.tif
# Downloading median_2725.tif
# Downloading median_2726.tif
# Downloading median_2727.tif
# Downloading median_2728.tif
# Downloading median_2729.tif
# Downloading median_2730.tif
# Downloading median_2731.tif
# Downloading median_2732.tif
# Downloading median_2733.tif
# Downloading median_2734.tif
# Downloading median_2735.tif
# Downloading median_2736.tif
# Downloading median_2737.tif
# Downloading median_2738.tif
# Downloading median_2739.tif
# Downloading median_2740.tif
# Downloading median_2741.tif
# Downloading median_2742.tif
# Downloading median_2743.tif
# Downloading median_2744.tif
# Downloading median_2745.tif
# Downloading median_2746.tif
# Downloading median_2747.tif
# Downloading median_2748.tif
# Downloading median_2749.tif
# Downloading median_2750.tif
# Downloading median_2751.tif
# Downloading median_2752.tif
# Downloading median_2753.tif
# Downloading median_2754.tif
# Downloading median_2755.tif
# Downloading median_2756.tif
# Downloading median_2757.tif
# Downloading median_2758.tif
# Downloading median_2759.tif
# Downloading median_2760.tif
# Downloading median_2761.tif
# Downloading median_2762.tif
# Downloading median_2763.tif
# Downloading median_2764.tif
# Downloading median_2765.tif
# Downloading median_2766.tif
# Downloading median_2767.tif
# Downloading median_2768.tif
# Downloading median_2769.tif
# Downloading median_2770.tif
# Downloading median_2771.tif
# Downloading median_2772.tif
# Downloading median_2773.tif
# Downloading median_2774.tif
# Downloading median_2775.tif
# Downloading median_2776.tif
# Downloading median_2777.tif
# Downloading median_2778.tif
# Downloading median_2779.tif
# Downloading median_2780.tif
# Downloading median_2781.tif
# Downloading median_2782.tif
# Downloading median_2783.tif
# Downloading median_2784.tif
# Downloading median_2785.tif
# Downloading median_2786.tif
# Downloading median_2787.tif
# Downloading median_2788.tif
# Downloading median_2789.tif
# Downloading median_2790.tif
# Downloading median_2791.tif
# Downloading median_2792.tif
# Downloading median_2793.tif
# Downloading median_2794.tif
# Downloading median_2795.tif
# Downloading median_2796.tif
# Downloading median_2797.tif
# Downloading median_2798.tif
# Downloading median_2799.tif
# Downloading median_2800.tif
# Downloading median_2801.tif
# Downloading median_2802.tif
# Downloading median_2803.tif
# Downloading median_2804.tif
# Downloading median_2805.tif
# Downloading median_2806.tif
# Downloading median_2807.tif
# Downloading median_2808.tif
# Downloading median_2809.tif
# Downloading median_2810.tif
# Downloading median_2811.tif
# Downloading median_2812.tif
# Downloading median_2813.tif
# Downloading median_2814.tif
# Downloading median_2815.tif
# Downloading median_2816.tif
# Downloading median_2817.tif
# Downloading median_2818.tif
# Downloading median_2819.tif
# Downloading median_2820.tif
# Downloading median_2821.tif
# Downloading median_2822.tif
# Downloading median_2823.tif
# Downloading median_2824.tif
# Downloading median_2825.tif
# Downloading median_2826.tif
# Downloading median_2827.tif
# Downloading median_2828.tif
# Downloading median_2829.tif
# Downloading median_2830.tif
# Downloading median_2831.tif
# Downloading median_2832.tif
# Downloading median_2833.tif
# Downloading median_2834.tif
# Downloading median_2835.tif
# Downloading median_2836.tif
# Downloading median_2837.tif
# Downloading median_2838.tif
# Downloading median_2839.tif
# Downloading median_2840.tif
# Downloading median_2841.tif
# Downloading median_2842.tif
# Downloading median_2843.tif
# Downloading median_2844.tif
# Downloading median_2845.tif
# Downloading median_2846.tif
# Downloading median_2847.tif
# Downloading median_2848.tif
# Downloading median_2849.tif
# Downloading median_2850.tif
# Downloading median_2851.tif
# Downloading median_2852.tif
# Downloading median_2853.tif
# Downloading median_2854.tif
# Downloading median_2855.tif
# Downloading median_2856.tif
# Downloading median_2857.tif
# Downloading median_2858.tif
# Downloading median_2859.tif
# Downloading median_2860.tif
# Downloading median_2861.tif
# Downloading median_2862.tif
# Downloading median_2863.tif
# Downloading median_2864.tif
# Downloading median_2865.tif
# Downloading median_2866.tif
# Downloading median_2867.tif
# Downloading median_2868.tif
# Downloading median_2869.tif
# Downloading median_2870.tif
# Downloading median_2871.tif
# Downloading median_2872.tif
# Downloading median_2873.tif
# Downloading median_2874.tif
# Downloading median_2875.tif
# Downloading median_2876.tif
# Downloading median_2877.tif
# Downloading median_2878.tif
# Downloading median_2879.tif
# Downloading median_2880.tif
# Downloading median_2881.tif
# Downloading median_2882.tif
# Downloading median_2883.tif
# Downloading median_2884.tif
# Downloading median_2885.tif
# Downloading median_2886.tif
# Downloading median_2887.tif
# Downloading median_2888.tif
# Downloading median_2889.tif
# Downloading median_2890.tif
# Downloading median_2891.tif
# Downloading median_2892.tif
# Downloading median_2893.tif
# Downloading median_2894.tif
# Downloading median_2895.tif
# Downloading median_2896.tif
# Downloading median_2897.tif
# Downloading median_2898.tif
# Downloading median_2899.tif
# Downloading median_2900.tif
# Downloading median_2901.tif
# Downloading median_2902.tif
# Downloading median_2903.tif
# Downloading median_2904.tif
# Downloading median_2905.tif
# Downloading median_2906.tif
# Downloading median_2907.tif
# Downloading median_2908.tif
# Downloading median_2909.tif
# Downloading median_2910.tif
# Downloading median_2911.tif
# Downloading median_2912.tif
# Downloading median_2913.tif
# Downloading median_2914.tif
# Downloading median_2915.tif
# Downloading median_2916.tif
# Downloading median_2917.tif
# Downloading median_2918.tif
# Downloading median_2919.tif
# Downloading median_2920.tif
# Downloading median_2921.tif
# Downloading median_2922.tif
# Downloading median_2923.tif
# Downloading median_2924.tif
# Downloading median_2925.tif
# Downloading median_2926.tif
# Downloading median_2927.tif
# Downloading median_2928.tif
# Downloading median_2929.tif
# Downloading median_2930.tif
# Downloading median_2931.tif
# Downloading median_2932.tif
# Downloading median_2933.tif
# Downloading median_2934.tif
# Downloading median_2935.tif
# Downloading median_2936.tif
# Downloading median_2937.tif
# Downloading median_2938.tif
# Downloading median_2939.tif
# Downloading median_2940.tif
# Downloading median_2941.tif
# Downloading median_2942.tif
# Downloading median_2943.tif
# Downloading median_2944.tif
# Downloading median_2945.tif
# Downloading median_2946.tif
# Downloading median_2947.tif
# Downloading median_2948.tif
# Downloading median_2949.tif
# Downloading median_2950.tif
# Downloading median_2951.tif
# Downloading median_2952.tif
# Downloading median_2953.tif
# Downloading median_2954.tif
# Downloading median_2955.tif
# Downloading median_2956.tif
# Downloading median_2957.tif
# Downloading median_2958.tif
# Downloading median_2959.tif
# Downloading median_2960.tif
# Downloading median_2961.tif
# Downloading median_2962.tif
# Downloading median_2963.tif
# Downloading median_2964.tif
# Downloading median_2965.tif
# Downloading median_2966.tif
# Downloading median_2967.tif
# Downloading median_2968.tif
# Downloading median_2969.tif
# Downloading median_2970.tif
# Downloading median_2971.tif
# Downloading median_2972.tif
# Downloading median_2973.tif
# Downloading median_2974.tif
# Downloading median_2975.tif
# Downloading median_2976.tif
# Downloading median_2977.tif
# Downloading median_2978.tif
# Downloading median_2979.tif
# Downloading median_2980.tif
# Downloading median_2981.tif
# Downloading median_2982.tif
# Downloading median_2983.tif
# Downloading median_2984.tif
# Downloading median_2985.tif
# Downloading median_2986.tif
# Downloading median_2987.tif
# Downloading median_2988.tif
# Downloading median_2989.tif
# Downloading median_2990.tif
# Downloading median_2991.tif
# Downloading median_2992.tif
# Downloading median_2993.tif
# Downloading median_2994.tif
# Downloading median_2995.tif
# Downloading median_2996.tif
# Downloading median_2997.tif
# Downloading median_2998.tif
# Downloading median_2999.tif
# Downloading median_3000.tif
# Downloading median_3001.tif
# Downloading median_3002.tif
# Downloading median_3003.tif
# Downloading median_3004.tif
# Downloading median_3005.tif
# Downloading median_3006.tif
# Downloading median_3007.tif
# Downloading median_3008.tif
# Downloading median_3009.tif
# Downloading median_3010.tif
# Downloading median_3011.tif
# Downloading median_3012.tif
# Downloading median_3013.tif
# Downloading median_3014.tif
# Downloading median_3015.tif
# Downloading median_3016.tif
# Downloading median_3017.tif
# Downloading median_3018.tif
# Downloading median_3019.tif
# Downloading median_3020.tif
# Downloading median_3021.tif
# Downloading median_3022.tif
# Downloading median_3023.tif
# Downloading median_3024.tif
# Downloading median_3025.tif
# Downloading median_3026.tif
# Downloading median_3027.tif
# Downloading median_3028.tif
# Downloading median_3029.tif
# Downloading median_3030.tif
# Downloading median_3031.tif
# Downloading median_3032.tif
# Downloading median_3033.tif
# Downloading median_3034.tif
# Downloading median_3035.tif
# Downloading median_3036.tif
# Downloading median_3037.tif
# Downloading median_3038.tif
# Downloading median_3039.tif
# Downloading median_3040.tif
# Downloading median_3041.tif
# Downloading median_3042.tif
# Downloading median_3043.tif
# Downloading median_3044.tif
# Downloading median_3045.tif
# Downloading median_3046.tif
# Downloading median_3047.tif
# Downloading median_3048.tif
# Downloading median_3049.tif
# Downloading median_3050.tif
# Downloading median_3051.tif
# Downloading median_3052.tif
# Downloading median_3053.tif
# Downloading median_3054.tif
# Downloading median_3055.tif
# Downloading median_3056.tif
# Downloading median_3057.tif
# Downloading median_3058.tif
# Downloading median_3059.tif
# Downloading median_3060.tif
# Downloading median_3061.tif
# Downloading median_3062.tif
# Downloading median_3063.tif
# Downloading median_3064.tif
# Downloading median_3065.tif
# Downloading median_3066.tif
# Downloading median_3067.tif
# Downloading median_3068.tif
# Downloading median_3069.tif
# Downloading median_3070.tif
# Downloading median_3071.tif
# Downloading median_3072.tif
# Downloading median_3073.tif
# Downloading median_3074.tif
# Downloading median_3075.tif
# Downloading median_3076.tif
# Downloading median_3077.tif
# Downloading median_3078.tif
# Downloading median_3079.tif
# Downloading median_3080.tif
# Downloading median_3081.tif
# Downloading median_3082.tif
# Downloading median_3083.tif
# Downloading median_3084.tif
# Downloading median_3085.tif
# Downloading median_3086.tif
# Downloading median_3087.tif
# Downloading median_3088.tif
# Downloading median_3089.tif
# Downloading median_3090.tif
# Downloading median_3091.tif
# Downloading median_3092.tif
# Downloading median_3093.tif
# Downloading median_3094.tif
# Downloading median_3095.tif
# Downloading median_3096.tif
# Downloading median_3097.tif
# Downloading median_3098.tif
# Downloading median_3099.tif
# Downloading median_3100.tif
# Downloading median_3101.tif
# Downloading median_3102.tif
# Downloading median_3103.tif
# Downloading median_3104.tif
# Downloading median_3105.tif
# Downloading median_3106.tif
# Downloading median_3107.tif
# Downloading median_3108.tif
# Downloading median_3109.tif
# Downloading median_3110.tif
# Downloading median_3111.tif
# Downloading median_3112.tif
# Downloading median_3113.tif
# Downloading median_3114.tif
# Downloading median_3115.tif
# Downloading median_3116.tif
# Downloading median_3117.tif
# Downloading median_3118.tif
# Downloading median_3119.tif
# Downloading median_3120.tif
# Downloading median_3121.tif
# Downloading median_3122.tif
# Downloading median_3123.tif
# Downloading median_3124.tif
# Downloading median_3125.tif
# Downloading median_3126.tif
# Downloading median_3127.tif
# Downloading median_3128.tif
# Downloading median_3129.tif
# Downloading median_3130.tif
# Downloading median_3131.tif
# Downloading median_3132.tif
# Downloading median_3133.tif
# Downloading median_3134.tif
# Downloading median_3135.tif
# Downloading median_3136.tif
# Downloading median_3137.tif
# Downloading median_3138.tif
# Downloading median_3139.tif
# Downloading median_3140.tif
# Downloading median_3141.tif
# Downloading median_3142.tif
# Downloading median_3143.tif
# Downloading median_3144.tif
# Downloading median_3145.tif
# Downloading median_3146.tif
# Downloading median_3147.tif
# Downloading median_3148.tif
# Downloading median_3149.tif
# Downloading median_3150.tif
# Downloading median_3151.tif
# Downloading median_3152.tif
# Downloading median_3153.tif
# Downloading median_3154.tif
# Downloading median_3155.tif
# Downloading median_3156.tif
# Downloading median_3157.tif
# Downloading median_3158.tif
# Downloading median_3159.tif
# Downloading median_3160.tif
# Downloading median_3161.tif
# Downloading median_3162.tif
# Downloading median_3163.tif
# Downloading median_3164.tif
# Downloading median_3165.tif
# Downloading median_3166.tif
# Downloading median_3167.tif
# Downloading median_3168.tif
# Downloading median_3169.tif
# Downloading median_3170.tif
# Downloading median_3171.tif
# Downloading median_3172.tif
# Downloading median_3173.tif
# Downloading median_3174.tif
# Downloading median_3175.tif
# Downloading median_3176.tif
# Downloading median_3177.tif
# Downloading median_3178.tif
# Downloading median_3179.tif
# Downloading median_3180.tif
# Downloading median_3181.tif
# Downloading median_3182.tif
# Downloading median_3183.tif
# Downloading median_3184.tif
# Downloading median_3185.tif
# Downloading median_3186.tif
# Downloading median_3187.tif
# Downloading median_3188.tif
# Downloading median_3189.tif
# Downloading median_3190.tif
# Downloading median_3191.tif
# Downloading median_3192.tif
# Downloading median_3193.tif
# Downloading median_3194.tif
# Downloading median_3195.tif
# Downloading median_3196.tif
# Downloading median_3197.tif
# Downloading median_3198.tif
# Downloading median_3199.tif
# Downloading median_3200.tif
# Downloading median_3201.tif
# Downloading median_3202.tif
# Downloading median_3203.tif
# Downloading median_3204.tif
# Downloading median_3205.tif
# Downloading median_3206.tif
# Downloading median_3207.tif
# Downloading median_3208.tif
# Downloading median_3209.tif
# Downloading median_3210.tif
# Downloading median_3211.tif
# Downloading median_3212.tif
# Downloading median_3213.tif
# Downloading median_3214.tif
# Downloading median_3215.tif
# Downloading median_3216.tif
# Downloading median_3217.tif
# Downloading median_3218.tif
# Downloading median_3219.tif
# Downloading median_3220.tif
# Downloading median_3221.tif
# Downloading median_3222.tif
# Downloading median_3223.tif
# Downloading median_3224.tif
# Downloading median_3225.tif
# Downloading median_3226.tif
# Downloading median_3227.tif
# Downloading median_3228.tif
# Downloading median_3229.tif
# Downloading median_3230.tif
# Downloading median_3231.tif
# Downloading median_3232.tif
# Downloading median_3233.tif
# Downloading median_3234.tif
# Downloading median_3235.tif
# Downloading median_3236.tif
# Downloading median_3237.tif
# Downloading median_3238.tif
# Downloading median_3239.tif
# Downloading median_3240.tif
# Downloading median_3241.tif
# Downloading median_3242.tif
# Downloading median_3243.tif
# Downloading median_3244.tif
# Downloading median_3245.tif
# Downloading median_3246.tif
# Downloading median_3247.tif
# Downloading median_3248.tif
# Downloading median_3249.tif
# Downloading median_3250.tif
# Downloading median_3251.tif
# Downloading median_3252.tif
# Downloading median_3253.tif
# Downloading median_3254.tif
# Downloading median_3255.tif
# Downloading median_3256.tif
# Downloading median_3257.tif
# Downloading median_3258.tif
# Downloading median_3259.tif
# Downloading median_3260.tif
# Downloading median_3261.tif
# Downloading median_3262.tif
# Downloading median_3263.tif
# Downloading median_3264.tif
# Downloading median_3265.tif
# Downloading median_3266.tif
# Downloading median_3267.tif
# Downloading median_3268.tif
# Downloading median_3269.tif
# Downloading median_3270.tif
# Downloading median_3271.tif
# Downloading median_3272.tif
# Downloading median_3273.tif
# Downloading median_3274.tif
# Downloading median_3275.tif
# Downloading median_3276.tif
# Downloading median_3277.tif
# Downloading median_3278.tif
# Downloading median_3279.tif
# Downloading median_3280.tif
# Downloading median_3281.tif
# Downloading median_3282.tif
# Downloading median_3283.tif
# Downloading median_3284.tif
# Downloading median_3285.tif
# Downloading median_3286.tif
# Downloading median_3287.tif
# Downloading median_3288.tif
# Downloading median_3289.tif
# Downloading median_3290.tif
# Downloading median_3291.tif
# Downloading median_3292.tif
# Downloading median_3293.tif
# Downloading median_3294.tif
# Downloading median_3295.tif
# Downloading median_3296.tif
# Downloading median_3297.tif
# Downloading median_3298.tif
# Downloading median_3299.tif
# Downloading median_3300.tif
# Downloading median_3301.tif
# Downloading median_3302.tif
# Downloading median_3303.tif
# Downloading median_3304.tif
# Downloading median_3305.tif
# Downloading median_3306.tif
# Downloading median_3307.tif
# Downloading median_3308.tif
# Downloading median_3309.tif
# Downloading median_3310.tif
# Downloading median_3311.tif
# Downloading median_3312.tif
# Downloading median_3313.tif
# Downloading median_3314.tif
# Downloading median_3315.tif
# Downloading median_3316.tif
# Downloading median_3317.tif
# Downloading median_3318.tif
# Downloading median_3319.tif
# Downloading median_3320.tif
# Downloading median_3321.tif
# Downloading median_3322.tif
# Downloading median_3323.tif
# Downloading median_3324.tif
# Downloading median_3325.tif
# Downloading median_3326.tif
# Downloading median_3327.tif
# Downloading median_3328.tif
# Downloading median_3329.tif
# Downloading median_3330.tif
# Downloading median_3331.tif
# Downloading median_3332.tif
# Downloading median_3333.tif
# Downloading median_3334.tif
# Downloading median_3335.tif
# Downloading median_3336.tif
# Downloading median_3337.tif
# Downloading median_3338.tif
# Downloading median_3339.tif
# Downloading median_3340.tif
# Downloading median_3341.tif
# Downloading median_3342.tif
# Downloading median_3343.tif
# Downloading median_3344.tif
# Downloading median_3345.tif
# Downloading median_3346.tif
# Downloading median_3347.tif
# Downloading median_3348.tif
# Downloading median_3349.tif

# %%
't'

# %%
# Use reduceRegion to calculate the minimum and maximum values in the specified ROI
stats = raw_bands.select('NBR_p85').reduceRegion(
    reducer=ee.Reducer.minMax(),
    geometry=final_buffer,
    scale=30,  # Set the scale according to the resolution of the image
    maxPixels=1e9  # Adjust maxPixels as needed
)

# Get the minimum and maximum values
min_value = stats.getNumber('NBR_p85_min')
max_value = stats.getNumber('NBR_p85_max')

# Print the results
print('Minimum Value:', min_value.getInfo())
print('Maximum Value:', max_value.getInfo())
