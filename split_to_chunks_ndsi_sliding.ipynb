# %% [markdown]
# This script will read in the tif files and split into chunks of 128x128 for training the model.  Note I will ignore all chunks where there is no data for dNBR as we wouldn't want to train on this.
# The in path and outpath have to be where the files from the tif files were sent to from the google cloud storage bucket after downloading from earth engine.

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import os
import numpy as np
import xarray as xr
import rioxarray
import glob
import random
import geopandas as gpd
from sklearn.utils import shuffle
from MightyMosaic import MightyMosaic

# %% [markdown]
# Right now the files are called final_i.tif, make median_i.tif

# %%
import os
import re

# Define the input path
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding'

# List all files in the directory
files = os.listdir(in_path)

# Loop through the files
for file_name in files:
    if 'final' in file_name:
        # Extract the number i using regex
        match = re.search(r'\d+', file_name)
        if match:
            number = match.group(0)
            # Create the new file name
            new_name = f'median_{number}.tif'
            # Get the full paths
            old_file = os.path.join(in_path, file_name)
            new_file = os.path.join(in_path, new_name)
            # Rename the file
            os.rename(old_file, new_file)
            print(f'Renamed: {old_file} -> {new_file}')

# %% [markdown]
# First take the input tif files and chunk them to sizes of 128x128 for the neural network.

# %%
"""arguments are path to .tif files to be chunked, out_path to save files, chunk size, and if desired a threshold"""       

#why din't 15524 save?

#check if all 0
def is_matrix_all_zeros(matrix):
    # Convert the matrix to a NumPy array
    np_matrix = np.array(matrix)

    # Check if all elements in the array are zeros
    return np.all(np_matrix == 0)

#in_path to tif files
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/Russia/nbac_monthly_ndsi_sliding'

#out_path which will be manipulated based on parameters below
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/Russia/nbac_monthly_ndsi_sliding'


#right now everything is set to use 0 dnbr threshold
size = 128
threshold = True

if threshold == True:

    out_path = out_path + '_subs_0_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

if threshold == False:

    out_path = out_path + '_subs_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

files = os.listdir(in_path)

# files = ['median_6169.tif']

#loop through files
for f in files:

    if f.endswith('.tif'):
        
         
        #in file
        try:
        
            #file name
            f2 = f.replace('median_', '')

            #ID of file
            f_id = int(f2.replace('.tif', ''))
        
     

            #read in file
            in_mat = rioxarray.open_rasterio(os.path.join(in_path, f))

            
            #now turn in mat to numpy, and in mtbs to numpy
            in_mat = in_mat.to_numpy().astype(float)


            #convert to band last
            in_mat = np.moveaxis(in_mat, 0, 2) 
            
               
            #get dnbr
            t = in_mat[:, :, 0]
            
             #check if all 0
            result = is_matrix_all_zeros(t)
            
            #if it is not all 0s keep data
            if result == False:

                #mosaic
                mosaic = MightyMosaic.from_array(in_mat, (size,size), overlap_factor=1) 

                #take off last dimensions of mosaic which give edge effects as they are filled with no data
                mosaic = mosaic[:-1, :-1, :, :, :]


                #first two dimensions are number of chunks, 3 and 4 are size (256, 266) and last is nbands
                for i in range(mosaic.shape[0]):

                    for j in range(mosaic.shape[1]):

                        fname = os.path.join(str(i) + '_' +  str(j)+ '_' + f2.replace('.tif', '.npy'))
                        out_name = os.path.join(out_path, fname)

                        if os.path.exists(out_name) == False:

                            in_mat3 = mosaic[i, j, :, :, :-1]

                            target = mosaic[i, j, :, :, 3]

                            #turn nan to -999
                            in_mat[np.isnan(in_mat)] = -999

                            target = target.astype('int')

                            target[target <0 ] = 0
                            target[target >1 ] = 0

                            #
                            target[~np.isin(target, [0,1])] = 0

                            #turn nan to 0
                            target[np.isnan(target)] = 0

                            #if the target is all 0 don't train on it
                            # if np.all(target == 0) == False:

                            #now get dnbr which is the 6th band
                            dnbr = in_mat3[:, :, 0]
                            
                            result1 = is_matrix_all_zeros(dnbr)

                            if result1 == False:

                                #if threshold apply dnbr threshold
                                target[dnbr < 0] = 0

                                e = np.dstack([in_mat3, target])

                                np.save(out_name, e)

                                print(f)

        except:
            pass

# %% [markdown]
# Tryy to mnake faster with dask

# %%
import os
import numpy as np
import rioxarray
import dask
from dask.diagnostics import ProgressBar
from MightyMosaic import MightyMosaic

# Check if all elements in a matrix are zero
def is_matrix_all_zeros(matrix):
    np_matrix = np.array(matrix)
    return np.all(np_matrix == 0)

# Input and output paths
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding'
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding'
size = 128
threshold = True

# Set output path based on threshold
if threshold:
    out_path += f'_subs_0_{size}'
else:
    out_path += f'_subs_{size}'

if not os.path.isdir(out_path):
    os.makedirs(out_path)

files = [f for f in os.listdir(in_path) if f.endswith('.tif')]

# Define the function to process a single file
def process_file(f):
    try:
        f2 = f.replace('median_', '')
        f_id = int(f2.replace('.tif', ''))
        in_mat = rioxarray.open_rasterio(os.path.join(in_path, f)).to_numpy().astype(float)
        in_mat = np.moveaxis(in_mat, 0, 2) 
        t = in_mat[:, :, 0]
        if not is_matrix_all_zeros(t):
            mosaic = MightyMosaic.from_array(in_mat, (size, size), overlap_factor=1) 
            mosaic = mosaic[:-1, :-1, :, :, :]
            for i in range(mosaic.shape[0]):
                for j in range(mosaic.shape[1]):
                    fname = os.path.join(str(i) + '_' +  str(j) + '_' + f2.replace('.tif', '.npy'))
                    out_name = os.path.join(out_path, fname)
                    if not os.path.exists(out_name):
                        in_mat3 = mosaic[i, j, :, :, :-1]
                        target = mosaic[i, j, :, :, 3]
                        in_mat3[np.isnan(in_mat3)] = -999
                        target = target.astype('int')
                        target[target < 0] = 0
                        target[target > 1] = 0
                        target[~np.isin(target, [0, 1])] = 0
                        target[np.isnan(target)] = 0
                        dnbr = in_mat3[:, :, 0]
                        if not is_matrix_all_zeros(dnbr):
                            if threshold:
                                target[dnbr < 0] = 0
                            e = np.dstack([in_mat3, target])
                            np.save(out_name, e)
                            print(f"Processed {f}")
    except Exception as e:
        print(f"Error processing {f}: {e}")

# Parallel execution using Dask
tasks = [dask.delayed(process_file)(f) for f in files]

with ProgressBar():
    dask.compute(*tasks)
# Out:
# [                                        ] | 0% Completed | 456.56 msProcessed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4004.tif
# [                                        ] | 0% Completed | 582.10 msProcessed median_4004.tif
# Processed median_4004.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# [                                        ] | 0% Completed | 683.56 msProcessed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# Processed median_4790.tif
# Processed median_4004.tif
# [                                        ] | 0% Completed | 792.89 msProcessed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# [                                        ] | 0% Completed | 894.04 msProcessed median_4790.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_63.tif
# Processed median_4790.tif
# Processed median_63.tif
# Processed median_4790.tif
# Processed median_4790.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 995.35 msProcessed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_4790.tif
# Processed median_63.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.10 sProcessed median_63.tif
# Processed median_63.tif
# Error processing median_1510.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.20 s
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.36 sProcessed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.46 sProcessed median_7886.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# [                                        ] | 0% Completed | 1.56 sProcessed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_7886.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.66 sProcessed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 1.76 sProcessed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 1.86 sProcessed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 1.97 sProcessed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 2.07 sProcessed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_63.tif
# [                                        ] | 0% Completed | 2.17 sProcessed median_17435.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_63.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 2.27 sProcessed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# [                                        ] | 0% Completed | 2.38 sProcessed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_19095.tif
# [                                        ] | 0% Completed | 2.48 sProcessed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_17435.tif
# Processed median_19095.tif
# Processed median_19095.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 2.59 sProcessed median_17435.tif
# Processed median_17435.tif
# Processed median_17435.tif
# [                                        ] | 0% Completed | 2.70 sProcessed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# [                                        ] | 0% Completed | 2.80 sProcessed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# [                                        ] | 0% Completed | 2.91 sProcessed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_17435.tif
# Processed median_5281.tif
# Processed median_5281.tif
# [                                        ] | 0% Completed | 3.01 sProcessed median_5281.tif
# Processed median_5281.tif
# Processed median_5281.tif
# Processed median_5281.tif
# Processed median_5281.tif
# Processed median_5281.tif
# [                                        ] | 0% Completed | 3.21 sProcessed median_17143.tif
# [                                        ] | 0% Completed | 3.32 sProcessed median_17143.tif
# Processed median_17143.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 3.42 sProcessed median_17143.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_17143.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 3.52 sProcessed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 3.63 sProcessed median_17143.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# [                                        ] | 0% Completed | 3.73 sProcessed median_17143.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# Processed median_17143.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 3.83 sProcessed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# [                                        ] | 0% Completed | 3.94 sProcessed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.04 sProcessed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# [                                        ] | 0% Completed | 4.14 sProcessed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# Processed median_12167.tif
# Processed median_4061.tif
# [                                        ] | 0% Completed | 4.24 sProcessed median_12167.tif
# Processed median_6808.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_6808.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.35 sProcessed median_6808.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_6808.tif
# Processed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.46 sProcessed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.59 sProcessed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.69 sProcessed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.79 sProcessed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 4.90 sProcessed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_2837.tifProcessed median_12167.tif
#
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.00 sProcessed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.10 sProcessed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.20 sProcessed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.30 sProcessed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.40 sProcessed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.51 sProcessed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# [                                        ] | 0% Completed | 5.61 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 5.71 sProcessed median_12167.tif
# Processed median_2837.tif
# Processed median_12167.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 5.81 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 5.92 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# [                                        ] | 0% Completed | 6.02 sProcessed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# [                                        ] | 0% Completed | 6.12 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# [                                        ] | 0% Completed | 6.22 sProcessed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# [                                        ] | 0% Completed | 6.32 sProcessed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# [                                        ] | 0% Completed | 6.42 sProcessed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 6.52 sProcessed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 6.63 sProcessed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_12407.tif
# Processed median_2837.tif
# Processed median_12407.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 6.74 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 6.84 sProcessed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_16904.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# [                                        ] | 0% Completed | 6.94 sProcessed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# [                                        ] | 0% Completed | 7.04 sProcessed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.14 sProcessed median_16904.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# [                                        ] | 0% Completed | 7.24 sProcessed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# Processed median_2837.tif
# Processed median_16904.tif
# [                                        ] | 0% Completed | 7.35 sProcessed median_2837.tif
# Processed median_11379.tif
# Processed median_11379.tif
# Processed median_11379.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.46 sProcessed median_11379.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# Processed median_11379.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.57 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.67 sProcessed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.77 sProcessed median_523.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_523.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.89 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 7.99 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 8.11 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 8.31 sProcessed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_2837.tif
# [                                        ] | 0% Completed | 8.42 sProcessed median_18516.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 8.53 sProcessed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_2837.tif
# Processed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 8.63 sProcessed median_18516.tif
# Processed median_2837.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 8.73 sProcessed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_8155.tif
# [                                        ] | 0% Completed | 8.83 sProcessed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 8.93 sProcessed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_8155.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.04 sProcessed median_8155.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_8155.tif
# Processed median_18516.tif
# Processed median_8155.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.15 sProcessed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.25 sProcessed median_11303.tif
# Processed median_18516.tifProcessed median_11303.tif
#
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_11303.tif
# [                                        ] | 0% Completed | 9.35 sProcessed median_11303.tif
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# Processed median_11303.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.46 sProcessed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.56 sProcessed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 9.66 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.77 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 9.87 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 9.97 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.08 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 10.18 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.30 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.40 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.50 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 10.64 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.75 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 10.85 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 10.95 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 11.05 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 11.15 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 11.25 sProcessed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 11.36 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# [                                        ] | 0% Completed | 11.46 sProcessed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 11.56 sProcessed median_18516.tif
# Processed median_2955.tif
# Processed median_18516.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 11.67 sProcessed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# Processed median_2955.tif
# [                                        ] | 0% Completed | 16.22 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.32 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.42 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.53 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.63 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.74 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.84 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 16.94 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.04 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.14 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.24 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.35 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.45 sProcessed median_13448.tif
# Processed median_13448.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.56 sProcessed median_13448.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 17.66 sProcessed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 17.76 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 17.87 sProcessed median_16151.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 17.98 sProcessed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 18.08 sProcessed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 18.19 sProcessed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 18.29 sProcessed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# Processed median_16151.tif
# Processed median_13448.tif
# [                                        ] | 0% Completed | 18.39 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_5266.tif
# [                                        ] | 0% Completed | 18.50 sProcessed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 18.60 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_5266.tif
# [                                        ] | 0% Completed | 18.71 sProcessed median_16151.tif
# Processed median_5266.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 18.81 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 18.91 sProcessed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.02 sProcessed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_5266.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.12 sProcessed median_8905.tifProcessed median_16151.tif
#
# Processed median_8905.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_8905.tif
# [                                        ] | 0% Completed | 19.22 sProcessed median_16151.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_8905.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.32 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.43 sProcessed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.53 sProcessed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# [                                        ] | 0% Completed | 19.63 sProcessed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# [                                        ] | 0% Completed | 19.75 sProcessed median_16151.tif
# Processed median_11526.tif
# Processed median_11526.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# [                                        ] | 0% Completed | 19.85 sProcessed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# [                                        ] | 0% Completed | 19.95 sProcessed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# [                                        ] | 0% Completed | 20.06 sProcessed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# [                                        ] | 0% Completed | 20.18 sProcessed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# Processed median_11526.tif
# Processed median_16151.tif
# Processed median_11526.tif
# ...
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# [##                                      ] | 5% Completed | 275.98 sProcessed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_8218.tif
# Processed median_716.tif
# Processed median_716.tif
# [##                                      ] | 5% Completed | 276.08 sProcessed median_716.tif
# Processed median_716.tif
# Processed median_716.tif
# Processed median_6307.tif
# Processed median_6307.tif
# Processed median_6307.tif
# [##                                      ] | 5% Completed | 276.19 sProcessed median_6307.tif
# Processed median_6307.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_6307.tif
# Processed median_11983.tif
# [##                                      ] | 5% Completed | 276.29 sProcessed median_6307.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_11983.tif
# Processed median_6307.tif
# [##                                      ] | 5% Completed | 276.39 sProcessed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# [##                                      ] | 5% Completed | 276.49 sProcessed median_6307.tif
# Processed median_11983.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# Processed median_11983.tif
# Processed median_6307.tif
# [##                                      ] | 5% Completed | 276.59 sProcessed median_6307.tif
# Processed median_17079.tif
# Processed median_17079.tif
# Processed median_17079.tif
# Processed median_17079.tif
# [##                                      ] | 5% Completed | 276.70 sProcessed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# [##                                      ] | 5% Completed | 276.80 sProcessed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# [##                                      ] | 5% Completed | 276.90 sProcessed median_17079.tif
# Processed median_5854.tif
# Processed median_17079.tif
# Processed median_5854.tif
# [##                                      ] | 5% Completed | 277.00 sProcessed median_5854.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# [##                                      ] | 5% Completed | 277.10 sProcessed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# Processed median_8933.tif
# Processed median_5854.tif
# [##                                      ] | 5% Completed | 277.21 sProcessed median_8933.tif
# Processed median_8933.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# [##                                      ] | 5% Completed | 277.32 sProcessed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# [##                                      ] | 5% Completed | 277.42 sProcessed median_18776.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_8933.tif
# [##                                      ] | 5% Completed | 277.53 sProcessed median_8933.tif
# Processed median_8933.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# [##                                      ] | 5% Completed | 277.63 sProcessed median_18776.tif
# Processed median_8933.tif
# Processed median_8933.tif
# Processed median_18776.tif
# Processed median_8933.tif
# Processed median_8933.tif
# [##                                      ] | 5% Completed | 277.73 sProcessed median_8933.tif
# Processed median_16524.tif
# Processed median_8933.tif
# Processed median_16524.tif
# Processed median_16524.tif
# [##                                      ] | 5% Completed | 277.83 sProcessed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_16524.tif
# [##                                      ] | 5% Completed | 277.93 sProcessed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# [##                                      ] | 5% Completed | 278.03 sProcessed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_10177.tif
# [##                                      ] | 5% Completed | 278.13 sProcessed median_10177.tif
# Processed median_16524.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_16524.tif
# Processed median_10177.tif
# Processed median_10177.tif
# Processed median_10177.tif
# [##                                      ] | 5% Completed | 278.24 sProcessed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# [##                                      ] | 5% Completed | 278.34 sProcessed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# [##                                      ] | 5% Completed | 278.44 sProcessed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10177.tif
# Processed median_10105.tif
# Processed median_10105.tif
# [##                                      ] | 5% Completed | 278.54 sProcessed median_10105.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_10105.tif
# Processed median_8818.tif
# Processed median_10105.tif
# Processed median_8818.tif
# [##                                      ] | 5% Completed | 278.64 sProcessed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# [##                                      ] | 5% Completed | 278.74 sProcessed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_8818.tif
# [##                                      ] | 5% Completed | 278.84 sProcessed median_8818.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# [##                                      ] | 5% Completed | 278.95 sProcessed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# Processed median_16150.tif
# Processed median_8818.tif
# [##                                      ] | 5% Completed | 279.06 sProcessed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.16 sProcessed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# [##                                      ] | 5% Completed | 279.27 sProcessed median_14503.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# Processed median_14503.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.37 sProcessed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.47 sProcessed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.57 sProcessed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 279.67 sProcessed median_13872.tifProcessed median_16150.tif
#
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.77 sProcessed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 279.87 sProcessed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_16150.tif
# [##                                      ] | 5% Completed | 279.98 sProcessed median_13872.tif
# Processed median_16150.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.08 sProcessed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.19 sProcessed median_6955.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_6955.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.29 sProcessed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.39 sProcessed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.50 sProcessed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_13872.tif
# [##                                      ] | 5% Completed | 280.60 sProcessed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 280.70 sProcessed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 280.80 sProcessed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 280.91 sProcessed median_2485.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 281.01 sProcessed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 281.12 sProcessed median_13872.tif
# Processed median_2485.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# [##                                      ] | 5% Completed | 281.22 sProcessed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif
# Processed median_2485.tif
# Processed median_13872.tif

# %%
't'
# Out:
# 't'

# %% [markdown]
# Now take those files and save a csv with file names for the 80/10/10 training, validation, testing parts

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

#list of files
# file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_1985_sent_harm_subs_128')
file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding_subs_0_128')


#shuffle file_names
file_names = shuffle(file_names, random_state = 555)


print(len(file_names))

random.seed(555)
# #get train at 80%

train_files = random.sample(file_names, k=round(len(file_names) * 0.8))

#files at 10%
val_files = list(set(file_names) - set(train_files))
val_files = random.sample(val_files, k=round(len(file_names) * 0.1))

#combine traini and val
temp = train_files + val_files
#get test files at 10%
test_files = list(set(file_names) - set(temp))


#convert the lists to pandas dataframes
train = pd.DataFrame({'Files': train_files})
val = pd.DataFrame({'Files': val_files})
test = pd.DataFrame({'Files': test_files})

print(train.shape)
print(val.shape)
print(test.shape)

train.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding_training_files.csv')
val.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding_validation_files.csv')
test.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/anna_monthly_ndsi_sliding_testing_files.csv')
# Out:
# 385096
# (308077, 1)
# (38510, 1)
# (38509, 1)
