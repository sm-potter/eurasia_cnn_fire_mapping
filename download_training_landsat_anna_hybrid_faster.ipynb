# %%
import os
import ee
import pandas as pd
from google.cloud import storage

# Authenticate GEE
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json"

service_account = 'gee-serdp-upload@appspot.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json")
ee.Initialize(credentials)

# Load collections
sent_2A = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
s2Clouds = ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY')
lfdb = ee.FeatureCollection("users/spotter/fire_cnn/ann_w_id")

# Constants
MAX_CLOUD_PROBABILITY = 50
bucket_name = 'smp-scratch'
folder_name = 'monthly_intervals_ndsi_fast'

# Cloud masking for Sentinel-2
def sent_maskcloud(image):
    image = image.select(['B2', 'B3', 'B4', 'B8', 'B11', 'B12'], 
                         ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).toShort()
    clouds = ee.Image(image.get('cloud_mask')).select('probability')
    isNotCloud = clouds.lt(MAX_CLOUD_PROBABILITY)
    return image.updateMask(isNotCloud).reproject(crs=image.projection().crs(), scale=30)

# Apply cloud masking
s2SrWithCloudMask = ee.Join.saveFirst('cloud_mask').apply(
    primary=sent_2A, 
    secondary=s2Clouds, 
    condition=ee.Filter.equals(leftField='system:index', rightField='system:index')
)
sent_2A = ee.ImageCollection(s2SrWithCloudMask).map(sent_maskcloud)

# Helper functions
def mask(image):
    qa = image.select('QA_PIXEL')                                       
    return image.updateMask(qa.bitwiseAnd(8).eq(0).And(qa.bitwiseAnd(10).eq(0)).And(qa.bitwiseAnd(32).eq(0)))

def land_scale(image):
    return image.multiply(0.0000275).add(-0.2)

def sent_scale(image):
    return image.multiply(0.0001)

def mask_ndsi(image):
    ndsi = image.normalizedDifference(['SR_B2', 'SR_B5'])
    return image.updateMask(ndsi.lte(-0.2))

def to_float(image):
    return image.select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).toFloat()

def landsat_correct(sat, bands):
    coeffs = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/raw_files/boreal_xcal_regression_coefficients.csv").fillna(0)
    l5 = coeffs[(coeffs['satellite'] == sat) & (coeffs['band.or.si'].isin(bands))]
    l5['band.or.si'] = pd.Categorical(l5['band.or.si'], categories=bands)
    l5 = l5.sort_values('band.or.si')
    return l5['B0'].values.tolist(), l5['B1'].values.tolist(), l5['B2'].values.tolist(), l5['B3'].values.tolist()

l8_corr = landsat_correct('LANDSAT_8', ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])
l5_corr = landsat_correct('LANDSAT_5', ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])

def apply_corrections(ic, pre_start, pre_end, post_start, post_end, geometry):
    pre_ic = ic.filterDate(pre_start, pre_end).filterBounds(geometry).map(mask).map(land_scale).select(
        ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float).map(mask_ndsi)
    post_ic = ic.filterDate(post_start, post_end).filterBounds(geometry).map(mask).map(land_scale).select(
        ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float).map(mask_ndsi)
    
    condition = pre_ic.size().gt(0).And(post_ic.size().gt(0))
    
    def calculate_difference(pre_ic, post_ic):
        pre_img = pre_ic.median().clip(geometry)
        post_img = post_ic.median().clip(geometry)
        return pre_img.subtract(post_img).multiply(1000).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7'])
    
    return ee.Algorithms.If(condition, calculate_difference(pre_ic, post_ic), ee.Image().select())

def get_pre_post(pre_start, pre_end, post_start, post_end, geometry):
    lt5 = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2')
    le7 = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2')
    lc8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
    sent = sent_2A
    
    lt5_img = apply_corrections(lt5, pre_start, pre_end, post_start, post_end, geometry)
    le7_img = apply_corrections(le7, pre_start, pre_end, post_start, post_end, geometry)
    lc8_img = apply_corrections(lc8, pre_start, pre_end, post_start, post_end, geometry)
    sent_img = apply_corrections(sent, pre_start, pre_end, post_start, post_end, geometry)

    return ee.ImageCollection([lt5_img, le7_img, lc8_img, sent_img]).mosaic()

# Main processing function for a fire polygon
def process_fire_polygon(i):
    sub_shape = lfdb.filter(ee.Filter.eq("ID", i))
    bbox = sub_shape.geometry().bounds()
    
    proj = ee.Projection("EPSG:4326").translate(0.00, 0.00)
    final_buffer = ee.Geometry.Polygon(bbox.coordinates(), proj).transform(proj)
    final_buffer2 = final_buffer.buffer(5000).bounds()
    final_buffer = final_buffer.buffer(40000)

    this_year = ee.Number(sub_shape.aggregate_array('Year').get(0))
    all_months = ee.List([
        ee.List(['-03-01', '-04-01']),
        ee.List(['-04-01', '-05-01']),
        ee.List(['-05-01', '-06-01']),
        ee.List(['-06-01', '-07-01']),
        ee.List(['-07-01', '-08-01']),
        ee.List(['-08-01', '-09-01']),
        ee.List(['-09-01', '-10-01']),
        ee.List(['-10-01', '-11-01']),
        ee.List(['-06-01', '-08-31'])
    ])
    
    def process_month(month):
        m1 = ee.String(ee.List(month).get(0))
        m2 = ee.String(ee.List(month).get(1))

        start_year = ee.Number(this_year).subtract(1)
        end_year = ee.Algorithms.If(m1.compareTo('-06-01').eq(0).And(m2.compareTo('-08-31').eq(0)), this_year.add(1), this_year)

        pre_start = ee.Date(ee.String(start_year).cat(m1))
        pre_end = ee.Date(ee.String(start_year).cat(m2))
        post_start = ee.Date(ee.String(end_year).cat(m1))
        post_end = ee.Date(ee.String(end_year).cat(m2))

        return get_pre_post(pre_start, pre_end, post_start, post_end, final_buffer)

    all_months_images = ee.ImageCollection(all_months.map(process_month)).max()

    raw_bands = all_months_images.clip(final_buffer)

    # Fire raster
    lfdb_filtered = lfdb.filterBounds(final_buffer).filter(ee.Filter.eq("Year", this_year))
    fire_rast = lfdb_filtered.reduceToImage(properties=['ID'], reducer=ee.Reducer.first())
    fire_rast = fire_rast.where(fire_rast.gt(0), 1)

    bad_filtered = lfdb.filterBounds(final_buffer).filter(ee.Filter.Or(
        ee.Filter.eq("Year", ee.Number(this_year).subtract(1)),
        ee.Filter.eq("Year", this_year),
        ee.Filter.eq("Year", ee.Number(this_year).add(1)),
        ee.Filter.eq("Year", ee.Number(this_year).add(2))
    ))
    
    bad_fire_rast = bad_filtered.reduceToImage(properties=['ID'], reducer=ee.Reducer.first())
    bad_fire_rast = bad_fire_rast.where(bad_fire_rast.gt(0), 1)
    bad_fire_rast = bad_fire_rast.where(bad_fire_rast.eq(1).And(fire_rast.eq(1)), 2).unmask(-999)

    raw_bands = raw_bands.updateMask(bad_fire_rast.neq(1))

    # Target variable
    y = raw_bands.select(['NBR'], ['y']).where(fire_rast.eq(1), 1).where(fire_rast.neq(1), 0)
    y = y.cast({'y': 'short'})
    raw_bands = raw_bands.addBands(y)

    # Start download
    fname = f"{folder_name}/final_{i}"
    task = ee.batch.Export.image.toCloudStorage(
        image=raw_bands.toShort(),
        region=final_buffer2,
        description=fname,
        scale=30,
        crs='EPSG:3413',
        maxPixels=1e13,
        bucket=bucket_name,
        fileNamePrefix=fname
    )
    task.start()
    print(f"Downloading {fname}")

    return raw_bands

# Convert all_ids to an ee.List and map over it
all_ids = ee.List([16086, 3381, 15894, 2464, 8737, 12494, 9763, 3266])
all_ids = ee.List([3266])

all_results = all_ids.map(process_fire_polygon)
# Out:
# /tmp/ipykernel_2067434/1188092074.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si'] = pd.Categorical(l5['band.or.si'], categories=bands)
# /tmp/ipykernel_2067434/1188092074.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si'] = pd.Categorical(l5['band.or.si'], categories=bands)
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[7], line 180
#     177 all_ids = ee.List([16086, 3381, 15894, 2464, 8737, 12494, 9763, 3266])
#     178 all_ids = ee.List([3266])
# --> 180 all_results = all_ids.map(process_fire_polygon)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/ee_list.py:417, in List.map(self, baseAlgorithm, dropNulls)
#     400 def map(
#     401     self, baseAlgorithm: _EeAnyType, dropNulls: _EeBoolType = False
#     402 ) -> 'List':
#     403   # pylint: enable=invalid-name
#     404   """Map an algorithm over a list.
#     405
#     406   The algorithm is expected to take an Object and return an Object.
#    (...)
#     414     An ee.List.
#     415   """
# --> 417   return apifunction.ApiFunction.call_(
#     418       self.name() + '.map', self, baseAlgorithm, dropNulls
#     419   )
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/apifunction.py:84, in ApiFunction.call_(cls, name, *args, **kwargs)
#      71 @classmethod
#      72 def call_(cls, name: str, *args: Any, **kwargs: Any) -> Any:
#      73   """Call a named API function with positional and keyword arguments.
#      74
#      75   Args:
#    (...)
#      82     a recognized return type, the returned value will be cast to that type.
#      83   """
# ---> 84   return cls.lookup(name).call(*args, **kwargs)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/function.py:62, in Function.call(self, *args, **kwargs)
#      50 def call(self, *args, **kwargs):
#      51   """Calls the function with the given positional and keyword arguments.
#      52
#      53   Args:
#    (...)
#      60     to that type.
#      61   """
# ---> 62   return self.apply(self.nameArgs(args, kwargs))
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/function.py:75, in Function.apply(self, named_args)
#      64 def apply(self, named_args):
#      65   """Calls the function with a dictionary of named arguments.
#      66
#      67   Args:
#    (...)
#      73     to that type.
#      74   """
# ---> 75   result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      76   return Function._promoter(result, self.getReturnType())
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/function.py:103, in Function.promoteArgs(self, args)
#     101 name = arg_spec['name']
#     102 if name in args:
# --> 103   promoted_args[name] = Function._promoter(args[name], arg_spec['type'])
#     104 elif not arg_spec.get('optional'):
#     105   raise ee_exception.EEException(
#     106       'Required argument (%s) missing to function: %s'
#     107       % (name, signature.get('name')))
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/__init__.py:335, in _Promote(arg, a_class)
#     332 elif callable(arg):
#     333   # A native function that needs to be wrapped.
#     334   args_count = len(inspect.getfullargspec(arg).args)
# --> 335   return CustomFunction.create(arg, 'Object', ['Object'] * args_count)
#     336 elif isinstance(arg, Encodable):
#     337   # An ee.Function or a computed function like the return value of
#     338   # Image.parseExpression().
#     339   return arg
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/customfunction.py:126, in CustomFunction.create(func, return_type, arg_types)
#     120 args = [{'name': None, 'type': StringifyType(i)} for i in arg_types]
#     121 signature = {
#     122     'name': '',
#     123     'returns': StringifyType(return_type),
#     124     'args': args
#     125 }
# --> 126 return CustomFunction(signature, func)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/customfunction.py:40, in CustomFunction.__init__(self, signature, body)
#      26 """Creates a function defined by a given expression with unbound variables.
#      27
#      28 The expression is created by evaluating the given function
#    (...)
#      35   body: The Python function to evaluate.
#      36 """
#      37 variables = [CustomFunction.variable(arg['type'], arg['name'])
#      38              for arg in signature['args']]
# ---> 40 if body(*variables) is None:
#      41   raise ee_exception.EEException('User-defined methods must return a value')
#      43 # The signature of the function.
#
# Cell In[7], line 160, in process_fire_polygon(i)
#     157 raw_bands = raw_bands.addBands(y)
#     159 # Start download
# --> 160 fname = f"{folder_name}/final_{i}"
#     161 task = ee.batch.Export.image.toCloudStorage(
#     162     image=raw_bands.toShort(),
#     163     region=final_buffer2,
#    (...)
#     169     fileNamePrefix=fname
#     170 )
#     171 task.start()
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/computedobject.py:187, in ComputedObject.__str__(self)
#     185 def __str__(self) -> str:
#     186   """Writes out the object in a human-readable form."""
# --> 187   return 'ee.%s(%s)' % (self.name(), serializer.toReadableJSON(self))
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/serializer.py:326, in toReadableJSON(obj, for_cloud_api)
#     324 def toReadableJSON(obj: Any, for_cloud_api: bool = True) -> Any:
#     325   """Convert an object to readable JSON."""
# --> 326   return toJSON(obj, True, for_cloud_api=for_cloud_api)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/serializer.py:319, in toJSON(obj, pretty, for_cloud_api)
#     307 """Serialize an object to a JSON string appropriate for API calls.
#     308
#     309 Args:
#    (...)
#     316   A JSON string representing the input.
#     317 """
#     318 serializer = Serializer(not pretty, for_cloud_api=for_cloud_api)
# --> 319 encoded = serializer._encode(obj)  # pylint: disable=protected-access
#     320 return json.dumps(encoded, indent=2 if pretty else None)
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/serializer.py:79, in Serializer._encode(self, obj)
#      70 """Encodes a top level object to be executed server-side.
#      71
#      72 Args:
#    (...)
#      76   An encoded object ready for JSON serialization.
#      77 """
#      78 if self._for_cloud_api:
# ---> 79   return self._encode_for_cloud_api(obj)
#      80 value = self._encode_value(obj)
#      81 if self._is_compound:
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/serializer.py:97, in Serializer._encode_for_cloud_api(self, obj)
#      95 def _encode_for_cloud_api(self, obj: Any) -> Any:
#      96   """Encodes an object as an Expression or quasi-Expression."""
# ---> 97   value = self._encode_cloud_object(obj)
#      98   if self._is_compound:
#      99     # Wrap the scopes and final value into an Expression.
#     100     value = _ExpressionOptimizer(value, self._scope).optimize()
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/.conda/envs/gee_ml/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     143     ref = encoder.__self__.unbound_name
#     144   if ref is None:
#     145     # We are trying to call getInfo() or make some other server call inside
#     146     # a function passed to collection.map() or .iterate(), and the call uses
#     147     # one of the function arguments. The argument will be unbound outside of
#     148     # the map operation and cannot be evaluated. See the Count Functions
#     149     # case in customfunction.py for details on the unbound_name mechanism.
# --> 150     raise ee_exception.EEException(
#     151         "A mapped function's arguments cannot be used in "
#     152         'client-side operations'
#     153     )
#     154   return {'argumentReference': ref}
#     155 else:
#
# EEException: A mapped function's arguments cannot be used in client-side operations
