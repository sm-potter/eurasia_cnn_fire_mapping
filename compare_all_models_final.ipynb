# %% [markdown]
# This script will run the ak and canada models together

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import tensorflow
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.python.lib.io import file_io
from tensorflow.python.keras.optimizer_v2.adam import Adam
import os
import segmentation_models as sm
import matplotlib.pyplot as plt
import numpy as np
#from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Dropout,Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.layers import concatenate, Conv2DTranspose, Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, Input, AvgPool2D
from tensorflow.keras.models import Model
from keras_unet_collection import models
import tensorflow_addons as tfa
import logging
# from tensorflow import tensorflow.keras.mixed_precision.set_global_policy("mixed_float16")
# Out:
# Segmentation Models: using `keras` framework.
# /home/spotter5/.conda/envs/deeplearning3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/spotter5/.conda/envs/deeplearning3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# Read in the testing data for all four models, plus all the mtbs data for models 1 and 2

# %%
#----------projected with negative nbac training 128
model_test = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_0_final_128_testing_files.csv')['Files'].tolist()



good_ids= pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/raw_files/ak_ca_1985_clip.csv')

def get_good(in_list, good_frame):
    
    final = []
    for i in in_list:

        try:

            in_id = int(i.split('/')[-1].split('_')[2].replace('.npy', ''))

            if in_id in good_frame['ID']:

                final.append(i)
        except:
            pass
        
    return final


model_test = get_good(model_test, good_ids)

#mtbs files to test on 
land_sent_mtbs_128_train = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_mtbs_0_128_training_files.csv')['Files'].tolist()
land_sent_mtbs_128_val = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_mtbs_0_128_validation_files.csv')['Files'].tolist()
land_sent_mtbs_128_test = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_mtbs_0_128_testing_files.csv')['Files'].tolist()


mtbs = land_sent_mtbs_128_train + land_sent_mtbs_128_val + land_sent_mtbs_128_test

#function to get files from storage bucket
def get_files(bucket_path):

    """argument is the path to where the numpy
    save files are located, return a list of filenames
    """
    all = []

    #list of files
    files = os.listdir(bucket_path)

    #get list of filenames we will use, notte I remove images that don't have a target due to clouds
    file_names = []
    for f in files:
        
        if f.endswith('.npy'):

            all.append(os.path.join(bucket_path, f))
        
    return(all)
  
model_test
# Out:
# ['/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_3_5587.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_32_8017.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_4_883.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_2_57.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_2_8629.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_1_1146.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_3_9048.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_19_10833.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_2_1116.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/19_17_71.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/8_14_4227.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_0_6875.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/14_14_2164.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/14_21_942.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/10_0_8099.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_1_11176.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_3_7482.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_0_3525.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_6_8202.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_42_6761.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_19_885.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_4_914.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_0_4551.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/12_8_8740.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/18_9_781.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_11_3702.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_29_3395.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_1_9749.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_4_1225.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/40_36_6777.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/25_19_8642.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/8_6_1767.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_6_2013.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/12_3_5030.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_2_9612.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_18_2155.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/25_23_612.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_13_3228.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_2_3040.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_8_8129.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_10_2024.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_2_6141.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_3_2168.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/7_8_6842.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_2_5329.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_2_8469.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/24_20_9617.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/8_9_4013.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_4_7177.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_2_9014.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_4_9622.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/24_3_2017.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_0_1678.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_4_3246.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_0_5174.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_0_3012.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/9_0_911.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128
npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_12_6753.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/17_19_1228.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_10_9205.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_4_7299.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_8_44.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/21_21_9617.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_0_117.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_5_7118.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/44_8_48.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_2_3431.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/12_4_1615.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_16_4490.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_5_4893.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_10_10878.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_12_7799.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_1_6841.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/18_9_1270.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_0_7190.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/7_13_7115.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/43_21_1217.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/14_13_6805.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_2_5744.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_1_6411.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/41_51_1217.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_2_5636.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_9_6822.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_2_8181.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/9_11_16.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_0_6842.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_2_4114.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_3_2505.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/7_1_4569.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/34_5_6299.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/13_34_114.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_2_1189.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_1_3643.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_14_4857.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/10_12_2012.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/24_18_16.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/15_11_10811.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/3_1_4394.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/9_8_6480.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_0_9415.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_11_1408.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_4_4591.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/9_0_848.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_3_3812.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/33_20_8093.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_0_5885.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_0_6506.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/29_37_868.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_13_897.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/25_6_868.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/21_28_781.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/8_17_2081.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_1_7631.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_2_2921.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/4_3_9531.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/9_38_885.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/37_6_6777.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/1_0_2927.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_41_868.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_11_1819.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/7_3_459.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_0_126.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/5_1_6389.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/11_17_27.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/2_0_4691.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/6_10_184.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/10_3_7190.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/0_6_1487.npy',
#  '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_proj_subs_0_final_128/16_10_2134.npy',
#  ...]

# %% [markdown]
# Set up image generator for dnbr

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

min_max = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_global_min_max_cutoff_proj.csv").reset_index(drop = True)
min_max = min_max[['6']]

class img_gen(tensorflow.keras.utils.Sequence):

    """Helper to iterate over the data (as Numpy arrays).
    Inputs are batch size, the image size, the input paths (x) and target paths (y)
    """

    #will need pre defined variables batch_size, img_size, input_img_paths and target_img_paths
    def __init__(self, batch_size, img_size, input_img_paths):
	    self.batch_size = batch_size
	    self.img_size = img_size
	    self.input_img_paths = input_img_paths
	    self.target_img_paths = input_img_paths

    #number of batches the generator is supposed to produceis the length of the paths divided by the batch siize
    def __len__(self):
	    return len(self.input_img_paths) // self.batch_size

    def __getitem__(self, idx):
        
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_img_paths = self.input_img_paths[i : i + self.batch_size] #for a given index get the input batch pathways (x)
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size] #for a given index get the input batch pathways (y)
		
        x = np.zeros((self.batch_size,) + self.img_size, dtype="float32") #create matrix of zeros which will have the dimension (batch_size, height, wideth, n_bands), 8 is the n_bands
        
  
        #start populating x by enumerating over the input img paths
        for j, path in enumerate(batch_img_paths):

            #load image
            img =  np.round(np.load(path), 3)[:, :, 6]

            # img = img * 1000
            img = img.astype(float)
            img = np.round(img, 3)
            img[img == 0] = -999

            img[np.isnan(img)] = -999


            img[img == -999] = np.nan

            in_shape = img.shape

            #turn to dataframe to normalize
            img = img.reshape(img.shape[0] * img.shape[1])

            img = pd.DataFrame(img)

            img.columns = min_max.columns

            img = pd.concat([min_max, img]).reset_index(drop = True)


            #normalize 0 to 1
            img = pd.DataFrame(scaler.fit_transform(img))

            img = img.iloc[2:]
#
#             img = img.values.reshape(in_shape)
            img = img.values.reshape(in_shape)

#             replace nan with -1
            img[np.isnan(img)] = -1

#apply standardization
# img = normalize(img, axis=(0,1))

            img = np.round(img, 3)
            #populate x
            x[j] = img#[:, :, 4:] index number is not included, 


        #do tthe same thing for y
        y = np.zeros((self.batch_size,) + self.img_size, dtype="uint8")

        for j, path in enumerate(batch_target_img_paths):

            #load image
            img =  np.round(np.load(path), 3)[:, :, -1]

            img = img.astype(int)

            img[img < 0] = 0
            img[img >1] = 0
            img[~np.isin(img, [0,1])] = 0

            img[np.isnan(img)] = 0
            img = img.astype(int)

            # img =  tf.keras.utils.to_categorical(img, num_classes = 2)
            # y[j] = np.expand_dims(img, 2) 
            y[j] = img
  
       
    #Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
    # y[j] -= 1

        return x, y

# %% [markdown]
# Image generator for 3 bands

# %%
min_max_vi = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_sent_collection2_global_min_max_cutoff_proj.csv").reset_index(drop = True)
min_max_vi = min_max_vi[['6', '7', '8']]

class img_gen_vi(tensorflow.keras.utils.Sequence):

    """Helper to iterate over the data (as Numpy arrays).
    Inputs are batch size, the image size, the input paths (x) and target paths (y)
    """

    #will need pre defined variables batch_size, img_size, input_img_paths and target_img_paths
    def __init__(self, batch_size, img_size, input_img_paths):
	    self.batch_size = batch_size
	    self.img_size = img_size
	    self.input_img_paths = input_img_paths
	    self.target_img_paths = input_img_paths

    #number of batches the generator is supposed to produceis the length of the paths divided by the batch siize
    def __len__(self):
	    return len(self.input_img_paths) // self.batch_size

    def __getitem__(self, idx):
        
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_img_paths = self.input_img_paths[i : i + self.batch_size] #for a given index get the input batch pathways (x)
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size] #for a given index get the input batch pathways (y)
		
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32") #create matrix of zeros which will have the dimension height, wideth, n_bands), 8 is the n_bands
        
  
         #start populating x by enumerating over the input img paths
        for j, path in enumerate(batch_img_paths):

            #load image
            img =  np.round(np.load(path), 3)[:, :, 6:9]

            # img = img * 1000
            img = img.astype(float)
            img = np.round(img, 3)
            img[img == 0] = -999

            img[np.isnan(img)] = -999


            img[img == -999] = np.nan

            in_shape = img.shape
            
            #turn to dataframe to normalize
            img = img.reshape(img.shape[0] * img.shape[1], img.shape[2])
			
            img = pd.DataFrame(img)
			
            img.columns = min_max_vi.columns
			
            img = pd.concat([min_max_vi, img]).reset_index(drop = True)


            #normalize 0 to 1
            img = pd.DataFrame(scaler.fit_transform(img))
			
            img = img.iloc[2:]
#
#             img = img.values.reshape(in_shape)
            img = img.values.reshape(in_shape)

#             replace nan with -1
            img[np.isnan(img)] = -1

#apply standardization
# img = normalize(img, axis=(0,1))

            img = np.round(img, 3)
            #populate x
            x[j] = img#[:, :, 4:] index number is not included, 


        #do tthe same thing for y
        y = np.zeros((self.batch_size,) + self.img_size, dtype="uint8")

        for j, path in enumerate(batch_target_img_paths):

            #load image
            img =  np.round(np.load(path), 3)[:, :, -1]

            img = img.astype(int)

            img[img < 0] = 0
            img[img >1] = 0
            img[~np.isin(img, [0,1])] = 0

            img[np.isnan(img)] = 0
            img = img.astype(int)

            # img =  tf.keras.utils.to_categorical(img, num_classes = 2)
            # y[j] = np.expand_dims(img, 2) 
            y[j] = img
  
       
    #Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
    # y[j] -= 1

        return x, y

# %% [markdown]
# Read in the images based on the generator

# %%
#batch size and img size
BATCH_SIZE = 15
GPUS = ["GPU:0", "GPU:1", "GPU:2", "GPU:3"]
strategy = tensorflow.distribute.MirroredStrategy() #can add GPUS here to select specific ones
print('Number of devices: %d' % strategy.num_replicas_in_sync) 

batch_size = BATCH_SIZE * strategy.num_replicas_in_sync

#image size
img_size = (128, 128)

#number of classes to predict
num_classes = 1

#nbac testing dnbr
models_dnbr_gen =  img_gen(batch_size, img_size, model_test)
models_vi_gen =  img_gen_vi(batch_size, img_size, model_test)

#mtbs
mtbs_dnbr_gen =  img_gen(batch_size, img_size, mtbs)
mtbs_vi_gen =  img_gen_vi(batch_size, img_size, mtbs)
# Out:
# Number of devices: 4

# %% [markdown]
# Read in all the models

# %%
# #-------landsat 8
# model_1 = tensorflow.keras.models.load_model("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/models/l8_collection2_dnbr_one_128_2d_ds_proj_gids.tf", 
#                                            custom_objects={'precision':sm.metrics.Precision(threshold=0.5), 
#                                                            'recall':sm.metrics.Recall(threshold = 0.5),
#                                                             'f1-score': sm.metrics.FScore(threshold=0.5),
#                                                              'iou_score': sm.metrics.IOUScore(threshold=0.5),
#                                                               'accuracy': 'accuracy'})

# model_2 = tensorflow.keras.models.load_model("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/models/l8_collection2_VI_one_128_2d_ds_proj_final_gids.tf", 
#                                            custom_objects={'precision':sm.metrics.Precision(threshold=0.5), 
#                                                            'recall':sm.metrics.Recall(threshold = 0.5),
#                                                             'f1-score': sm.metrics.FScore(threshold=0.5),
#                                                              'iou_score': sm.metrics.IOUScore(threshold=0.5)})

# model_3 = tensorflow.keras.models.load_model("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/models/l8_collection2_dnbr_one_128_2d_ds_proj_mtbs_gids.tf", 
#                                            custom_objects={'precision':sm.metrics.Precision(threshold=0.5), 
#                                                            'recall':sm.metrics.Recall(threshold = 0.5),
#                                                             'f1-score': sm.metrics.FScore(threshold=0.5),
#                                                              'iou_score': sm.metrics.IOUScore(threshold=0.5)})

model_4 = tensorflow.keras.models.load_model("/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/models/l8_collection2_VI_one_128_2d_ds_proj_final_mtbs_gids.tf", 
                                           custom_objects={'precision':sm.metrics.Precision(threshold=0.5), 
                                                           'recall':sm.metrics.Recall(threshold = 0.5),
                                                            'f1-score': sm.metrics.FScore(threshold=0.5),
                                                             'iou_score': sm.metrics.IOUScore(threshold=0.5)})

# %% [markdown]
# Model 1 testing scores

# %%
model_1_res = model_1.evaluate_generator(mtbs_dnbr_gen, 100)

iou = model_1_res[-2]
precision = model_1_res[-5]
recall = model_1_res[-4]
f1 = model_1_res[-3]
accuracy = model_1_res[-1]

print(f"Model 1 testing IoU is {iou}")
print(f"Model 1 testing precision is {precision}")
print(f"Model 1 testing recall is {recall}")
print(f"Model 1 testing f1 is {f1}")
print(f"Model 1 testing accuracy is {accuracy}")
# Out:
# /tmp/ipykernel_762106/3175516196.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model_1_res = model_1.evaluate_generator(mtbs_dnbr_gen, 100)
# Model 1 testing IoU is 0.790679931640625
# Model 1 testing precision is 0.9726361036300659
# Model 1 testing recall is 0.8082199096679688
# Model 1 testing f1 is 0.8809217810630798
# Model 1 testing accuracy is 0.963837742805481

# %% [markdown]
# Model 2 testing scores

# %%
model_2_res = model_2.evaluate_generator(mtbs_vi_gen, 100)

iou = model_2_res[-2]
precision = model_2_res[-5]
recall = model_2_res[-4]
f1 = model_2_res[-3]
accuracy = model_2_res[-1]

print(f"Model 2 testing IoU is {iou}")
print(f"Model 2 testing precision is {precision}")
print(f"Model 2 testing recall is {recall}")
print(f"Model 2 testing f1 is {f1}")
print(f"Model 2 testing accuracy is {accuracy}")
# Out:
# /tmp/ipykernel_762106/455516871.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model_2_res = model_2.evaluate_generator(mtbs_vi_gen, 100)
# Model 2 testing IoU is 0.8228231072425842
# Model 2 testing precision is 0.9722893238067627
# Model 2 testing recall is 0.8424709439277649
# Model 2 testing f1 is 0.9010870456695557
# Model 2 testing accuracy is 0.9692376255989075

# %% [markdown]
# Model 3 testing scores

# %%
model_3_res = model_3.evaluate_generator(models_dnbr_gen, 100)

iou = model_3_res[-2]
precision = model_3_res[-5]
recall = model_3_res[-4]
f1 = model_3_res[-3]
accuracy = model_3_res[-1]

print(f"Model 2 testing IoU is {iou}")
print(f"Model 2 testing precision is {precision}")
print(f"Model 2 testing recall is {recall}")
print(f"Model 2 testing f1 is {f1}")
print(f"Model 2 testing accuracy is {accuracy}")
# Out:
# /tmp/ipykernel_762106/1577085814.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model_3_res = model_3.evaluate_generator(models_dnbr_gen, 100)
# Model 2 testing IoU is 0.865113377571106
# Model 2 testing precision is 0.920407235622406
# Model 2 testing recall is 0.9351356029510498
# Model 2 testing f1 is 0.9272314310073853
# Model 2 testing accuracy is 0.9808530211448669

# %% [markdown]
# Model 4 testing scores

# %%
model_4_res = model_4.evaluate_generator(models_vi_gen, 100)

iou = model_4_res[-2]
precision = model_4_res[-5]
recall = model_4_res[-4]
f1 = model_4_res[-3]
accuracy = model_4_res[-1]

print(f"Model 2 testing IoU is {iou}")
print(f"Model 2 testing precision is {precision}")
print(f"Model 2 testing recall is {recall}")
print(f"Model 2 testing f1 is {f1}")
print(f"Model 2 testing accuracy is {accuracy}")
# Out:
# /tmp/ipykernel_882445/111447473.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model_4_res = model_4.evaluate_generator(models_vi_gen, 100)
# Model 2 testing IoU is 0.8775147795677185
# Model 2 testing precision is 0.938153088092804
# Model 2 testing recall is 0.931460440158844
# Model 2 testing f1 is 0.934390127658844
# Model 2 testing accuracy is 0.9827530384063721

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import os
font = {'family' : 'normal',
        'size'   : 28}
matplotlib.rc('font', **font)





# good models
df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/nbac_mtbs.csv")

# df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia.csv")

# df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_good.csv")

# df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/combined.csv")


# df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_no_grass.csv")
# 
# df = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_no_grass_old.csv")

# df = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/combined_good.csv')
# 
# df = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_good_adaptive.csv')

# df = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_good_regularize.csv')
df = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/russia_good_2015_2019_no_regularize.csv')
# df = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/Russia/combined_good_no_reg_2015_2019.csv')

df['Moving Average'] = df['Val_IOU'].rolling(5).mean()
df['Moving Average2'] = df['Val_Loss'].rolling(5).mean()




plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.plot(df['IOU'])
plt.plot(df['Val_IOU'])
plt.plot(df['Moving Average'])

plt.ylabel('IOU')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation', 'Validation Moving Average'], loc='lower right', prop={'size': 17})


# Plot training & validation loss values
plt.subplot(222)
plt.plot(df['Loss'])
plt.plot(df['Val_Loss'])
plt.plot(df['Moving Average2'])

# plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.tight_layout()


plt.show()

# %% [markdown]
# Make final table with all the metrics, note here we will use the best IoU for all four models than get the other stats

# %%
#model 1
mod1 = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_collection2_dnbr_one_128_2d_ds_proj_final.csv')
mod2 = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_collection2_VI_one_128_2d_ds_proj_final.csv')
mod3 = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_collection2_dnbr_one_128_2d_ds_proj_mtbs.csv')
mod4 = pd.read_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/l8_collection2_VI_one_128_2d_ds_proj_final_mtbs.csv')

t = mod4[mod4['Val_IOU'] == mod4['Val_IOU'].max()][['Val_IOU', 'Val_Precision', 'Val_Recall', 'Val_F1', 'Val_Accuracy']]
print(t)
# Out:
#      Val_IOU  Val_Precision  Val_Recall   Val_F1  Val_Accuracy
# 49  0.854954       0.914487    0.930018  0.91691      0.980829

# %%
t2 = mod4[mod4['Val_IOU'] == mod4['Val_IOU'].max()]
print(t2.shape)
# Out:
# (1, 13)

# %%
len(model1_dnbr_res)
# Out:
# 19

# %%
model_1.history
# Out:
# keras.callbacks.History
