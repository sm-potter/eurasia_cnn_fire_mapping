# %% [markdown]
# Read in all the packages

# %%
import os
import ee
import geemap
from geeml.extract import extractor
from google.cloud import storage
from google.cloud import client
import random
import xarray as xr

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json"

service_account = 'gee-serdp-upload@appspot.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json")

ee.Initialize(credentials)#h high-volume end-point
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')

# %% [markdown]
# Read in assets

# %%
sent_2A = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") #sentinel 2
s2Clouds = ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY') #cloud masking for sentinel
lfdb = ee.FeatureCollection("users/spotter/fire_cnn/raw/nbac_1985") #nbac_fire_polygons, this can be any polygon shapefile, final version would be nbac and mtbs

# %% [markdown]
# Mask clouds Sentinel

# %%
#probability of clouds
MAX_CLOUD_PROBABILITY = 50

def sent_maskcloud(image):
    
    
    image = image.select(['B2', 'B3', 'B4', 'B8', 'B11', 'B12'], ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7'])# rename bands to match landsat
  
    image =  image.toShort()
    
    clouds = ee.Image(image.get('cloud_mask')).select('probability')
    
    isNotCloud = clouds.lt(MAX_CLOUD_PROBABILITY)
    
    image = image.updateMask(isNotCloud)

    #reproject 30m but remember b1, b2 and b3 are 10 and the rest are 20
    image1 = image.select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4'])
    image2 = image.select(['SR_B5', 'SR_B7'])

    
    image1 = image1.reproject(
    crs = image1.projection().crs(),
    scale = 30) #resample for landsat
    
    
    image2 = image2.reproject(
    crs = image2.projection().crs(),
    scale = 30) #resample for landsat
    
    image = image1.addBands(image2)
    
    return image 

#Join S2 SR with cloud probability dataset to add cloud mask.
s2SrWithCloudMask = ee.Join.saveFirst('cloud_mask').apply(
    
  primary=sent_2A,
  secondary=s2Clouds,
  condition=ee.Filter.equals(leftField='system:index', rightField='system:index'))

#apply cloud masking
sent_2A = ee.ImageCollection(s2SrWithCloudMask).map(sent_maskcloud)

# %% [markdown]
# Landsat Mask, snow and clouds

# %%
def mask(image):
    qa = image.select('QA_PIXEL')                                       
    mask = qa.bitwiseAnd(8).eq(0).And(qa.bitwiseAnd(10).eq(0)).And(qa.bitwiseAnd(32).eq(0))  
    return(image.updateMask(mask))

# %% [markdown]
# Correct the landsat scale factor and sentinel scale factor

# %%
def land_scale(image):

    return(image.multiply(0.0000275).add(-0.2))

def sent_scale(image):
    return(image.multiply(0.0001))

# %% [markdown]
# Coefficients from Logan Berner to apply correction factors

# %%
import pandas as pd
coeffs = pd.read_csv("/explore/nobackup/people/spotter5/cnn_mapping/raw_files/boreal_xcal_regression_coefficients.csv").fillna(0)

#l5
def landsat_correct(sat, bands):

    """argument 1 is which sattelite, LANDASAT_5 or LANDSAT_8
    argument 2 is bands of interest.  Bands must be in same order as EE,
    
    regression is of form,
    L7 = B0 + (B1 * L5/8) + (B2 * L^2) + (B3 * L^3)
    """

    #bands of interest in order of interest
    l5 = coeffs[(coeffs['satellite'] == sat) & (coeffs['band.or.si'] .isin (bands))] 

    #arrange the band or si column
    l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)
    l5=l5.sort_values('band.or.si')

    b0 = l5['B0'].values.tolist()
    b1 = l5['B1'].values.tolist()
    b2 = l5['B2'].values.tolist()
    b3 = l5['B3'].values.tolist()

    return (b0, b1, b2, b3)

#get the corrections, each output is a list at one of the four locations
l8_corr = landsat_correct(sat = 'LANDSAT_8', bands = ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])
l5_corr = landsat_correct(sat = 'LANDSAT_5', bands = ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'nbr', 'ndvi', 'ndii'])
# Out:
# /tmp/ipykernel_1214470/639313901.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)
# /tmp/ipykernel_1214470/639313901.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l5['band.or.si']=pd.Categorical(l5['band.or.si'],categories=bands)

# %% [markdown]
# Authenticate my google bucket, not sure if this is needed anymore

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json"
storage_client = storage.Client.from_service_account_json("/explore/nobackup/people/spotter5/cnn_mapping/gee-serdp-upload-7cd81da3dc69.json")

os.environ["GCLOUD_PROJECT"] = "gee-serdp-upload"
storage_client = storage.Client()

bucket_name = 'smp-scratch'

bucket = storage_client.bucket(bucket_name)

# %% [markdown]
# There are going to be issues later with different band types, so cast them all to float

# %%
def to_float(image):

    b1 = image.select('SR_B1').cast({'SR_B1':'float'}) #0
    b2 = image.select('SR_B2').cast({'SR_B2':'float'}) #1
    b3 = image.select('SR_B3').cast({'SR_B3':'float'}) #2
    b4 = image.select('SR_B4').cast({'SR_B4':'float'}) #3
    b5 = image.select('SR_B5').cast({'SR_B5':'float'}) #4
    b6 = image.select('SR_B7').cast({'SR_B7':'float'}) #5

    image = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6)

    return image

# %%
#get all the ids within the lfdb shapefile
all_ids = ee.List(lfdb.distinct(["ID"]).aggregate_array("ID"))
all_ids = all_ids.getInfo()

# all_ids = all_ids[0:2]
#loop through each fire polygon
for i in all_ids:

    #name of output file
    fname = f"median_{i}.tif"

    #check if file exists on my bucket, if it does skip
    stats = storage.Blob(bucket=bucket, name=fname).exists(storage_client)
    if stats == False:
        
        #get the fire polygon of interest
        sub_shape = lfdb.filter(ee.Filter.eq("ID", i))

        #get all other fire ids that are not this one
        not_fires = lfdb.filter(ee.Filter.neq("ID", i))

        #get the year of this fire
        this_year = ee.Number(sub_shape.aggregate_array('Year').get(0))
      
        #date ranges for pre and post fire
        pre_start = ee.Date.fromYMD(this_year.subtract(1), 6, 1)
        pre_end = ee.Date.fromYMD(this_year.subtract(1), 8, 31)
        post_start = pre_start.advance(2, 'year')
        post_end = pre_end.advance(2, 'year')


        #first get the bounding box of the fire
        bbox = sub_shape.geometry().bounds()


        #offset the bounding box by a random number
        all_rands = [0.00, 0.02, -0.02]
        all_rands = [0.00]


        rand1 = random.sample(all_rands, 1)[0]
        rand2 = random.sample(all_rands, 1)[0]

        #offset applied
        proj = ee.Projection("EPSG:4326").translate(rand1, rand2)
        
        #for the bounding box apply the randomly selected offset
        final_buffer = ee.Geometry.Polygon(bbox.coordinates(), proj).transform(proj)
        
        #this is a bit of a hack but we have two different bounding box sizes because when we export we need to use some additonal area to avoid cuttoffs
        final_buffer2 = final_buffer.buffer(distance= 5000).bounds()

        final_buffer = final_buffer.buffer(distance= 40000)#.bounds().transform(proj='EPSG:3413', maxError=1)
    
     
        #just getting some date info here to ensure pre fire is one  year before and post fire is one year after the fire year of interest
        startYear = pre_start.get('year')

        #convert to client side
        startYear = startYear.getInfo()  # local string
        endYear = str(int(startYear) + 2)
        startYear = str(startYear)

        #------------------------------------------------harmonize landsat
        startDay  = '01-01' # what is the beginning of date filter | month-day
        endDay     = '12-30' # what is the end of date filter | month-day



        #------ RETRIEVE A SENSOR SR COLLECTION FUNCTION -----
        def getSRcollection(start_date, end_date, sensor):
            # get a landsat collection for given year, day range, and sensor
            srCollection = ee.ImageCollection('LANDSAT/'+ sensor + '/C02/T1_L2').filterDate(start_date, end_date)

            return srCollection

        #get the image collections only in the dates of interest and filter by the final buffer aoi
        lt5 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LT05').filterBounds(final_buffer)    
        le7 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LE07').filterBounds(final_buffer)     
        lc8 = getSRcollection(startYear+'-'+startDay, endYear+'-'+endDay, 'LC08').filterBounds(final_buffer)        
        sent= sent_2A.filterBounds(final_buffer)

        #------------------------------------------Landsat 5 corrections

        #pre fire apply landsat mask, scale factor etc.
        pre_lt5 = lt5.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #ensure we have imagery for the sensor
        if pre_lt5.size().getInfo() > 0 :


            #take the median pf the collection
            pre_lt5 = pre_lt5.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            pre_lt5_nbr = pre_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            pre_lt5_ndvi = pre_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            pre_lt5_ndii = pre_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            pre_lt5 = pre_lt5.addBands(pre_lt5_nbr).addBands(pre_lt5_ndvi).addBands(pre_lt5_ndii)

            #apply the corrections from Logan
            l5_pre_corr = pre_lt5.multiply(l5_corr[1]).add(pre_lt5.pow(2).multiply(l5_corr[2])).add(pre_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])

        #-------now do post-fire
        #select bands
        post_lt5 = lt5.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if post_lt5.size().getInfo() > 0 :

            #take the median
            post_lt5 = post_lt5.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            post_lt5_nbr = post_lt5.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            post_lt5_ndvi = post_lt5.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            post_lt5_ndii = post_lt5.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            post_lt5 = post_lt5.addBands(post_lt5_nbr).addBands(post_lt5_ndvi).addBands(post_lt5_ndii)

            #apply the corrections

            l5_post_corr = post_lt5.multiply(l5_corr[1]).add(post_lt5.pow(2).multiply(l5_corr[2])).add(post_lt5.pow(3).multiply(l5_corr[3])).add(l5_corr[0])


        #------------------------------------------Landsat 7, no corrections but get things clipped and do pre fire/post_fire stuff


        #select bands
        pre_le7 = le7.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

              #ensure we have imagery for the sensor
        if pre_le7.size().getInfo() > 0 :

            #take the median
            pre_le7 = pre_le7.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            pre_le7_nbr = pre_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            pre_le7_ndvi = pre_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            pre_le7_ndii = pre_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            pre_le72 = pre_le7.addBands(pre_le7_nbr).addBands(pre_le7_ndvi).addBands(pre_le7_ndii)

#         #-------now do post-fire
#         #select bands
        post_le7 = le7.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if post_le7.size().getInfo() > 0 :


            #take the median
            post_le7 = post_le7.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            post_le7_nbr = post_le7.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            post_le7_ndvi = post_le7.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            post_le7_ndii = post_le7.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            post_le72 = post_le7.addBands(post_le7_nbr).addBands(post_le7_ndvi).addBands(post_le7_ndii)

        #------------------------------------------Landsat 8 corrections


        #-------first do pre-fire

        #select bands, note here we rename to match landsat 5 and 7
        pre_lc8 = lc8.filterDate(pre_start, pre_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if pre_lc8.size().getInfo() > 0 :

            #take the median
            pre_lc8 = pre_lc8.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            pre_lc8_nbr = pre_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            pre_lc8_ndvi = pre_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            pre_lc8_ndii = pre_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            pre_lc8 = pre_lc8.addBands(pre_lc8_nbr).addBands(pre_lc8_ndvi).addBands(pre_lc8_ndii)

            #apply the corrections
            l8_pre_corr = pre_lc8.multiply(l8_corr[1]).add(pre_lc8.pow(2).multiply(l8_corr[2])).add(pre_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

        #-------now do post-fire
          #select bands
        post_lc8 = lc8.filterDate(post_start, post_end).map(mask).map(land_scale).filterBounds(final_buffer).select(['SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7'],['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if post_lc8.size().getInfo() > 0 :

        #take the median
            post_lc8 = post_lc8.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            post_lc8_nbr = post_lc8.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            post_lc8_ndvi = post_lc8.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            post_lc8_ndii = post_lc8.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            post_lc8 = post_lc8.addBands(post_lc8_nbr).addBands(post_lc8_ndvi).addBands(post_lc8_ndii)

            #apply the corrections

            l8_post_corr = post_lc8.multiply(l8_corr[1]).add(post_lc8.pow(2).multiply(l8_corr[2])).add(post_lc8.pow(3).multiply(l8_corr[3])).add(l8_corr[0])
        #------------------------------------------Sentinel 2 corrections, use landsat 8 coefficients


        #-------first do pre-fire

        # select bands
        pre_sent = sent_2A.filterDate(pre_start, pre_end).map(sent_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if pre_sent.size().getInfo() > 0 :

            #take the median
            pre_sent = pre_sent.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            pre_sent_nbr = pre_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            pre_sent_ndvi = pre_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            pre_sent_ndii = pre_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            pre_sent = pre_sent.addBands(pre_sent_nbr).addBands(pre_sent_ndvi).addBands(pre_sent_ndii)

            #apply the corrections

            sent_pre_corr = pre_sent.multiply(l8_corr[1]).add(pre_sent.pow(2).multiply(l8_corr[2])).add(pre_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])

        #-------now do post-fire
        #select bands
        post_sent = sent_2A.filterDate(post_start, post_end).map(sent_scale).filterBounds(final_buffer).select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).map(to_float)

        #       #ensure we have imagery for the sensor
        if post_sent.size().getInfo() > 0 :

            #take the median
            post_sent = post_sent.median().clip(final_buffer)

            #calculate nbr, ndvi and ndii
            post_sent_nbr = post_sent.normalizedDifference(['SR_B4', 'SR_B7']).select([0], ['NBR']).toFloat()
            post_sent_ndvi = post_sent.normalizedDifference(['SR_B4', 'SR_B3']).select([0], ['NDVI']).toFloat()
            post_sent_ndii = post_sent.normalizedDifference(['SR_B4', 'SR_B5']).select([0], ['NDII']).toFloat()

            #add the bands back
            post_sent = post_sent.addBands(post_sent_nbr).addBands(post_sent_ndvi).addBands(post_sent_ndii)

            #apply the corrections

            sent_post_corr = post_sent.multiply(l8_corr[1]).add(post_sent.pow(2).multiply(l8_corr[2])).add(post_sent.pow(3).multiply(l8_corr[3])).add(l8_corr[0])


        #try to see if image exists, if so append

        #----------------------all prefire

        #empty list for pre-fire, use this to combine if we have land 5, 7, 8 or sentinel 
        pre_input = []

        try:
            l5_pre_corr.getInfo()
            pre_input.append(l5_pre_corr)

        except:
            pass

        try:
            pre_le72.getInfo()
            pre_input.append(pre_le72)

        except:
            pass

        try:
            l8_pre_corr.getInfo()
            pre_input.append(l8_pre_corr)

        except:
            pass

        try:
            sent_pre_corr.getInfo()
            pre_input.append(sent_pre_corr)

        except:
            pass


        #----------------------all postfire

        #empty list for post-fire, use this to combine if we have land 5, 7, 8 or sentinel 
        post_input = []

        try:
            l5_post_corr.getInfo()
            post_input.append(l5_post_corr)

        except:
            pass

        try:
            post_le72.getInfo()
            post_input.append(post_le72)

        except:
            pass

        try:
            l8_post_corr.getInfo()
            post_input.append(l8_post_corr)

        except:
            pass

        try:
            sent_post_corr.getInfo()
            post_input.append(sent_post_corr)

        except:
            pass
    
        
        #ensure we have both pre fire and post fire imagery, otherwise can't get training data
        if (len(pre_input) >0) and (len(post_input) > 0):

            #take the median of the image collections
            pre_input = ee.ImageCollection(pre_input)
            post_input = ee.ImageCollection(post_input)

            pre_input = pre_input.median()
            post_input= post_input.median()

            #difference the bands fore pre and post fire
            raw_bands = pre_input.subtract(post_input).multiply(1000)

            #we need to see which image ids from the entire lfdb are already included in the buffer
            lfdb_filtered_orig = lfdb.filterBounds(final_buffer)

            #ensure all fires are within the actual year of interest (this_year) and two years prior, otherwise ignore, this is to ensure we don't have nearby fires from previous years
            first_year =  int(startYear) + 1
            second_year =  int(startYear)
            third_year =  int(startYear) - 1
            fourth_year = int(startYear) + 2

            lfdb_filtered = lfdb_filtered_orig.filter(ee.Filter.eq("Year", first_year))

            bad_filtered = lfdb_filtered_orig.filter(ee.Filter.Or(ee.Filter.eq("Year", second_year), ee.Filter.eq("Year", third_year), ee.Filter.eq("Year", fourth_year)))


            #get ids which are in image
            all_ids_new = ee.List(lfdb_filtered.distinct(["ID"]).aggregate_array("ID")).getInfo()


            #remove ids from all dates which we do not need anymore
            all_ids2 = [i for i in all_ids if i not in all_ids_new]

            #area we have good fires
            fire_rast = lfdb_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

            #areas we have fires from other years or nearby we don't want to use
            bad_fire_rast = bad_filtered.reduceToImage(properties= ['ID'], reducer = ee.Reducer.first())

            #change values to 1 for fire of interest
            fire_rast = fire_rast.where(fire_rast.gt(0), 1)

            #change values for bad fire raster to 1 as well
            bad_fire_rast = bad_fire_rast.where(bad_fire_rast.gt(0), 1)

            #if the fires overlap we want to keep those locations
            bad_fire_rast = bad_fire_rast.where(bad_fire_rast.eq(1).And(fire_rast.eq(1)), 2).unmask(-999)

            #rename to y for the fire raster
            fire_rast = fire_rast.rename(['y'])

            #copy the first values of raw_bands
            y = post_input.select(['SR_B2'], ['y'])

            #turn all values of y to 0
            y  = y.where(y.gt(0), 0)

            #turn values to 1 where fire_rast is 1
            y  = y.where(fire_rast.eq(1), 1)
            
            #we need to ensure all bands are shorts 
            b1 = raw_bands.select('SR_B1').cast({'SR_B1':'short'}) 
            b2 = raw_bands.select('SR_B2').cast({'SR_B2':'short'}) 
            b3 = raw_bands.select('SR_B3').cast({'SR_B3':'short'}) 
            b4 = raw_bands.select('SR_B4').cast({'SR_B4':'short'}) 
            b5 = raw_bands.select('SR_B5').cast({'SR_B5':'short'}) 
            b6 = raw_bands.select('SR_B7').cast({'SR_B7':'short'}) 
            b7 = raw_bands.select('NBR').cast({'NBR':'short'}) 
            b8 = raw_bands.select('NDVI').cast({'NDVI':'short'}) 
            b9 = raw_bands.select('NDII').cast({'NDII':'short'}) 
            b10 = y.select('y').cast({'y':'short'})
            
            #combine all the bands for predictors
            # raw_bands = b1.addBands(b2).addBands(b3).addBands(b4).addBands(b5).addBands(b6).addBands(b7).addBands(b8).addBands(b9)
            raw_bands = b7.addBands(b8).addBands(b9)

            #for areas where there are nearby fires or fires in previous years we set those to 0
            raw_bands = raw_bands.updateMask(bad_fire_rast.neq(1))
            
            #add in the target variable
            raw_bands = raw_bands.addBands(b10)

            #start download
            print(f"Downloading {fname}")
            

            #export image to my cloud storage
            task = ee.batch.Export.image.toCloudStorage(
                                    image = raw_bands.toShort(),
                                    region=final_buffer2, 
                                    description='median_' + str(i),
                                    scale=30,
                                    crs='EPSG:3413',
                                    maxPixels=1e13,
                                    bucket = 'smp-scratch')
            
#             ds = xr.open_dataset(raw_bands.toShort(),
#                      engine='ee',
#                      crs='EPSG:3413',
#                      scale=30,
#                      geometry=final_buffer2)  
            
#             # You can also simply save it as zarr (and use compression too):
#             compressor = zarr.Blosc(cname="zstd", clevel=3, shuffle=2)
#             ds.to_zarr(os.path.join(out_path, fname.replace('.tif', '.zarr')), 
                              # encoding={fname.replace('.tif', ''):{"compressor":compressor}})  

            task.start()
# Out:
# Downloading median_2497.tif
# Downloading median_4628.tif
# Downloading median_6169.tif
# Downloading median_10045.tif
# Downloading median_10849.tif
# Downloading median_11241.tif
# Downloading median_11146.tif
# Downloading median_471.tif
# Downloading median_636.tif
# Downloading median_697.tif
# Downloading median_728.tif
# Downloading median_1067.tif
# Downloading median_2227.tif
# Downloading median_2576.tif
# Downloading median_2514.tif
# Downloading median_2534.tif
# Downloading median_3606.tif
# Downloading median_3635.tif
# Downloading median_3645.tif
# Downloading median_3685.tif
# Downloading median_3703.tif
# Downloading median_4541.tif
# Downloading median_4721.tif
# Downloading median_4490.tif
# Downloading median_4568.tif
# Downloading median_4573.tif
# Downloading median_4480.tif
# Downloading median_4589.tif
# Downloading median_4633.tif
# Downloading median_5319.tif
# Downloading median_5422.tif
# Downloading median_5322.tif
# Downloading median_5419.tif
# Downloading median_5455.tif
# Downloading median_5330.tif
# Downloading median_5432.tif
# Downloading median_5523.tif
# Downloading median_5525.tif
# Downloading median_5531.tif
# Downloading median_5520.tif
# Downloading median_6559.tif
# Downloading median_6448.tif
# Downloading median_6357.tif
# Downloading median_6383.tif
# Downloading median_6322.tif
# Downloading median_6324.tif
# Downloading median_6329.tif
# Downloading median_6336.tif
# Downloading median_6337.tif
# Downloading median_6373.tif
# Downloading median_6400.tif
# Downloading median_6432.tif
# Downloading median_6565.tif
# Downloading median_6610.tif
# Downloading median_6611.tif
# Downloading median_6334.tif
# Downloading median_6375.tif
# Downloading median_6439.tif
# Downloading median_6330.tif
# Downloading median_6397.tif
# Downloading median_7174.tif
# Downloading median_7084.tif
# Downloading median_7406.tif
# Downloading median_7150.tif
# Downloading median_7156.tif
# Downloading median_7230.tif
# Downloading median_7272.tif
# Downloading median_7410.tif
# Downloading median_7438.tif
# Downloading median_8443.tif
# Downloading median_8442.tif
# Downloading median_9082.tif
# Downloading median_9086.tif
# Downloading median_8486.tif
# Downloading median_9072.tif
# Downloading median_9455.tif
# Downloading median_9463.tif
# Downloading median_9807.tif
# Downloading median_9633.tif
# Downloading median_10043.tif
# Downloading median_10630.tif
# Downloading median_10621.tif
# Downloading median_10481.tif
# Downloading median_10646.tif
# Downloading median_11183.tif
# Downloading median_11201.tif
# Downloading median_11207.tif
# Downloading median_11237.tif
# Downloading median_379.tif
# Downloading median_375.tif
# Downloading median_50.tif
# Downloading median_142.tif
# Downloading median_263.tif
# Downloading median_389.tif
# Downloading median_374.tif
# Downloading median_387.tif
# Downloading median_95.tif
# Downloading median_486.tif
# Downloading median_444.tif
# Downloading median_578.tif
# Downloading median_736.tif
# Downloading median_757.tif
# Downloading median_787.tif
# Downloading median_795.tif
# Downloading median_932.tif
# Downloading median_1435.tif
# Downloading median_1264.tif
# Downloading median_1298.tif
# Downloading median_1314.tif
# Downloading median_1220.tif
# Downloading median_1202.tif
# Downloading median_1364.tif
# Downloading median_1493.tif
# Downloading median_1296.tif
# Downloading median_1327.tif
# Downloading median_1695.tif
# Downloading median_1565.tif
# Downloading median_1757.tif
# Downloading median_1544.tif
# Downloading median_1545.tif
# Downloading median_1556.tif
# Downloading median_1559.tif
# Downloading median_1584.tif
# Downloading median_1595.tif
# Downloading median_1602.tif
# Downloading median_1615.tif
# Downloading median_1617.tif
# Downloading median_1620.tif
# Downloading median_1676.tif
# Downloading median_1681.tif
# Downloading median_1689.tif
# Downloading median_1696.tif
# Downloading median_1785.tif
# Downloading median_1796.tif
# Downloading median_1808.tif
# Downloading median_1580.tif
# Downloading median_1601.tif
# Downloading median_1781.tif
# Downloading median_1568.tif
# Downloading median_1577.tif
# Downloading median_1581.tif
# Downloading median_1570.tif
# Downloading median_1585.tif
# Downloading median_1603.tif
# Downloading median_1673.tif
# Downloading median_1794.tif
# Downloading median_1795.tif
# Downloading median_1822.tif
# Downloading median_1686.tif
# Downloading median_1683.tif
# Downloading median_1684.tif
# Downloading median_1887.tif
# Downloading median_1890.tif
# Downloading median_1912.tif
# Downloading median_1925.tif
# Downloading median_1940.tif
# Downloading median_1892.tif
# Downloading median_1895.tif
# Downloading median_1897.tif
# Downloading median_1896.tif
# Downloading median_1900.tif
# Downloading median_1937.tif
# Downloading median_1958.tif
# Downloading median_1907.tif
# Downloading median_1909.tif
# Downloading median_1917.tif
# Downloading median_1926.tif
# Downloading median_1929.tif
# Downloading median_1931.tif
# Downloading median_1975.tif
# Downloading median_1982.tif
# Downloading median_1889.tif
# Downloading median_1910.tif
# Downloading median_1981.tif
# Downloading median_2031.tif
# Downloading median_2184.tif
# Downloading median_2187.tif
# Downloading median_2339.tif
# Downloading median_2233.tif
# Downloading median_2354.tif
# Downloading median_2013.tif
# Downloading median_2182.tif
# Downloading median_2032.tif
# Downloading median_2598.tif
# Downloading median_2471.tif
# Downloading median_2481.tif
# Downloading median_2564.tif
# Downloading median_2640.tif
# Downloading median_2749.tif
# Downloading median_3086.tif
# Downloading median_3412.tif
# Downloading median_3150.tif
# Downloading median_3180.tif
# Downloading median_3462.tif
# Downloading median_3631.tif
# Downloading median_3670.tif
# Downloading median_3546.tif
# Downloading median_3634.tif
# Downloading median_3843.tif
# Downloading median_3885.tif
# Downloading median_3495.tif
# Downloading median_3508.tif
# Downloading median_4461.tif
# Downloading median_4463.tif
# Downloading median_4475.tif
# Downloading median_4516.tif
# Downloading median_4533.tif
# Downloading median_4559.tif
# Downloading median_4583.tif
# Downloading median_4590.tif
# Downloading median_4620.tif
# Downloading median_4692.tif
# Downloading median_4695.tif
# Downloading median_4697.tif
# Downloading median_4803.tif
# Downloading median_4824.tif
# Downloading median_4483.tif
# Downloading median_4484.tif
# Downloading median_4494.tif
# Downloading median_4506.tif
# Downloading median_4524.tif
# Downloading median_4531.tif
# Downloading median_4603.tif
# Downloading median_4686.tif
# Downloading median_4827.tif
# Downloading median_4468.tif
# Downloading median_4477.tif
# Downloading median_4481.tif
# Downloading median_4556.tif
# Downloading median_4576.tif
# Downloading median_4597.tif
# Downloading median_4600.tif
# Downloading median_4637.tif
# Downloading median_4809.tif
# Downloading median_4501.tif
# Downloading median_4544.tif
# Downloading median_4548.tif
# Downloading median_4575.tif
# Downloading median_4606.tif
# Downloading median_4646.tif
# Downloading median_4723.tif
# Downloading median_4774.tif
# Downloading median_4779.tif
# Downloading median_4818.tif
# Downloading median_4493.tif
# Downloading median_4564.tif
# Downloading median_4649.tif
# Downloading median_4677.tif
# Downloading median_4678.tif
# Downloading median_4699.tif
# Downloading median_4708.tif
# Downloading median_4724.tif
# Downloading median_4819.tif
# Downloading median_4753.tif
# Downloading median_4780.tif
# Downloading median_4634.tif
# Downloading median_4828.tif
# Downloading median_4829.tif
# Downloading median_4866.tif
# Downloading median_5273.tif
# Downloading median_4843.tif
# Downloading median_4850.tif
# Downloading median_4888.tif
# Downloading median_5133.tif
# Downloading median_5209.tif
# Downloading median_4903.tif
# Downloading median_5129.tif
# Downloading median_5219.tif
# Downloading median_5317.tif
# Downloading median_5313.tif
# Downloading median_5341.tif
# Downloading median_5343.tif
# Downloading median_5379.tif
# Downloading median_5457.tif
# Downloading median_5320.tif
# Downloading median_5344.tif
# Downloading median_5357.tif
# Downloading median_5370.tif
# Downloading median_5373.tif
# Downloading median_5374.tif
# Downloading median_5378.tif
# Downloading median_5380.tif
# Downloading median_5383.tif
# Downloading median_5387.tif
# Downloading median_5393.tif
# Downloading median_5404.tif
# Downloading median_5405.tif
# Downloading median_5423.tif
# Downloading median_5437.tif
# Downloading median_5438.tif
# Downloading median_5517.tif
# Downloading median_5528.tif
# Downloading median_5580.tif
# Downloading median_5396.tif
# Downloading median_5451.tif
# Downloading median_5491.tif
# Downloading median_5336.tif
# Downloading median_5429.tif
# Downloading median_5448.tif
# Downloading median_5478.tif
# Downloading median_5488.tif
# Downloading median_5524.tif
# Downloading median_5527.tif
# Downloading median_5323.tif
# Downloading median_5342.tif
# Downloading median_5477.tif
# Downloading median_5495.tif
# Downloading median_5518.tif
# Downloading median_5522.tif
# Downloading median_5530.tif
# Downloading median_5555.tif
# Downloading median_5585.tif
# Downloading median_5587.tif
# Downloading median_5589.tif
# Downloading median_5590.tif
# Downloading median_5593.tif
# Downloading median_5318.tif
# Downloading median_5403.tif
# Downloading median_5479.tif
# Downloading median_5532.tif
# Downloading median_5579.tif
# Downloading median_5592.tif
# Downloading median_5311.tif
# Downloading median_5348.tif
# Downloading median_5363.tif
# Downloading median_5371.tif
# Downloading median_5384.tif
# Downloading median_5392.tif
# Downloading median_5420.tif
# Downloading median_5534.tif
# Downloading median_5556.tif
# Downloading median_5572.tif
# Downloading median_5576.tif
# Downloading median_5578.tif
# Downloading median_5337.tif
# Downloading median_5382.tif
# Downloading median_5535.tif
# Downloading median_5536.tif
# Downloading median_5574.tif
# Downloading median_5598.tif
# Downloading median_5614.tif
# Downloading median_5594.tif
# Downloading median_5605.tif
# Downloading median_5867.tif
# Downloading median_5791.tif
# Downloading median_5857.tif
# Downloading median_5906.tif
# Downloading median_6042.tif
# Downloading median_6220.tif
# Downloading median_6139.tif
# Downloading median_5928.tif
# Downloading median_5940.tif
# Downloading median_5956.tif
# Downloading median_5966.tif
# Downloading median_5977.tif
# Downloading median_6009.tif
# Downloading median_6033.tif
# Downloading median_6081.tif
# Downloading median_6174.tif
# Downloading median_6073.tif
# Downloading median_5936.tif
# Downloading median_5974.tif
# Downloading median_6017.tif
# Downloading median_6032.tif
# Downloading median_6045.tif
# Downloading median_6137.tif
# Downloading median_5988.tif
# Downloading median_6222.tif
# Downloading median_6000.tif
# Downloading median_6040.tif
# Downloading median_6412.tif
# Downloading median_6321.tif
# Downloading median_6410.tif
# Downloading median_6411.tif
# Downloading median_6605.tif
# Downloading median_6325.tif
# Downloading median_6331.tif
# Downloading median_6433.tif
# Downloading median_6476.tif
# Downloading median_6960.tif
# Downloading median_6735.tif
# Downloading median_6749.tif
# Downloading median_7019.tif
# Downloading median_6775.tif
# Downloading median_7533.tif
# Downloading median_7244.tif
# Downloading median_7545.tif
# Downloading median_7196.tif
# Downloading median_7064.tif
# Downloading median_7373.tif
# Downloading median_7231.tif
# Downloading median_7221.tif
# Downloading median_7245.tif
# Downloading median_7051.tif
# Downloading median_7213.tif
# Downloading median_7319.tif
# Downloading median_7441.tif
# Downloading median_7464.tif
# Downloading median_7071.tif
# Downloading median_7280.tif
# Downloading median_7333.tif
# Downloading median_7490.tif
# Downloading median_7263.tif
# Downloading median_7487.tif
# Downloading median_7530.tif
# Downloading median_7238.tif
# Downloading median_7239.tif
# Downloading median_7447.tif
# Downloading median_7241.tif
# Downloading median_7256.tif
# Downloading median_7301.tif
# Downloading median_7346.tif
# Downloading median_7149.tif
# Downloading median_7488.tif
# Downloading median_8065.tif
# Downloading median_8373.tif
# Downloading median_8071.tif
# Downloading median_8385.tif
# Downloading median_7990.tif
# Downloading median_7991.tif
# Downloading median_8534.tif
# Downloading median_8806.tif
# Downloading median_8837.tif
# Downloading median_8445.tif
# Downloading median_8817.tif
# Downloading median_9464.tif
# Downloading median_9206.tif
# Downloading median_9295.tif
# Downloading median_9369.tif
# Downloading median_9716.tif
# Downloading median_9656.tif
# Downloading median_9578.tif
# Downloading median_9702.tif
# Downloading median_9763.tif
# Downloading median_10642.tif
# Downloading median_10427.tif
# Downloading median_10250.tif
# Downloading median_10132.tif
# Downloading median_10252.tif
# Downloading median_10301.tif
# Downloading median_10340.tif
# Downloading median_10885.tif
# Downloading median_11126.tif
# Downloading median_11223.tif
# Downloading median_11202.tif
# Downloading median_11212.tif
# Downloading median_11133.tif
# Downloading median_11213.tif
# Downloading median_208.tif
# Downloading median_354.tif
# Downloading median_489.tif
# Downloading median_498.tif
# Downloading median_504.tif
# Downloading median_520.tif
# Downloading median_549.tif
# Downloading median_648.tif
# Downloading median_612.tif
# Downloading median_629.tif
# Downloading median_637.tif
# Downloading median_641.tif
# Downloading median_649.tif
# Downloading median_646.tif
# Downloading median_661.tif
# Downloading median_635.tif
# Downloading median_1061.tif
# Downloading median_1486.tif
# Downloading median_1495.tif
# Downloading median_1497.tif
# Downloading median_1500.tif
# Downloading median_1502.tif
# Downloading median_1231.tif
# Downloading median_1344.tif
# Downloading median_1348.tif
# Downloading median_1290.tif
# Downloading median_1230.tif
# Downloading median_1677.tif
# Downloading median_1950.tif
# Downloading median_1908.tif
# Downloading median_1992.tif
# Downloading median_1970.tif
# Downloading median_2262.tif
# Downloading median_2315.tif
# Downloading median_2312.tif
# Downloading median_2336.tif
# Downloading median_2739.tif
# Downloading median_2568.tif
# Downloading median_2853.tif
# Downloading median_2923.tif
# Downloading median_2973.tif
# Downloading median_2980.tif
# Downloading median_2983.tif
# Downloading median_2989.tif
# Downloading median_2921.tif
# Downloading median_3015.tif
# Downloading median_2914.tif
# Downloading median_2981.tif
# Downloading median_2982.tif
# Downloading median_3004.tif
# Downloading median_3008.tif
# Downloading median_3010.tif
# Downloading median_3011.tif
# Downloading median_3018.tif
# Downloading median_2829.tif
# Downloading median_2868.tif
# Downloading median_2936.tif
# Downloading median_2979.tif
# Downloading median_2986.tif
# Downloading median_2987.tif
# Downloading median_2999.tif
# Downloading median_3022.tif
# Downloading median_3024.tif
# Downloading median_3026.tif
# Downloading median_2990.tif
# Downloading median_2984.tif
# Downloading median_2988.tif
# Downloading median_2991.tif
# Downloading median_2996.tif
# Downloading median_3002.tif
# Downloading median_3005.tif
# Downloading median_2867.tif
# Downloading median_2919.tif
# Downloading median_2939.tif
# Downloading median_2985.tif
# Downloading median_2992.tif
# Downloading median_3009.tif
# Downloading median_3023.tif
# Downloading median_3182.tif
# Downloading median_3190.tif
# Downloading median_3209.tif
# Downloading median_3249.tif
# Downloading median_3258.tif
# Downloading median_3281.tif
# Downloading median_3163.tif
# Downloading median_3200.tif
# Downloading median_3162.tif
# Downloading median_3218.tif
# Downloading median_3280.tif
# Downloading median_3353.tif
# Downloading median_3378.tif
# Downloading median_3171.tif
# Downloading median_3173.tif
# Downloading median_3191.tif
# Downloading median_3204.tif
# Downloading median_3206.tif
# Downloading median_3259.tif
# Downloading median_3225.tif
# Downloading median_3244.tif
# Downloading median_3245.tif
# Downloading median_3420.tif
# Downloading median_3146.tif
# Downloading median_3148.tif
# Downloading median_3153.tif
# Downloading median_3177.tif
# Downloading median_3196.tif
# Downloading median_3208.tif
# Downloading median_3210.tif
# Downloading median_3220.tif
# Downloading median_3234.tif
# Downloading median_3243.tif
# Downloading median_3257.tif
# Downloading median_3290.tif
# Downloading median_3381.tif
# Downloading median_3405.tif
# Downloading median_3385.tif
# Downloading median_3360.tif
# Downloading median_3176.tif
# Downloading median_3155.tif
# Downloading median_3235.tif
# Downloading median_3887.tif
# Downloading median_3650.tif
# Downloading median_3669.tif
# Downloading median_3921.tif
# Downloading median_3917.tif
# Downloading median_3560.tif
# Downloading median_3895.tif
# Downloading median_4217.tif
# Downloading median_4430.tif
# Downloading median_4436.tif
# Downloading median_4498.tif
# Downloading median_4574.tif
# Downloading median_4644.tif
# Downloading median_4718.tif
# Downloading median_4772.tif
# Downloading median_4802.tif
# Downloading median_4690.tif
# Downloading median_4713.tif
# Downloading median_4728.tif
# Downloading median_4740.tif
# Downloading median_4815.tif
# Downloading median_4825.tif
# Downloading median_4795.tif
# Downloading median_4812.tif
# Downloading median_4504.tif
# Downloading median_4528.tif
# Downloading median_4537.tif
# Downloading median_4587.tif
# Downloading median_4594.tif
# Downloading median_4614.tif
# Downloading median_4794.tif
# Downloading median_4535.tif
# Downloading median_4554.tif
# Downloading median_4791.tif
# Downloading median_4521.tif
# Downloading median_4536.tif
# Downloading median_4553.tif
# Downloading median_4650.tif
# Downloading median_4653.tif
# Downloading median_4712.tif
# Downloading median_4744.tif
# Downloading median_4769.tif
# Downloading median_4823.tif
# Downloading median_4786.tif
# Downloading median_4789.tif
# Downloading median_4797.tif
# Downloading median_4584.tif
# Downloading median_4663.tif
# Downloading median_4865.tif
# Downloading median_5154.tif
# Downloading median_5092.tif
# Downloading median_5144.tif
# Downloading median_5047.tif
# Downloading median_4970.tif
# Downloading median_5459.tif
# Downloading median_5407.tif
# Downloading median_5356.tif
# Downloading median_6202.tif
# Downloading median_6223.tif
# Downloading median_6010.tif
# Downloading median_6039.tif
# Downloading median_5929.tif
# Downloading median_5959.tif
# Downloading median_5961.tif
# Downloading median_6195.tif
# Downloading median_6203.tif
# Downloading median_6225.tif
# Downloading median_6193.tif
# Downloading median_7026.tif
# Downloading median_6843.tif
# Downloading median_7023.tif
# Downloading median_6859.tif
# Downloading median_7318.tif
# Downloading median_7489.tif
# Downloading median_7151.tif
# Downloading median_7577.tif
# Downloading median_7604.tif
# Downloading median_7618.tif
# Downloading median_7621.tif
# Downloading median_7642.tif
# Downloading median_7725.tif
# Downloading median_7970.tif
# Downloading median_7635.tif
# Downloading median_7662.tif
# Downloading median_7578.tif
# Downloading median_7579.tif
# Downloading median_7643.tif
# Downloading median_7699.tif
# Downloading median_7700.tif
# Downloading median_7719.tif
# Downloading median_7793.tif
# Downloading median_7606.tif
# Downloading median_7619.tif
# Downloading median_7632.tif
# Downloading median_7723.tif
# Downloading median_7734.tif
# Downloading median_7767.tif
# Downloading median_7774.tif
# Downloading median_7871.tif
# Downloading median_7934.tif
# Downloading median_7973.tif
# Downloading median_7655.tif
# Downloading median_7656.tif
# Downloading median_7684.tif
# Downloading median_7685.tif
# Downloading median_7724.tif
# Downloading median_7935.tif
# Downloading median_7620.tif
# Downloading median_7601.tif
# Downloading median_7654.tif
# Downloading median_7665.tif
# Downloading median_7698.tif
# Downloading median_7715.tif
# Downloading median_7804.tif
# Downloading median_7836.tif
# Downloading median_7967.tif
# Downloading median_7835.tif
# Downloading median_7969.tif
# Downloading median_7726.tif
# Downloading median_7731.tif
# Downloading median_7766.tif
# Downloading median_7816.tif
# Downloading median_8074.tif
# Downloading median_8155.tif
# Downloading median_8168.tif
# Downloading median_8169.tif
# Downloading median_8295.tif
# Downloading median_8232.tif
# Downloading median_8362.tif
# Downloading median_8414.tif
# Downloading median_8038.tif
# Downloading median_8113.tif
# Downloading median_8289.tif
# Downloading median_8281.tif
# Downloading median_8535.tif
# Downloading median_8885.tif
# Downloading median_9100.tif
# Downloading median_8926.tif
# Downloading median_9419.tif
# Downloading median_9229.tif
# Downloading median_9257.tif
# Downloading median_9326.tif
# Downloading median_9439.tif
# Downloading median_9466.tif
# Downloading median_9471.tif
# Downloading median_9202.tif
# Downloading median_9209.tif
# Downloading median_9211.tif
# Downloading median_9276.tif
# Downloading median_9333.tif
# Downloading median_9376.tif
# Downloading median_9395.tif
# Downloading median_9397.tif
# Downloading median_9207.tif
# Downloading median_9246.tif
# Downloading median_9316.tif
# Downloading median_9328.tif
# Downloading median_9339.tif
# Downloading median_9370.tif
# Downloading median_9390.tif
# Downloading median_9457.tif
# Downloading median_9285.tif
# Downloading median_9212.tif
# Downloading median_9247.tif
# Downloading median_9331.tif
# Downloading median_9408.tif
# Downloading median_9235.tif
# Downloading median_9266.tif
# Downloading median_9406.tif
# Downloading median_9582.tif
# Downloading median_10046.tif
# Downloading median_9871.tif
# Downloading median_10200.tif
# Downloading median_10279.tif
# Downloading median_10635.tif
# Downloading median_10649.tif
# Downloading median_10374.tif
# Downloading median_10203.tif
# Downloading median_10143.tif
# Downloading median_10321.tif
# Downloading median_10793.tif
# Downloading median_10797.tif
# Downloading median_10186.tif
# Downloading median_11070.tif
# Downloading median_10963.tif
# Downloading median_10801.tif
# Downloading median_10845.tif
# Downloading median_10893.tif
# Downloading median_10919.tif
# Downloading median_11072.tif
# Downloading median_10802.tif
# Downloading median_10863.tif
# Downloading median_11136.tif
# Downloading median_11134.tif
# Downloading median_11127.tif
# Downloading median_11197.tif
# Downloading median_11204.tif
# Downloading median_11116.tif
# Downloading median_11190.tif
# Downloading median_11210.tif
# Downloading median_11151.tif
# Downloading median_296.tif
# Downloading median_96.tif
# Downloading median_510.tif
# Downloading median_524.tif
# Downloading median_516.tif
# Downloading median_615.tif
# Downloading median_616.tif
# Downloading median_663.tif
# Downloading median_665.tif
# Downloading median_666.tif
# Downloading median_668.tif
# Downloading median_670.tif
# Downloading median_662.tif
# Downloading median_664.tif
# Downloading median_588.tif
# Downloading median_628.tif
# Downloading median_671.tif
# Downloading median_669.tif
# Downloading median_672.tif
# Downloading median_673.tif
# Downloading median_674.tif
# Downloading median_667.tif
# Downloading median_762.tif
# Downloading median_838.tif
# Downloading median_1484.tif
# Downloading median_1485.tif
# Downloading median_1489.tif
# Downloading median_1210.tif
# Downloading median_1362.tif
# Downloading median_1512.tif
# Downloading median_1509.tif
# Downloading median_1164.tif
# Downloading median_1267.tif
# Downloading median_1408.tif
# Downloading median_1161.tif
# Downloading median_1163.tif
# Downloading median_1315.tif
# Downloading median_1335.tif
# Downloading median_1360.tif
# Downloading median_1177.tif
# Downloading median_1605.tif
# Downloading median_1643.tif
# Downloading median_1575.tif
# Downloading median_1589.tif
# Downloading median_1635.tif
# Downloading median_1734.tif
# Downloading median_1737.tif
# Downloading median_1739.tif
# Downloading median_1740.tif
# Downloading median_1847.tif
# Downloading median_1855.tif
# Downloading median_1857.tif
# Downloading median_1861.tif
# Downloading median_1671.tif
# Downloading median_1835.tif
# Downloading median_1856.tif
# Downloading median_1858.tif
# Downloading median_2722.tif
# Downloading median_2691.tif
# Downloading median_2692.tif
# Downloading median_3021.tif
# Downloading median_3019.tif
# Downloading median_2827.tif
# Downloading median_3309.tif
# Downloading median_3311.tif
# Downloading median_3888.tif
# Downloading median_3889.tif
# Downloading median_3913.tif
# Downloading median_3501.tif
# Downloading median_3665.tif
# Downloading median_3482.tif
# Downloading median_3742.tif
# Downloading median_3902.tif
# Downloading median_3906.tif
# Downloading median_3909.tif
# Downloading median_3911.tif
# Downloading median_3686.tif
# Downloading median_3905.tif
# Downloading median_3914.tif
# Downloading median_3832.tif
# Downloading median_5456.tif
# Downloading median_5910.tif
# Downloading median_5901.tif
# Downloading median_8094.tif
# Downloading median_8235.tif
# Downloading median_8360.tif
# Downloading median_8296.tif
# Downloading median_8110.tif
# Downloading median_8218.tif
# Downloading median_9290.tif
# Downloading median_9475.tif
# Downloading median_9459.tif
# Downloading median_10206.tif
# Downloading median_11135.tif
# Downloading median_11165.tif
# Downloading median_301.tif
# Downloading median_482.tif
# Downloading median_1829.tif
# Downloading median_3583.tif
# Downloading median_5668.tif
# Downloading median_4403.tif
# Downloading median_4482.tif
# Downloading median_4530.tif
# Downloading median_2544.tif
# Downloading median_4777.tif
# Downloading median_6024.tif
# Downloading median_8317.tif
# Downloading median_9441.tif
# Downloading median_619.tif
# Downloading median_2121.tif
# Downloading median_2190.tif
# Downloading median_2220.tif
# Downloading median_2296.tif
# Downloading median_2297.tif
# Downloading median_2254.tif
# Downloading median_2302.tif
# Downloading median_2175.tif
# Downloading median_2295.tif
# Downloading median_2479.tif
# Downloading median_2509.tif
# Downloading median_2539.tif
# Downloading median_2584.tif
# Downloading median_2623.tif
# Downloading median_2647.tif
# Downloading median_2621.tif
# Downloading median_2577.tif
# Downloading median_2560.tif
# Downloading median_3073.tif
# Downloading median_3601.tif
# Downloading median_3481.tif
# Downloading median_3678.tif
# Downloading median_4591.tif
# Downloading median_4499.tif
# Downloading median_4510.tif
# Downloading median_4727.tif
# Downloading median_4814.tif
# Downloading median_4466.tif
# Downloading median_4525.tif
# Downloading median_4562.tif
# Downloading median_4607.tif
# Downloading median_5020.tif
# Downloading median_5049.tif
# Downloading median_4884.tif
# Downloading median_5496.tif
# Downloading median_5386.tif
# Downloading median_5557.tif
# Downloading median_5541.tif
# Downloading median_6335.tif
# Downloading median_6279.tif
# Downloading median_6346.tif
# Downloading median_6615.tif
# Downloading median_7491.tif
# Downloading median_7388.tif
# Downloading median_7183.tif
# Downloading median_7492.tif
# Downloading median_7575.tif
# Downloading median_7152.tif
# Downloading median_7250.tif
# Downloading median_8040.tif
# Downloading median_8331.tif
# Downloading median_8180.tif
# Downloading median_8145.tif
# Downloading median_9263.tif
# Downloading median_9480.tif
# Downloading median_48.tif
# Downloading median_114.tif
# Downloading median_214.tif
# Downloading median_93.tif
# Downloading median_199.tif
# Downloading median_59.tif
# Downloading median_170.tif
# Downloading median_202.tif
# Downloading median_206.tif
# Downloading median_376.tif
# Downloading median_727.tif
# Downloading median_744.tif
# Downloading median_745.tif
# Downloading median_748.tif
# Downloading median_751.tif
# Downloading median_752.tif
# Downloading median_749.tif
# Downloading median_747.tif
# Downloading median_848.tif
# Downloading median_1037.tif
# Downloading median_1036.tif
# Downloading median_1074.tif
# Downloading median_1038.tif
# Downloading median_1075.tif
# Downloading median_1076.tif
# Downloading median_1081.tif
# Downloading median_1077.tif
# Downloading median_910.tif
# Downloading median_1083.tif
# Downloading median_1080.tif
# Downloading median_1378.tif
# Downloading median_1287.tif
# Downloading median_1403.tif
# Downloading median_1417.tif
# Downloading median_1421.tif
# Downloading median_1478.tif
# Downloading median_1356.tif
# Downloading median_1416.tif
# Downloading median_1274.tif
# Downloading median_1374.tif
# Downloading median_1187.tif
# Downloading median_1358.tif
# Downloading median_1425.tif
# Downloading median_1446.tif
# Downloading median_1453.tif
# Downloading median_1470.tif
# Downloading median_1481.tif
# Downloading median_1186.tif
# Downloading median_1271.tif
# Downloading median_1303.tif
# Downloading median_1318.tif
# Downloading median_1354.tif
# Downloading median_1788.tif
# Downloading median_1707.tif
# Downloading median_1724.tif
# Downloading median_1745.tif
# Downloading median_1569.tif
# Downloading median_1600.tif
# Downloading median_1653.tif
# Downloading median_1697.tif
# Downloading median_1708.tif
# Downloading median_1746.tif
# Downloading median_1748.tif
# Downloading median_1789.tif
# Downloading median_1567.tif
# Downloading median_1772.tif
# Downloading median_1714.tif
# Downloading median_1685.tif
# Downloading median_1701.tif
# Downloading median_1551.tif
# Downloading median_1561.tif
# Downloading median_1566.tif
# Downloading median_1599.tif
# Downloading median_1611.tif
# Downloading median_1612.tif
# Downloading median_1654.tif
# Downloading median_1679.tif
# Downloading median_1741.tif
# Downloading median_1744.tif
# Downloading median_1831.tif
# Downloading median_1547.tif
# Downloading median_1554.tif
# Downloading median_1557.tif
# Downloading median_1693.tif
# Downloading median_1702.tif
# Downloading median_1703.tif
# Downloading median_1769.tif
# Downloading median_1971.tif
# Downloading median_1938.tif
# Downloading median_1943.tif
# Downloading median_1963.tif
# Downloading median_1966.tif
# Downloading median_1967.tif
# Downloading median_1979.tif
# Downloading median_1901.tif
# Downloading median_1904.tif
# Downloading median_1919.tif
# Downloading median_1934.tif
# Downloading median_1935.tif
# Downloading median_1944.tif
# Downloading median_1957.tif
# Downloading median_1903.tif
# Downloading median_1956.tif
# Downloading median_1959.tif
# Downloading median_1960.tif
# Downloading median_1962.tif
# Downloading median_1893.tif
# Downloading median_1918.tif
# Downloading median_1965.tif
# Downloading median_2304.tif
# Downloading median_2258.tif
# Downloading median_2243.tif
# Downloading median_2326.tif
# Downloading median_2024.tif
# Downloading median_2081.tif
# Downloading median_2109.tif
# Downloading median_2319.tif
# Downloading median_2240.tif
# Downloading median_2310.tif
# Downloading median_2314.tif
# Downloading median_2500.tif
# Downloading median_2571.tif
# Downloading median_3103.tif
# Downloading median_3230.tif
# Downloading median_3266.tif
# Downloading median_3365.tif
# Downloading median_3404.tif
# Downloading median_3507.tif
# Downloading median_3541.tif
# Downloading median_3461.tif
# Downloading median_3561.tif
# Downloading median_3759.tif
# Downloading median_3761.tif
# Downloading median_3629.tif
# Downloading median_3789.tif
# Downloading median_4247.tif
# Downloading median_4491.tif
# Downloading median_4629.tif
# Downloading median_4808.tif
# Downloading median_4669.tif
# Downloading median_4977.tif
# Downloading median_5039.tif
# Downloading median_4935.tif
# Downloading median_4895.tif
# Downloading median_4934.tif
# Downloading median_5460.tif
# Downloading median_5583.tif
# Downloading median_5439.tif
# Downloading median_5519.tif
# Downloading median_5562.tif
# Downloading median_5568.tif
# Downloading median_5564.tif
# Downloading median_5570.tif
# Downloading median_5482.tif
# Downloading median_5533.tif
# Downloading median_5888.tif
# Downloading median_5954.tif
# Downloading median_5976.tif
# Downloading median_6007.tif
# Downloading median_6191.tif
# Downloading median_5957.tif
# Downloading median_5989.tif
# Downloading median_5996.tif
# Downloading median_6190.tif
# Downloading median_5931.tif
# Downloading median_5939.tif
# Downloading median_5967.tif
# Downloading median_6046.tif
# Downloading median_5975.tif
# Downloading median_6048.tif
# Downloading median_6176.tif
# Downloading median_6021.tif
# Downloading median_5934.tif
# Downloading median_5943.tif
# Downloading median_6367.tif
# Downloading median_6416.tif
# Downloading median_6408.tif
# Downloading median_6438.tif
# Downloading median_6320.tif
# Downloading median_6359.tif
# Downloading median_6642.tif
# Downloading median_6617.tif
# Downloading median_7012.tif
# Downloading median_6893.tif
# Downloading median_7016.tif
# Downloading median_7021.tif
# Downloading median_6961.tif
# Downloading median_7255.tif
# Downloading median_7262.tif
# Downloading median_7497.tif
# Downloading median_7095.tif
# Downloading median_7516.tif
# Downloading median_8032.tif
# Downloading median_8090.tif
# Downloading median_9132.tif
# Downloading median_8951.tif
# Downloading median_8531.tif
# Downloading median_9120.tif
# Downloading median_9143.tif
# Downloading median_9287.tif
# Downloading median_9738.tif
# Downloading median_9880.tif
# Downloading median_9566.tif
# Downloading median_9580.tif
# Downloading median_9690.tif
# Downloading median_9743.tif
# Downloading median_10794.tif
# Downloading median_10331.tif
# Downloading median_10121.tif
# Downloading median_10266.tif
# Downloading median_10280.tif
# Downloading median_10290.tif
# Downloading median_10306.tif
# Downloading median_10323.tif
# Downloading median_10362.tif
# Downloading median_10373.tif
# Downloading median_11112.tif
# Downloading median_11118.tif
# Downloading median_427.tif
# Downloading median_176.tif
# Downloading median_121.tif
# Downloading median_370.tif
# Downloading median_477.tif
# Downloading median_483.tif
# Downloading median_513.tif
# Downloading median_499.tif
# Downloading median_472.tif
# Downloading median_490.tif
# Downloading median_497.tif
# Downloading median_562.tif
# Downloading median_605.tif
# Downloading median_644.tif
# Downloading median_660.tif
# Downloading median_632.tif
# Downloading median_656.tif
# Downloading median_622.tif
# Downloading median_1243.tif
# Downloading median_1278.tif
# Downloading median_1280.tif
# Downloading median_1300.tif
# Downloading median_1310.tif
# Downloading median_1322.tif
# Downloading median_1336.tif
# Downloading median_1341.tif
# Downloading median_1342.tif
# Downloading median_1346.tif
# Downloading median_1347.tif
# Downloading median_1166.tif
# Downloading median_1688.tif
# Downloading median_1555.tif
# Downloading median_1837.tif
# Downloading median_1825.tif
# Downloading median_1830.tif
# Downloading median_1969.tif
# Downloading median_1968.tif
# Downloading median_1914.tif
# Downloading median_1974.tif
# Downloading median_1894.tif
# Downloading median_1978.tif
# Downloading median_2313.tif
# Downloading median_2242.tif
# Downloading median_2256.tif
# Downloading median_2342.tif
# Downloading median_2036.tif
# Downloading median_2143.tif
# Downloading median_2222.tif
# Downloading median_2039.tif
# Downloading median_2062.tif
# Downloading median_2170.tif
# Downloading median_2330.tif
# Downloading median_2255.tif
# Downloading median_2235.tif
# Downloading median_2300.tif
# Downloading median_2191.tif
# Downloading median_2257.tif
# Downloading median_2928.tif
# Downloading median_2964.tif
# Downloading median_2924.tif
# Downloading median_2947.tif
# Downloading median_2946.tif
# Downloading median_3120.tif
# Downloading median_3291.tif
# Downloading median_3390.tif
# Downloading median_3398.tif
# Downloading median_3189.tif
# Downloading median_3192.tif
# Downloading median_3247.tif
# Downloading median_3279.tif
# Downloading median_3283.tif
# Downloading median_3307.tif
# Downloading median_3232.tif
# Downloading median_3145.tif
# Downloading median_3149.tif
# Downloading median_3219.tif
# Downloading median_3248.tif
# Downloading median_3297.tif
# Downloading median_3298.tif
# Downloading median_3377.tif
# Downloading median_3393.tif
# Downloading median_3394.tif
# Downloading median_3397.tif
# Downloading median_3402.tif
# Downloading median_3411.tif
# Downloading median_3172.tif
# Downloading median_3199.tif
# Downloading median_3236.tif
# Downloading median_3246.tif
# Downloading median_3403.tif
# Downloading median_3410.tif
# Downloading median_3415.tif
# Downloading median_3240.tif
# Downloading median_3255.tif
# Downloading median_3195.tif
# Downloading median_3286.tif
# Downloading median_3254.tif
# Downloading median_3359.tif
# Downloading median_3303.tif
# Downloading median_3334.tif
# Downloading median_3333.tif
# Downloading median_3267.tif
# Downloading median_4505.tif
# Downloading median_4580.tif
# Downloading median_4581.tif
# Downloading median_4754.tif
# Downloading median_4514.tif
# Downloading median_4518.tif
# Downloading median_4565.tif
# Downloading median_4570.tif
# Downloading median_4745.tif
# Downloading median_4798.tif
# Downloading median_4711.tif
# Downloading median_4816.tif
# Downloading median_4660.tif
# Downloading median_4741.tif
# Downloading median_4781.tif
# Downloading median_4806.tif
# Downloading median_4725.tif
# Downloading median_4770.tif
# Downloading median_4773.tif
# Downloading median_4817.tif
# Downloading median_4782.tif
# Downloading median_5153.tif
# Downloading median_4943.tif
# Downloading median_5210.tif
# Downloading median_5810.tif
# Downloading median_5891.tif
# Downloading median_6108.tif
# Downloading median_6853.tif
# Downloading median_6916.tif
# Downloading median_7003.tif
# Downloading median_7501.tif
# Downloading median_7075.tif
# Downloading median_7576.tif
# Downloading median_7097.tif
# Downloading median_7229.tif
# Downloading median_7270.tif
# Downloading median_7498.tif
# Downloading median_7495.tif
# Downloading median_7458.tif
# Downloading median_7610.tif
# Downloading median_7691.tif
# Downloading median_7732.tif
# Downloading median_7756.tif
# Downloading median_7746.tif
# Downloading median_7692.tif
# Downloading median_7736.tif
# Downloading median_7777.tif
# Downloading median_7850.tif
# Downloading median_7885.tif
# Downloading median_7932.tif
# Downloading median_7964.tif
# Downloading median_7797.tif
# Downloading median_7778.tif
# Downloading median_7802.tif
# Downloading median_7933.tif
# Downloading median_7660.tif
# Downloading median_7856.tif
# Downloading median_7862.tif
# Downloading median_7872.tif
# Downloading median_7863.tif
# Downloading median_7925.tif
# Downloading median_8030.tif
# Downloading median_8214.tif
# Downloading median_9140.tif
# Downloading median_9338.tif
# Downloading median_9469.tif
# Downloading median_9303.tif
# Downloading median_9230.tif
# Downloading median_9239.tif
# Downloading median_9248.tif
# Downloading median_9275.tif
# Downloading median_9227.tif
# Downloading median_9241.tif
# Downloading median_9399.tif
# Downloading median_9934.tif
# Downloading median_10269.tif
# Downloading median_10351.tif
# Downloading median_10262.tif
# Downloading median_10237.tif
# Downloading median_10273.tif
# Downloading median_10311.tif
# Downloading median_10350.tif
# Downloading median_10131.tif
# Downloading median_10141.tif
# Downloading median_10204.tif
# Downloading median_10222.tif
# Downloading median_10431.tif
# Downloading median_10525.tif
# Downloading median_10547.tif
# Downloading median_10548.tif
# Downloading median_10573.tif
# Downloading median_10220.tif
# Downloading median_10400.tif
# Downloading median_10788.tif
# Downloading median_10365.tif
# Downloading median_10287.tif
# Downloading median_10330.tif
# Downloading median_10248.tif
# Downloading median_10471.tif
# Downloading median_10737.tif
# Downloading median_10381.tif
# Downloading median_10145.tif
# Downloading median_11073.tif
# Downloading median_10824.tif
# Downloading median_10837.tif
# Downloading median_10834.tif
# Downloading median_10980.tif
# Downloading median_11167.tif
# Downloading median_11206.tif
# Downloading median_49.tif
# Downloading median_240.tif
# Downloading median_428.tif
# Downloading median_75.tif
# Downloading median_205.tif
# Downloading median_280.tif
# Downloading median_286.tif
# Downloading median_377.tif
# Downloading median_446.tif
# Downloading median_621.tif
# Downloading median_647.tif
# Downloading median_614.tif
# Downloading median_630.tif
# Downloading median_634.tif
# Downloading median_1160.tif
# Downloading median_1373.tif
# Downloading median_1361.tif
# Downloading median_1369.tif
# Downloading median_1397.tif
# Downloading median_1400.tif
# Downloading median_1379.tif
# Downloading median_1433.tif
# Downloading median_1407.tif
# Downloading median_1398.tif
# Downloading median_1414.tif
# Downloading median_1661.tif
# Downloading median_1804.tif
# Downloading median_1812.tif
# Downloading median_1915.tif
# Downloading median_2113.tif
# Downloading median_2251.tif
# Downloading median_2195.tif
# Downloading median_2516.tif
# Downloading median_2542.tif
# Downloading median_2629.tif
# Downloading median_2929.tif
# Downloading median_2961.tif
# Downloading median_3582.tif
# Downloading median_3540.tif
# Downloading median_3644.tif
# Downloading median_3656.tif
# Downloading median_3674.tif
# Downloading median_3630.tif
# Downloading median_3632.tif
# Downloading median_3637.tif
# Downloading median_3657.tif
# Downloading median_3671.tif
# Downloading median_3648.tif
# Downloading median_3649.tif
# Downloading median_4630.tif
# Downloading median_4638.tif
# Downloading median_5208.tif
# Downloading median_5017.tif
# Downloading median_5218.tif
# Downloading median_7009.tif
# Downloading median_6733.tif
# Downloading median_9477.tif
# Downloading median_9731.tif
# Downloading median_10052.tif
# Downloading median_2655.tif
# Downloading median_4197.tif
# Downloading median_4487.tif
# Downloading median_4563.tif
# Downloading median_4761.tif
# Downloading median_5207.tif
# Downloading median_5018.tif
# Downloading median_5085.tif
# Downloading median_4855.tif
# Downloading median_5113.tif
# Downloading median_4871.tif
# Downloading median_5118.tif
# Downloading median_5203.tif
# Downloading median_4863.tif
# Downloading median_4874.tif
# Downloading median_5170.tif
# Downloading median_5051.tif
# Downloading median_5169.tif
# Downloading median_5171.tif
# Downloading median_5178.tif
# Downloading median_5179.tif
# Downloading median_5201.tif
# Downloading median_4854.tif
# Downloading median_4908.tif
# Downloading median_4972.tif
# Downloading median_4989.tif
# Downloading median_4991.tif
# Downloading median_5050.tif
# Downloading median_5095.tif
# Downloading median_5098.tif
# Downloading median_5156.tif
# Downloading median_5164.tif
# Downloading median_5167.tif
# Downloading median_5168.tif
# Downloading median_5173.tif
# Downloading median_5174.tif
# Downloading median_5177.tif
# Downloading median_5182.tif
# Downloading median_5202.tif
# Downloading median_4909.tif
# Downloading median_5040.tif
# Downloading median_5069.tif
# Downloading median_5161.tif
# Downloading median_5881.tif
# Downloading median_6996.tif
# Downloading median_2931.tif
# Downloading median_3395.tif
# Downloading median_3997.tif
# Downloading median_6979.tif
# Downloading median_6997.tif
# Downloading median_9330.tif
# Downloading median_2930.tif
# Downloading median_4388.tif
# Downloading median_10700.tif
# Downloading median_338.tif
# Downloading median_266.tif
# Downloading median_476.tif
# Downloading median_613.tif
# Downloading median_626.tif
# Downloading median_627.tif
# Downloading median_686.tif
# Downloading median_842.tif
# Downloading median_1256.tif
# Downloading median_1329.tif
# Downloading median_2089.tif
# Downloading median_2444.tif
# Downloading median_2446.tif
# Downloading median_2657.tif
# Downloading median_2630.tif
# Downloading median_2639.tif
# Downloading median_2664.tif
# Downloading median_2680.tif
# Downloading median_2583.tif
# Downloading median_2585.tif
# Downloading median_2632.tif
# Downloading median_2637.tif
# Downloading median_2654.tif
# Downloading median_2957.tif
# Downloading median_3762.tif
# Downloading median_5619.tif
# Downloading median_5968.tif
# Downloading median_6638.tif
# Downloading median_6616.tif
# Downloading median_6314.tif
# Downloading median_6323.tif
# Downloading median_6709.tif
# Downloading median_6561.tif
# Downloading median_7038.tif
# Downloading median_6726.tif
# Downloading median_6744.tif
# Downloading median_8618.tif
# Downloading median_8689.tif
# Downloading median_8924.tif
# Downloading median_9038.tif
# Downloading median_8800.tif
# Downloading median_8465.tif
# Downloading median_8606.tif
# Downloading median_8659.tif
# Downloading median_8872.tif
# Downloading median_8882.tif
# Downloading median_9006.tif
# Downloading median_8452.tif
# Downloading median_8477.tif
# Downloading median_8504.tif
# Downloading median_8974.tif
# Downloading median_9043.tif
# Downloading median_8566.tif
# Downloading median_8506.tif
# Downloading median_8836.tif
# Downloading median_8920.tif
# Downloading median_8505.tif
# Downloading median_8637.tif
# Downloading median_8656.tif
# Downloading median_8681.tif
# Downloading median_9144.tif
# Downloading median_9023.tif
# Downloading median_9201.tif
# Downloading median_8564.tif
# Downloading median_8493.tif
# Downloading median_9440.tif
# Downloading median_10805.tif
# Downloading median_11017.tif
# Downloading median_11037.tif
# Downloading median_10886.tif
# Downloading median_116.tif
# Downloading median_329.tif
# Downloading median_194.tif
# Downloading median_328.tif
# Downloading median_334.tif
# Downloading median_337.tif
# Downloading median_429.tif
# Downloading median_430.tif
# Downloading median_302.tif
# Downloading median_330.tif
# Downloading median_331.tif
# Downloading median_335.tif
# Downloading median_339.tif
# Downloading median_364.tif
# Downloading median_431.tif
# Downloading median_550.tif
# Downloading median_651.tif
# Downloading median_569.tif
# Downloading median_696.tif
# Downloading median_705.tif
# Downloading median_707.tif
# Downloading median_709.tif
# Downloading median_746.tif
# Downloading median_754.tif
# Downloading median_730.tif
# Downloading median_739.tif
# Downloading median_773.tif
# Downloading median_712.tif
# Downloading median_716.tif
# Downloading median_753.tif
# Downloading median_750.tif
# Downloading median_771.tif
# Downloading median_713.tif
# Downloading median_767.tif
# Downloading median_741.tif
# Downloading median_859.tif
# Downloading median_861.tif
# Downloading median_822.tif
# Downloading median_860.tif
# Downloading median_1041.tif
# Downloading median_1073.tif
# Downloading median_972.tif
# Downloading median_1079.tif
# Downloading median_1042.tif
# Downloading median_1070.tif
# Downloading median_1072.tif
# Downloading median_1085.tif
# Downloading median_1125.tif
# Downloading median_1431.tif
# Downloading median_1185.tif
# Downloading median_1380.tif
# Downloading median_1365.tif
# Downloading median_1233.tif
# Downloading median_1143.tif
# Downloading median_1532.tif
# Downloading median_1241.tif
# Downloading median_1238.tif
# Downloading median_1304.tif
# Downloading median_1427.tif
# Downloading median_1529.tif
# Downloading median_1179.tif
# Downloading median_1195.tif
# Downloading median_1350.tif
# Downloading median_1366.tif
# Downloading median_1483.tif
# Downloading median_1422.tif
# Downloading median_1457.tif
# Downloading median_1193.tif
# Downloading median_1208.tif
# Downloading median_1224.tif
# Downloading median_1263.tif
# Downloading median_1381.tif
# Downloading median_1487.tif
# Downloading median_1528.tif
# Downloading median_1530.tif
# Downloading median_1173.tif
# Downloading median_1198.tif
# Downloading median_1372.tif
# Downloading median_1418.tif
# Downloading median_1454.tif
# Downloading median_1459.tif
# Downloading median_1461.tif
# Downloading median_1291.tif
# Downloading median_1308.tif
# Downloading median_1349.tif
# Downloading median_1382.tif
# Downloading median_1456.tif
# Downloading median_1176.tif
# Downloading median_1201.tif
# Downloading median_1245.tif
# Downloading median_1272.tif
# Downloading median_1306.tif
# Downloading median_1328.tif
# Downloading median_1367.tif
# Downloading median_1385.tif
# Downloading median_1390.tif
# Downloading median_1412.tif
# Downloading median_1242.tif
# Downloading median_1370.tif
# Downloading median_1389.tif
# Downloading median_1411.tif
# Downloading median_1140.tif
# Downloading median_1239.tif
# Downloading median_1189.tif
# Downloading median_1232.tif
# Downloading median_1464.tif
# Downloading median_1384.tif
# Downloading median_1392.tif
# Downloading median_1721.tif
# Downloading median_1651.tif
# Downloading median_1758.tif
# Downloading median_1807.tif
# Downloading median_1809.tif
# Downloading median_1560.tif
# Downloading median_1626.tif
# Downloading median_1698.tif
# Downloading median_1699.tif
# Downloading median_1710.tif
# Downloading median_1715.tif
# Downloading median_1716.tif
# Downloading median_1764.tif
# Downloading median_1770.tif
# Downloading median_1771.tif
# Downloading median_1773.tif
# Downloading median_1776.tif
# Downloading median_1779.tif
# Downloading median_1791.tif
# Downloading median_1797.tif
# Downloading median_1800.tif
# Downloading median_1811.tif
# Downloading median_1713.tif
# Downloading median_1756.tif
# Downloading median_1759.tif
# Downloading median_1760.tif
# Downloading median_1761.tif
# Downloading median_1762.tif
# Downloading median_1766.tif
# Downloading median_1768.tif
# Downloading median_1712.tif
# Downloading median_1597.tif
# Downloading median_1755.tif
# Downloading median_1763.tif
# Downloading median_1709.tif
# Downloading median_1813.tif
# Downloading median_1881.tif
# Downloading median_1884.tif
# Downloading median_1885.tif
# Downloading median_1727.tif
# Downloading median_1874.tif
# Downloading median_1573.tif
# Downloading median_1576.tif
# Downloading median_1590.tif
# Downloading median_1726.tif
# Downloading median_1880.tif
# Downloading median_1563.tif
# Downloading median_1650.tif
# Downloading median_1687.tif
# Downloading median_1877.tif
# Downloading median_1738.tif
# Downloading median_1680.tif
# Downloading median_1872.tif
# Downloading median_2433.tif
# Downloading median_2193.tif
# Downloading median_2445.tif
# Downloading median_2120.tif
# Downloading median_2363.tif
# Downloading median_2095.tif
# Downloading median_2298.tif
# Downloading median_2299.tif
# Downloading median_2305.tif
# Downloading median_2019.tif
# ...
# Downloading median_5415.tif
# Downloading median_5362.tif
# Downloading median_5433.tif
# Downloading median_5584.tif
# Downloading median_5388.tif
# Downloading median_5641.tif
# Downloading median_5804.tif
# Downloading median_5671.tif
# Downloading median_5728.tif
# Downloading median_5815.tif
# Downloading median_5742.tif
# Downloading median_5692.tif
# Downloading median_5738.tif
# Downloading median_5660.tif
# Downloading median_6418.tif
# Downloading median_6398.tif
# Downloading median_6473.tif
# Downloading median_6354.tif
# Downloading median_6294.tif
# Downloading median_6407.tif
# Downloading median_6395.tif
# Downloading median_6469.tif
# Downloading median_6539.tif
# Downloading median_6560.tif
# Downloading median_6282.tif
# Downloading median_6463.tif
# Downloading median_6292.tif
# Downloading median_6304.tif
# Downloading median_6365.tif
# Downloading median_6406.tif
# Downloading median_6443.tif
# Downloading median_6505.tif
# Downloading median_6532.tif
# Downloading median_6537.tif
# Downloading median_6690.tif
# Downloading median_6313.tif
# Downloading median_6347.tif
# Downloading median_6468.tif
# Downloading median_6533.tif
# Downloading median_6683.tif
# Downloading median_6363.tif
# Downloading median_6504.tif
# Downloading median_6528.tif
# Downloading median_6308.tif
# Downloading median_6525.tif
# Downloading median_6526.tif
# Downloading median_6684.tif
# Downloading median_6446.tif
# Downloading median_6503.tif
# Downloading median_6287.tif
# Downloading median_6530.tif
# Downloading median_6379.tif
# Downloading median_6689.tif
# Downloading median_6987.tif
# Downloading median_7045.tif
# Downloading median_6730.tif
# Downloading median_6864.tif
# Downloading median_7354.tif
# Downloading median_7066.tif
# Downloading median_7193.tif
# Downloading median_7217.tif
# Downloading median_7233.tif
# Downloading median_7413.tif
# Downloading median_7054.tif
# Downloading median_7077.tif
# Downloading median_7211.tif
# Downloading median_7112.tif
# Downloading median_7128.tif
# Downloading median_7177.tif
# Downloading median_7204.tif
# Downloading median_7248.tif
# Downloading median_7261.tif
# Downloading median_7294.tif
# Downloading median_7329.tif
# Downloading median_7340.tif
# Downloading median_7061.tif
# Downloading median_7279.tif
# Downloading median_7409.tif
# Downloading median_7046.tif
# Downloading median_7049.tif
# Downloading median_7123.tif
# Downloading median_7609.tif
# Downloading median_7776.tif
# Downloading median_7820.tif
# Downloading median_7614.tif
# Downloading median_7670.tif
# Downloading median_7839.tif
# Downloading median_7868.tif
# Downloading median_7971.tif
# Downloading median_7678.tif
# Downloading median_7808.tif
# Downloading median_7867.tif
# Downloading median_7771.tif
# Downloading median_7599.tif
# Downloading median_7864.tif
# Downloading median_8014.tif
# Downloading median_8066.tif
# Downloading median_8172.tif
# Downloading median_8293.tif
# Downloading median_8103.tif
# Downloading median_8183.tif
# Downloading median_8181.tif
# Downloading median_8358.tif
# Downloading median_8107.tif
# Downloading median_8345.tif
# Downloading median_8219.tif
# Downloading median_8332.tif
# Downloading median_8059.tif
# Downloading median_8972.tif
# Downloading median_8494.tif
# Downloading median_9059.tif
# Downloading median_8507.tif
# Downloading median_8568.tif
# Downloading median_8615.tif
# Downloading median_8688.tif
# Downloading median_8890.tif
# Downloading median_8629.tif
# Downloading median_8670.tif
# Downloading median_8943.tif
# Downloading median_9069.tif
# Downloading median_8586.tif
# Downloading median_8760.tif
# Downloading median_8473.tif
# Downloading median_8984.tif
# Downloading median_8542.tif
# Downloading median_8844.tif
# Downloading median_8879.tif
# Downloading median_8983.tif
# Downloading median_9437.tif
# Downloading median_9365.tif
# Downloading median_9413.tif
# Downloading median_9568.tif
# Downloading median_9695.tif
# Downloading median_9665.tif
# Downloading median_9667.tif
# Downloading median_9598.tif
# Downloading median_9796.tif
# Downloading median_9552.tif
# Downloading median_9659.tif
# Downloading median_10201.tif
# Downloading median_10148.tif
# Downloading median_10597.tif
# Downloading median_10591.tif
# Downloading median_10965.tif
# Downloading median_10803.tif
# Downloading median_10906.tif
# Downloading median_10964.tif
# Downloading median_10927.tif
# Downloading median_10976.tif
# Downloading median_11051.tif
# Downloading median_11053.tif
# Downloading median_11048.tif
# Downloading median_11049.tif
# Downloading median_10847.tif
# Downloading median_10952.tif
# Downloading median_10939.tif
# Downloading median_11047.tif
# Downloading median_14.tif
# Downloading median_99.tif
# Downloading median_35.tif
# Downloading median_58.tif
# Downloading median_88.tif
# Downloading median_101.tif
# Downloading median_163.tif
# Downloading median_136.tif
# Downloading median_270.tif
# Downloading median_283.tif
# Downloading median_384.tif
# Downloading median_382.tif
# Downloading median_383.tif
# Downloading median_435.tif
# Downloading median_526.tif
# Downloading median_527.tif
# Downloading median_519.tif
# Downloading median_521.tif
# Downloading median_591.tif
# Downloading median_575.tif
# Downloading median_602.tif
# Downloading median_555.tif
# Downloading median_600.tif
# Downloading median_620.tif
# Downloading median_597.tif
# Downloading median_611.tif
# Downloading median_557.tif
# Downloading median_733.tif
# Downloading median_961.tif
# Downloading median_893.tif
# Downloading median_1022.tif
# Downloading median_872.tif
# Downloading median_884.tif
# Downloading median_2132.tif
# Downloading median_2246.tif
# Downloading median_2204.tif
# Downloading median_2391.tif
# Downloading median_2393.tif
# Downloading median_2185.tif
# Downloading median_2370.tif
# Downloading median_2104.tif
# Downloading median_2130.tif
# Downloading median_2351.tif
# Downloading median_2371.tif
# Downloading median_2380.tif
# Downloading median_2383.tif
# Downloading median_2365.tif
# Downloading median_2379.tif
# Downloading median_2384.tif
# Downloading median_2154.tif
# Downloading median_2566.tif
# Downloading median_2997.tif
# Downloading median_2894.tif
# Downloading median_3017.tif
# Downloading median_3138.tif
# Downloading median_3664.tif
# Downloading median_3897.tif
# Downloading median_3907.tif
# Downloading median_3908.tif
# Downloading median_3468.tif
# Downloading median_3868.tif
# Downloading median_3658.tif
# Downloading median_3896.tif
# Downloading median_3990.tif
# Downloading median_4366.tif
# Downloading median_5509.tif
# Downloading median_5650.tif
# Downloading median_5908.tif
# Downloading median_5743.tif
# Downloading median_6352.tif
# Downloading median_6471.tif
# Downloading median_6534.tif
# Downloading median_6666.tif
# Downloading median_6303.tif
# Downloading median_6310.tif
# Downloading median_6668.tif
# Downloading median_6423.tif
# Downloading median_6501.tif
# Downloading median_6531.tif
# Downloading median_6649.tif
# Downloading median_6685.tif
# Downloading median_6686.tif
# Downloading median_7348.tif
# Downloading median_7188.tif
# Downloading median_7825.tif
# Downloading median_7761.tif
# Downloading median_7616.tif
# Downloading median_7818.tif
# Downloading median_7869.tif
# Downloading median_7624.tif
# Downloading median_8101.tif
# Downloading median_8227.tif
# Downloading median_8352.tif
# Downloading median_8366.tif
# Downloading median_8013.tif
# Downloading median_8118.tif
# Downloading median_8192.tif
# Downloading median_8239.tif
# Downloading median_8256.tif
# Downloading median_8370.tif
# Downloading median_8212.tif
# Downloading median_8308.tif
# Downloading median_8355.tif
# Downloading median_8073.tif
# Downloading median_8226.tif
# Downloading median_8280.tif
# Downloading median_8078.tif
# Downloading median_8039.tif
# Downloading median_8271.tif
# Downloading median_8963.tif
# Downloading median_9776.tif
# Downloading median_9885.tif
# Downloading median_9543.tif
# Downloading median_9558.tif
# Downloading median_9595.tif
# Downloading median_9777.tif
# Downloading median_9803.tif
# Downloading median_9982.tif
# Downloading median_9626.tif
# Downloading median_9720.tif
# Downloading median_9631.tif
# Downloading median_9610.tif
# Downloading median_9643.tif
# Downloading median_9990.tif
# Downloading median_9512.tif
# Downloading median_9518.tif
# Downloading median_9689.tif
# Downloading median_9759.tif
# Downloading median_10021.tif
# Downloading median_9729.tif
# Downloading median_9831.tif
# Downloading median_9952.tif
# Downloading median_9576.tif
# Downloading median_9579.tif
# Downloading median_9625.tif
# Downloading median_9747.tif
# Downloading median_9938.tif
# Downloading median_9653.tif
# Downloading median_9661.tif
# Downloading median_9860.tif
# Downloading median_10532.tif
# Downloading median_10665.tif
# Downloading median_2455.tif
# Downloading median_2456.tif
# Downloading median_2086.tif
# Downloading median_7027.tif
# Downloading median_7650.tif
# Downloading median_7749.tif
# Downloading median_7896.tif
# Downloading median_9524.tif
# Downloading median_4407.tif
# Downloading median_4415.tif
# Downloading median_4419.tif
# Downloading median_1184.tif
# Downloading median_2672.tif
# Downloading median_3704.tif
# Downloading median_5861.tif
# Downloading median_8991.tif
# Downloading median_10512.tif
# Downloading median_209.tif
# Downloading median_47.tif
# Downloading median_265.tif
# Downloading median_151.tif
# Downloading median_71.tif
# Downloading median_702.tif
# Downloading median_695.tif
# Downloading median_719.tif
# Downloading median_725.tif
# Downloading median_708.tif
# Downloading median_780.tif
# Downloading median_798.tif
# Downloading median_825.tif
# Downloading median_841.tif
# Downloading median_876.tif
# Downloading median_903.tif
# Downloading median_1065.tif
# Downloading median_954.tif
# Downloading median_882.tif
# Downloading median_885.tif
# Downloading median_897.tif
# Downloading median_911.tif
# Downloading median_891.tif
# Downloading median_962.tif
# Downloading median_1246.tif
# Downloading median_1254.tif
# Downloading median_1499.tif
# Downloading median_1503.tif
# Downloading median_1504.tif
# Downloading median_1496.tif
# Downloading median_1261.tif
# Downloading median_1305.tif
# Downloading median_1309.tif
# Downloading median_1345.tif
# Downloading median_1480.tif
# Downloading median_1498.tif
# Downloading median_1167.tif
# Downloading median_1326.tif
# Downloading median_1182.tif
# Downloading median_1270.tif
# Downloading median_1281.tif
# Downloading median_1475.tif
# Downloading median_1149.tif
# Downloading median_1174.tif
# Downloading median_1183.tif
# Downloading median_1206.tif
# Downloading median_1221.tif
# Downloading median_1222.tif
# Downloading median_1234.tif
# Downloading median_1317.tif
# Downloading median_1323.tif
# Downloading median_1482.tif
# Downloading median_1169.tif
# Downloading median_1248.tif
# Downloading median_1268.tif
# Downloading median_1286.tif
# Downloading median_1477.tif
# Downloading median_1492.tif
# Downloading median_1258.tif
# Downloading median_1505.tif
# Downloading median_1257.tif
# Downloading median_1488.tif
# Downloading median_1501.tif
# Downloading median_1269.tif
# Downloading median_1277.tif
# Downloading median_1490.tif
# Downloading median_1316.tif
# Downloading median_1682.tif
# Downloading median_1947.tif
# Downloading median_1939.tif
# Downloading median_2128.tif
# Downloading median_2003.tif
# Downloading median_2057.tif
# Downloading median_2055.tif
# Downloading median_2523.tif
# Downloading median_2734.tif
# Downloading median_2547.tif
# Downloading median_2678.tif
# Downloading median_2684.tif
# Downloading median_2694.tif
# Downloading median_2721.tif
# Downloading median_2726.tif
# Downloading median_2735.tif
# Downloading median_2736.tif
# Downloading median_2806.tif
# Downloading median_2807.tif
# Downloading median_2530.tif
# Downloading median_2556.tif
# Downloading median_2614.tif
# Downloading median_2619.tif
# Downloading median_2681.tif
# Downloading median_2682.tif
# Downloading median_2695.tif
# Downloading median_2696.tif
# Downloading median_2697.tif
# Downloading median_2702.tif
# Downloading median_2715.tif
# Downloading median_2716.tif
# Downloading median_2730.tif
# Downloading median_2741.tif
# Downloading median_2742.tif
# Downloading median_2714.tif
# Downloading median_3130.tif
# Downloading median_3135.tif
# Downloading median_3060.tif
# Downloading median_3066.tif
# Downloading median_3091.tif
# Downloading median_3069.tif
# Downloading median_3098.tif
# Downloading median_3096.tif
# Downloading median_3097.tif
# Downloading median_3115.tif
# Downloading median_3133.tif
# Downloading median_3131.tif
# Downloading median_3132.tif
# Downloading median_3076.tif
# Downloading median_3253.tif
# Downloading median_3401.tif
# Downloading median_3422.tif
# Downloading median_3421.tif
# Downloading median_3864.tif
# Downloading median_3564.tif
# Downloading median_3740.tif
# Downloading median_3504.tif
# Downloading median_3535.tif
# Downloading median_3598.tif
# Downloading median_3614.tif
# Downloading median_3861.tif
# Downloading median_3862.tif
# Downloading median_3880.tif
# Downloading median_4820.tif
# Downloading median_4496.tif
# Downloading median_4922.tif
# Downloading median_5266.tif
# Downloading median_5268.tif
# Downloading median_5197.tif
# Downloading median_5248.tif
# Downloading median_5007.tif
# Downloading median_4995.tif
# Downloading median_5088.tif
# Downloading median_5244.tif
# Downloading median_5254.tif
# Downloading median_4899.tif
# Downloading median_5025.tif
# Downloading median_5159.tif
# Downloading median_5242.tif
# Downloading median_5246.tif
# Downloading median_5250.tif
# Downloading median_5251.tif
# Downloading median_5256.tif
# Downloading median_5257.tif
# Downloading median_5259.tif
# Downloading median_5245.tif
# Downloading median_5255.tif
# Downloading median_5160.tif
# Downloading median_5241.tif
# Downloading median_5249.tif
# Downloading median_5252.tif
# Downloading median_5028.tif
# Downloading median_5091.tif
# Downloading median_5111.tif
# Downloading median_5200.tif
# Downloading median_5299.tif
# Downloading median_5606.tif
# Downloading median_5553.tif
# Downloading median_5575.tif
# Downloading median_5670.tif
# Downloading median_5776.tif
# Downloading median_5813.tif
# Downloading median_5698.tif
# Downloading median_5866.tif
# Downloading median_5893.tif
# Downloading median_5868.tif
# Downloading median_5898.tif
# Downloading median_5899.tif
# Downloading median_6453.tif
# Downloading median_6646.tif
# Downloading median_6648.tif
# Downloading median_6760.tif
# Downloading median_7538.tif
# Downloading median_7050.tif
# Downloading median_8198.tif
# Downloading median_9054.tif
# Downloading median_8894.tif
# Downloading median_9035.tif
# Downloading median_9101.tif
# Downloading median_9126.tif
# 2024-01-12 10:17:24,332 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-01-12 10:17:24,332 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-01-12 10:17:24,632 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,640 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,663 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,664 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,700 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,702 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,704 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,707 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,756 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,759 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,763 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,764 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,885 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,886 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,887 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:24,891 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:25,209 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:25,210 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:25,212 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:25,215 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:26,247 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:26,248 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:26,251 - distributed.nanny - WARNING - Restarting worker
# 2024-01-12 10:17:26,254 - distributed.nanny - WARNING - Restarting worker
